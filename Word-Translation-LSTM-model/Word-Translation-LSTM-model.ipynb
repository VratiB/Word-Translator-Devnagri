# %%
import xml.etree.ElementTree as ET 
import numpy as np
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# %%
# Load the data from the XML file
def load_data(filename):
    tree = ET.parse(filename)
    root = tree.getroot()
    input_texts = []
    target_texts = []
    for i, item in enumerate(root):
        input_text = item[0].text
        target_text = item[1].text
        input_texts.append(input_text)
        target_texts.append(target_text)
    return input_texts, target_texts

# Tokenize the text data
def tokenize(lang):
    lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='')
    lang_tokenizer.fit_on_texts(lang)
    tensor = lang_tokenizer.texts_to_sequences(lang)
    tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor, padding='post')
    return tensor, lang_tokenizer

# Load and tokenize the data
input_texts, target_texts = load_data('NEWS2018_M-EnHi_trn.xml')
input_tensor, inp_lang_tokenizer = tokenize(input_texts)
target_tensor, targ_lang_tokenizer = tokenize(target_texts)

# Calculate max length of input and target tensors
max_length_inp, max_length_tar = input_tensor.shape[1], target_tensor.shape[1]

# Convert the target tensor to have the expected shape
target_tensor = tf.keras.utils.to_categorical(target_tensor, num_classes=len(targ_lang_tokenizer.word_index) + 1)
target_tensor = tf.keras.preprocessing.sequence.pad_sequences(target_tensor, maxlen=max_length_inp, padding='post')

# Create the LSTM model
def create_model(inp_vocab_size, tar_vocab_size, max_length_inp, max_length_tar):
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Embedding(inp_vocab_size, 150, input_length=max_length_inp))
    model.add(tf.keras.layers.LSTM(150, return_sequences=True))
    model.add(tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(tar_vocab_size, activation='softmax')))
    return model


model = create_model(len(inp_lang_tokenizer.word_index) + 1, len(targ_lang_tokenizer.word_index) + 1, max_length_inp, max_length_tar)

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Fit the model
history = model.fit(input_tensor, target_tensor, epochs=45, batch_size=128, validation_split=0.2)
# Out:
# Epoch 1/45
# 81/81 [==============================] - 59s 705ms/step - loss: 4.1294 - accuracy: 0.8408 - val_loss: 1.6433 - val_accuracy: 0.8557
# Epoch 2/45
# 81/81 [==============================] - 56s 693ms/step - loss: 1.4660 - accuracy: 0.8515 - val_loss: 1.4200 - val_accuracy: 0.8557
# Epoch 3/45
# 81/81 [==============================] - 56s 687ms/step - loss: 1.3903 - accuracy: 0.8518 - val_loss: 1.4052 - val_accuracy: 0.8557
# Epoch 4/45
# 81/81 [==============================] - 57s 704ms/step - loss: 1.3755 - accuracy: 0.8517 - val_loss: 1.4037 - val_accuracy: 0.8557
# Epoch 5/45
# 81/81 [==============================] - 56s 695ms/step - loss: 1.3639 - accuracy: 0.8518 - val_loss: 1.4028 - val_accuracy: 0.8557
# Epoch 6/45
# 81/81 [==============================] - 57s 707ms/step - loss: 1.3541 - accuracy: 0.8515 - val_loss: 1.4017 - val_accuracy: 0.8557
# Epoch 7/45
# 81/81 [==============================] - 58s 716ms/step - loss: 1.3438 - accuracy: 0.8514 - val_loss: 1.4007 - val_accuracy: 0.8557
# Epoch 8/45
# 81/81 [==============================] - 53s 659ms/step - loss: 1.3325 - accuracy: 0.8514 - val_loss: 1.3983 - val_accuracy: 0.8557
# Epoch 9/45
# 81/81 [==============================] - 52s 647ms/step - loss: 1.3180 - accuracy: 0.8514 - val_loss: 1.3922 - val_accuracy: 0.8557
# Epoch 10/45
# 81/81 [==============================] - 56s 687ms/step - loss: 1.2980 - accuracy: 0.8514 - val_loss: 1.3800 - val_accuracy: 0.8557
# Epoch 11/45
# 81/81 [==============================] - 54s 668ms/step - loss: 1.2777 - accuracy: 0.8515 - val_loss: 1.3727 - val_accuracy: 0.8555
# Epoch 12/45
# 81/81 [==============================] - 58s 721ms/step - loss: 1.2594 - accuracy: 0.8517 - val_loss: 1.3710 - val_accuracy: 0.8557
# Epoch 13/45
# 81/81 [==============================] - 58s 719ms/step - loss: 1.2437 - accuracy: 0.8519 - val_loss: 1.3712 - val_accuracy: 0.8556
# Epoch 14/45
# 81/81 [==============================] - 55s 686ms/step - loss: 1.2298 - accuracy: 0.8524 - val_loss: 1.3712 - val_accuracy: 0.8576
# Epoch 15/45
# 81/81 [==============================] - 59s 733ms/step - loss: 1.2163 - accuracy: 0.8544 - val_loss: 1.3736 - val_accuracy: 0.8577
# Epoch 16/45
# 81/81 [==============================] - 57s 702ms/step - loss: 1.2027 - accuracy: 0.8554 - val_loss: 1.3747 - val_accuracy: 0.8579
# Epoch 17/45
# 81/81 [==============================] - 58s 715ms/step - loss: 1.1897 - accuracy: 0.8569 - val_loss: 1.3745 - val_accuracy: 0.8580
# Epoch 18/45
# 81/81 [==============================] - 58s 715ms/step - loss: 1.1771 - accuracy: 0.8574 - val_loss: 1.3747 - val_accuracy: 0.8585
# Epoch 19/45
# 81/81 [==============================] - 58s 720ms/step - loss: 1.1639 - accuracy: 0.8582 - val_loss: 1.3745 - val_accuracy: 0.8589
# Epoch 20/45
# 81/81 [==============================] - 59s 726ms/step - loss: 1.1501 - accuracy: 0.8592 - val_loss: 1.3739 - val_accuracy: 0.8594
# Epoch 21/45
# 81/81 [==============================] - 59s 723ms/step - loss: 1.1355 - accuracy: 0.8601 - val_loss: 1.3731 - val_accuracy: 0.8595
# Epoch 22/45
# 81/81 [==============================] - 58s 721ms/step - loss: 1.1191 - accuracy: 0.8609 - val_loss: 1.3724 - val_accuracy: 0.8599
# Epoch 23/45
# 81/81 [==============================] - 58s 721ms/step - loss: 1.1011 - accuracy: 0.8619 - val_loss: 1.3702 - val_accuracy: 0.8602
# Epoch 24/45
# 81/81 [==============================] - 59s 726ms/step - loss: 1.0814 - accuracy: 0.8632 - val_loss: 1.3678 - val_accuracy: 0.8611
# Epoch 25/45
# 81/81 [==============================] - 58s 720ms/step - loss: 1.0599 - accuracy: 0.8646 - val_loss: 1.3654 - val_accuracy: 0.8612
# Epoch 26/45
# 81/81 [==============================] - 58s 718ms/step - loss: 1.0364 - accuracy: 0.8662 - val_loss: 1.3613 - val_accuracy: 0.8614
# Epoch 27/45
# 81/81 [==============================] - 56s 691ms/step - loss: 1.0107 - accuracy: 0.8675 - val_loss: 1.3594 - val_accuracy: 0.8619
# Epoch 28/45
# 81/81 [==============================] - 58s 719ms/step - loss: 0.9824 - accuracy: 0.8692 - val_loss: 1.3554 - val_accuracy: 0.8625
# Epoch 29/45
# 81/81 [==============================] - 57s 705ms/step - loss: 0.9513 - accuracy: 0.8710 - val_loss: 1.3530 - val_accuracy: 0.8626
# Epoch 30/45
# 81/81 [==============================] - 58s 717ms/step - loss: 0.9178 - accuracy: 0.8727 - val_loss: 1.3510 - val_accuracy: 0.8648
# Epoch 31/45
# 81/81 [==============================] - 57s 706ms/step - loss: 0.8816 - accuracy: 0.8745 - val_loss: 1.3475 - val_accuracy: 0.8654
# Epoch 32/45
# 81/81 [==============================] - 56s 696ms/step - loss: 0.8423 - accuracy: 0.8773 - val_loss: 1.3450 - val_accuracy: 0.8657
# Epoch 33/45
# 81/81 [==============================] - 55s 675ms/step - loss: 0.7998 - accuracy: 0.8805 - val_loss: 1.3437 - val_accuracy: 0.8669
# Epoch 34/45
# 81/81 [==============================] - 59s 723ms/step - loss: 0.7525 - accuracy: 0.8842 - val_loss: 1.3418 - val_accuracy: 0.8674
# Epoch 35/45
# 81/81 [==============================] - 55s 674ms/step - loss: 0.7014 - accuracy: 0.8888 - val_loss: 1.3404 - val_accuracy: 0.8694
# Epoch 36/45
# 81/81 [==============================] - 55s 677ms/step - loss: 0.6472 - accuracy: 0.8948 - val_loss: 1.3382 - val_accuracy: 0.8699
# Epoch 37/45
# 81/81 [==============================] - 56s 697ms/step - loss: 0.5907 - accuracy: 0.9024 - val_loss: 1.3375 - val_accuracy: 0.8707
# Epoch 38/45
# 81/81 [==============================] - 54s 667ms/step - loss: 0.5328 - accuracy: 0.9127 - val_loss: 1.3335 - val_accuracy: 0.8713
# Epoch 39/45
# 81/81 [==============================] - 55s 678ms/step - loss: 0.4744 - accuracy: 0.9287 - val_loss: 1.3311 - val_accuracy: 0.8719
# Epoch 40/45
# 81/81 [==============================] - 56s 687ms/step - loss: 0.4162 - accuracy: 0.9471 - val_loss: 1.3281 - val_accuracy: 0.8730
# Epoch 41/45
# 81/81 [==============================] - 53s 650ms/step - loss: 0.3584 - accuracy: 0.9661 - val_loss: 1.3253 - val_accuracy: 0.8733
# Epoch 42/45
# 81/81 [==============================] - 55s 674ms/step - loss: 0.3024 - accuracy: 0.9798 - val_loss: 1.3227 - val_accuracy: 0.8741
# Epoch 43/45
# 81/81 [==============================] - 54s 665ms/step - loss: 0.2501 - accuracy: 0.9873 - val_loss: 1.3210 - val_accuracy: 0.8744
# Epoch 44/45
# 81/81 [==============================] - 53s 653ms/step - loss: 0.2026 - accuracy: 0.9914 - val_loss: 1.3189 - val_accuracy: 0.8745
# Epoch 45/45
# 81/81 [==============================] - 56s 689ms/step - loss: 0.1613 - accuracy: 0.9939 - val_loss: 1.3169 - val_accuracy: 0.8752

# %% [markdown]
# - Model's Accuracy on Training data is
# - Loss on Training data is

# %%
# Saving the model

model.save('LSTM-wordTranslator.h5')

# %% [markdown]
# ## Evaluating on Test Data

# %%
# # Loading the Model
from tensorflow.keras.models import load_model

model = load_model('LSTM-wordTranslator.h5')

# %% [markdown]
# ## Calculating Model's loss and Accuray on Testing data

# %%
# Load and tokenize the test data
input_texts_test, target_texts_test = load_data('NEWS2018_M-EnHi_dev.xml')
input_tensor_test, input_lang_tokenizer = tokenize(input_texts_test)
target_tensor_test, targ_lang_tokenizer = tokenize(target_texts_test)

# Get the number of unique words in the target language
tar_vocab_size = len(targ_lang_tokenizer.word_index) + 1

# Convert the target tensor to have the expected shape
final_layer_output_shape = model.layers[-1].output_shape
target_tensor_test = tf.keras.preprocessing.sequence.pad_sequences(target_tensor_test, maxlen=final_layer_output_shape[1], padding='post')
target_tensor_test = tf.keras.utils.to_categorical(target_tensor_test, num_classes=final_layer_output_shape[2])

# Pad the input tensor to have the expected shape
input_tensor_test = tf.keras.preprocessing.sequence.pad_sequences(input_tensor_test, maxlen=final_layer_output_shape[1], padding='post')

# Evaluate the model on the test data
test_loss, test_acc = model.evaluate(input_tensor_test, target_tensor_test)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
# Out:
# 32/32 [==============================] - 8s 98ms/step - loss: 1.7047 - accuracy: 0.8645
# Test loss: 1.7046736478805542
# Test accuracy: 0.8644999861717224

# %% [markdown]
# - Loss is 1.32
# - Models accuracy is

# %% [markdown]
# ## How the Test file looks

# %%
# Test file Input & Target
input_texts_decoded = []
for i in range(input_tensor_test.shape[0]):
    input_text = input_lang_tokenizer.sequences_to_texts([input_tensor_test[i]])
    input_texts_decoded.append(input_text[0])

# Decode the target tensor to see the target strings
target_texts_decoded = []
for i in range(target_tensor_test.shape[0]):
    target_text = targ_lang_tokenizer.sequences_to_texts([np.argmax(target_tensor_test[i], axis=1)])
    target_texts_decoded.append(target_text[0])

# Print the decoded input and target strings
for i in range(input_tensor_test.shape[0]):
    print("Input:", input_texts_decoded[i])
    print("Target",target_texts_decoded[i] )
# Out:
# Input: aachaaryanandana
# Target आचार्यनंदना
# Input: aachaarysut
# Target आचार्यसुत
# Input: aacharynandan
# Target आचार्यनंदन
# Input: aacharynandanaa
# Target आचार्यनंदना
# Input: aadamkhor
# Target आदमखोर
# Input: aag aur shola
# Target आग और शोला
# Input: aaj ki baat
# Target आज की बात
# Input: aaj ki taza khabar
# Target आज की ताज़ा खबर
# Input: aakanksha
# Target आकांक्षा
# Input: aan
# Target आन
# Input: aankhon dekhi
# Target आँखों देखी
# Input: aansoo ban gaye phool
# Target आँसू बन गए फ़ूल
# Input: aashaa
# Target आशा
# Input: aatank
# Target आतंक
# Input: ab kya hoga
# Target अब क्या होगा
# Input: abdul haakim
# Target अब्दुल हाकिम
# Input: abdul hannan
# Target अब्दुल हन्नान
# Input: abdul muhasin
# Target अब्दुल मुहासिन
# Input: abdul muiz
# Target अब्दुल मुईज़
# Input: abdul wakil
# Target अब्दुल वकील
# Input: aberdeen
# Target एबरडीन
# Input: abha
# Target आभा
# Input: abhiman
# Target अभिमान
# Input: abhinanda
# Target अभिनन्दा
# Input: abisso
# Target एबीसो
# Input: abu mansur daqiqi
# Target अबू मंसूर दक़ीक़ी
# Input: abul fazal
# Target अबुल फजल
# Input: acharysuta
# Target आचार्यसुता
# Input: achhnera junction
# Target अछनेरा जंक्शन
# Input: achindr
# Target अचिंद्र
# Input: adhip
# Target अधिप
# Input: aditya
# Target अदित्या
# Input: admiralty
# Target एडमिरैल्टी
# Input: afasaana
# Target अफसाना
# Input: afsana
# Target अफसाना
# Input: agar tum na hote
# Target अगर तुम न होते
# Input: aglaia
# Target एग्लेइया
# Input: agni chakra
# Target अग्नि चक्र
# Input: agrima
# Target अग्रिमा
# Input: akalmash
# Target अकल्मश
# Input: akarshan
# Target आकर्षण
# Input: akeel
# Target अकील
# Input: akhila
# Target अखिला
# Input: akila daily
# Target अकीला डेल्ही
# Input: akmal
# Target अकमाल
# Input: alan wells
# Target ऐलन वेल्स
# Input: alarice
# Target एलेराइस
# Input: alaska
# Target अलास्का
# Input: albertsons
# Target एल्बर्टसन्स
# Input: alboran
# Target अल्बोरान
# Input: alexavier
# Target अलेक्जेवियर
# Input: alima
# Target अलीमा
# Input: allegheny
# Target अल्लेगहेन्ये
# Input: allstate
# Target ऑलस्टेट
# Input: ally
# Target एली
# Input: aloysius
# Target अलोयसियस
# Input: aluabari road
# Target अलुयाबरी रोड
# Input: amalie
# Target एमेली
# Input: amaryllis
# Target एमेरीलिस
# Input: ambala
# Target अंबाला
# Input: ameeri
# Target अमीरी
# Input: american academy of arts and letters fiction award
# Target अमेरिकन अकेडमी ऑफ आर्ट्‍स एण्ड लेटर्स फिक्शन अवार्ड
# Input: amrapali
# Target आम्रपाली
# Input: amrit
# Target अमृत
# Input: anal
# Target अनल
# Input: andha intequam
# Target अंधा इंतेक़ाम
# Input: angelica
# Target एंजेलिका
# Input: anilatmaj
# Target अनिलात्मज
# Input: anirvaan
# Target अनिर्वाण
# Input: anisaa
# Target अनीसा
# Input: anjum
# Target अंजुम
# Input: annabella
# Target अन्नाबेला
# Input: annapurna
# Target अन्नपूर्णा
# Input: anthony stuart
# Target एंथनी स्टुआर्ट
# Input: anupshahr
# Target अनुपशहर
# Input: anusooyaa
# Target अनुसूया
# Input: anuvaa
# Target अनुवा
# Input: anwar
# Target अनवर
# Input: apna ghar
# Target अपना घर
# Input: apne dam par
# Target अपने दम पर
# Input: apollo tyres
# Target अपोलो टायर्स
# Input: ara
# Target आरा
# Input: arbon
# Target आर्बन
# Input: archon
# Target आर्कन
# Input: argheshwar
# Target अर्घेश्वर
# Input: arivalagan
# Target अरिवलगन
# Input: arnetha
# Target अर्नेठा
# Input: arnie
# Target एर्नी
# Input: artemas
# Target आर्टेमस
# Input: arya
# Target आर्य
# Input: asad
# Target असद
# Input: asahi india
# Target आसही इंडिया
# Input: asaoti
# Target असौती
# Input: ashantha de mel
# Target अशांथा डे मेल
# Input: ashivan
# Target अशिवन
# Input: asia
# Target आसिया
# Input: asif mohammad
# Target आसिफ मोहम्मद
# Input: aslana
# Target अस्लाना
# Input: atchafalaya
# Target अटचाफल्या
# Input: athar ali khan
# Target आथर अली खान
# Input: atharvan
# Target अथर्वन
# Input: attacker
# Target अटैकर
# Input: attur
# Target अट्‍टूर
# Input: aurum
# Target ऑरम
# Input: avani
# Target अवनि
# Input: avanindra
# Target अवनींद्र
# Input: azraqi
# Target अज़राकी
# Input: baap beti
# Target बाप बेटी
# Input: baaqir
# Target बाकिर
# Input: baat ek raat ke
# Target बात एक रात की
# Input: babel
# Target बाबेल
# Input: badar
# Target बदर
# Input: badreeprasaad
# Target बद्रीप्रसाद
# Input: badshahnagar
# Target बादशाहनगर
# Input: baghawat
# Target बगावत
# Input: bahuroop
# Target बहुरूप
# Input: bajwa
# Target बाजवा
# Input: balak dhruv
# Target बालक ध्रुव
# Input: balasor
# Target बालासोर
# Input: balil
# Target बलिल
# Input: balqees
# Target बल्कीस
# Input: banajit
# Target बनजित
# Input: banff
# Target बन्फ़
# Input: bangui
# Target बैंगई
# Input: banke lal
# Target बाँके लाल
# Input: bansi
# Target बंसी
# Input: bansilaal
# Target बंसीलाल
# Input: baragaon
# Target बरागांव
# Input: bardoli
# Target बरदोली
# Input: bareth
# Target बरेथ
# Input: barhan
# Target बरहान
# Input: basit ali
# Target बसित अली
# Input: batool
# Target बतूल
# Input: batra
# Target बत्रा
# Input: bayana junction
# Target बयाना जंक्शन
# Input: bearn
# Target बर्न
# Input: bees saal baad
# Target बीस साल बाद
# Input: behake kadam
# Target बहके कदम
# Input: bekhbar
# Target बेखबर
# Input: belgaum
# Target बेलगॉम
# Input: berchha
# Target बरचा
# Input: beti
# Target बेटी
# Input: bhaarateey
# Target भारतीय
# Input: bhachau
# Target भचउ
# Input: bhadkamkar
# Target भडकमकर
# Input: bhadrachalam
# Target भद्राचलम
# Input: bhagyawati
# Target भाग्यवती
# Input: bhai saheb
# Target भाई साहब
# Input: bhamini
# Target भामिनी
# Input: bhandardara
# Target भंडारदरा
# Input: bhanuprasad
# Target भानुप्रसाद
# Input: bhatpur
# Target भटपुर
# Input: bhedi lutera
# Target भेदी लुटेरा
# Input: bhel
# Target भेल
# Input: bheroolaal
# Target भेरूलाल
# Input: bhilainagar
# Target भिलाईनगर
# Input: bhildi
# Target भीलड़ी
# Input: bholi
# Target भोली
# Input: bhongir
# Target भोंगीर
# Input: bhootnath
# Target भूतनाथ
# Input: bhudhar
# Target भूधर
# Input: bhuranyu
# Target भूरण्यु
# Input: bichia
# Target बिछिया
# Input: bikram
# Target बिक्रम
# Input: bilhaur
# Target बिल्हौर
# Input: bisla
# Target बिस्ला
# Input: bismarck
# Target बिस्मार्क
# Input: bloomberg tower
# Target ब्लूमबर्ग टॉवर
# Input: blue dart
# Target ब्लू डार्ट
# Input: bombay masjid
# Target बॉम्बे मस्जिद
# Input: bombay war
# Target बॉम्बे वार
# Input: bongaigaon
# Target बॉन्गाईगांव
# Input: boot polish
# Target बूट पॉलिश
# Input: bozeman
# Target बॉजमेन
# Input: bracken
# Target ब्रेकन
# Input: brazosport
# Target ब्राझोस्पोर्ट
# Input: brendon bracewell
# Target ब्रेंडन ब्रेसवेल
# Input: british book awards
# Target ब्रिटिश बुक अवार्ड्‍स
# Input: brookes
# Target ब्रूक्स
# Input: bruce medal
# Target ब्रूस मेडल
# Input: budalur
# Target बुदालुर
# Input: bunny hop
# Target बनी हॉप
# Input: burnett
# Target बरनेट
# Input: burrows
# Target बॉरोज
# Input: bushra
# Target बुशरा
# Input: cadmium
# Target कैडमियम
# Input: caitir
# Target कैतिर
# Input: cala
# Target कैला
# Input: camila
# Target कैमिला
# Input: cape cod
# Target केप कॉड
# Input: cape maclear
# Target केप मैकलियर
# Input: caraf
# Target कैराफ
# Input: carr
# Target कार
# Input: carson
# Target कार्सन
# Input: caspian
# Target कास्पियन
# Input: cathy betts
# Target कॅथे बेट्स
# Input: catskill
# Target कैस्किल
# Input: centimes
# Target सेंटाइम्स
# Input: central michigan university
# Target सेंट्रल मिशिगन यूनिवर्सिटी
# Input: chaad
# Target चाड
# Input: chabbra
# Target छाबड़ा
# Input: chaha
# Target चाहा
# Input: chainwa
# Target चैनवा
# Input: chakrapani
# Target चक्रपाणि
# Input: chakravarty rajagopalachari
# Target चक्रवर्ती राजगोपालाचारी
# Input: chaksu
# Target चाकसू
# Input: chaminda vaas
# Target चमिंडा वास
# Input: chamomile
# Target कैमोमाइल
# Input: champaka ramanayake
# Target चंपका रामनायक
# Input: chandan ka palna
# Target चंदन का पालना
# Input: chandragupta
# Target चंद्रगुप्त
# Input: chaparmukh junction
# Target चपरमुख जंक्शन
# Input: chaphekar
# Target चाफेकर
# Input: charitha buddhika
# Target चरिथा बुद्धिका
# Input: charles darwin
# Target चार्ल्स डार्विन
# Input: charusheela
# Target चारुशीला
# Input: chester
# Target चेस्टर
# Input: chichagof
# Target चिचागॉफ़
# Input: chikmangloor
# Target चिकमंगलूर
# Input: china finance online
# Target चाइना फ़ाइनेंस ऑनलाइन
# Input: china grentech corporation limited
# Target चाइना ग्रेन्टेक कॉर्पोरेशन लिमिटेड
# Input: chinna
# Target चिन्ना
# Input: chinnar reservoir
# Target चिन्नार रिज़रवायर
# Input: chitahra
# Target चितहरा
# Input: chor chor
# Target चोर चोर
# Input: chordophone
# Target कॉरडोफोन
# Input: christy hefner
# Target क्रिस्टी हैन्फ़र
# Input: chubb
# Target शुब
# Input: clara
# Target क्लारा
# Input: clarence
# Target क्लारेंस
# Input: clayland
# Target क्लेलैंड
# Input: cleta
# Target क्लेटा
# Input: cobalt
# Target कोबाल्ट
# Input: coborne
# Target कॉबॉर्न
# Input: collis king
# Target कॉलिस किंग
# Input: colorado kettle river
# Target कोलोरैडो केटल रिवर
# Input: columbia
# Target कोलम्बिया
# Input: comfort
# Target कम्फर्ट
# Input: compton crook award
# Target कॉम्पटन क्रूक अवार्ड
# Input: cormac
# Target कॉर्मेक
# Input: cosco
# Target कॉस्को
# Input: craig evans
# Target क्रेग ईवंस
# Input: cranfield university
# Target क्रैनफील्ड यूनिवर्सिटी
# Input: credit susse
# Target क्रेडिट सुसे
# Input: cricket
# Target क्रिकेट
# Input: cricketer
# Target क्रिकेटर
# Input: cybille
# Target सायबिल
# Input: cyprus
# Target सायप्रस
# Input: dabolim
# Target दबोलिम
# Input: dainik janambhumi
# Target दैन‍िक जन्मभूमि
# Input: dak babu
# Target डाक बाबू
# Input: daku aur mahatma
# Target डाकू और महात्मा
# Input: daku hasina
# Target डाकू हसीना
# Input: daku rani himmatwali
# Target डाकू रानी हिम्मतवाली
# Input: dalauda
# Target दलौदा
# Input: daleville baptist
# Target डेलविले बैपटिस्ट
# Input: damaad
# Target दामाद
# Input: dang
# Target डंग
# Input: darban
# Target दरबान
# Input: darin
# Target डैरिन
# Input: darren gough
# Target डॉरेन गॉ
# Input: darren sammy
# Target डैरन सैम्मी
# Input: darrin murray
# Target डेरिन मुर्रे
# Input: darwaza
# Target दरवाज़ा
# Input: dasha
# Target डैश
# Input: david terbrugge
# Target डेविड टर्ब्रग
# Input: de zeven provincien
# Target डी ज़ेवेन प्रोविंसियन
# Input: deepabali
# Target दीपाबाली
# Input: deepamala
# Target दीपमाला
# Input: dekha jayega
# Target देखा जाएगा
# Input: delhi cantonment
# Target डेल्ही कैंनटॉनमेंट
# Input: delores
# Target डेलोरेस
# Input: demi moore
# Target डेमी मूर
# Input: derick
# Target डेरिक
# Input: des pardes
# Target देस परदेस
# Input: deswal
# Target देस्वाल
# Input: deswell
# Target डेस्वेल
# Input: deuel
# Target डूएल
# Input: deuskar
# Target देऊसकर
# Input: devinderpal
# Target देविंदरपाल
# Input: devnarayan
# Target देवनारायण
# Input: devprayag
# Target देवप्रयाग
# Input: devvrat
# Target देवव्रत
# Input: dhadvaiwale
# Target धडवईवाले
# Input: dham
# Target धाम
# Input: dhamkee
# Target धमकी
# Input: dharam kanta
# Target धरम काँटा
# Input: dharam veer
# Target धरम वीर
# Input: dharangaon
# Target धरनगांव
# Input: dhobi doctor
# Target धोबी डॉक्टर
# Input: dhriti
# Target धृति
# Input: dhumr
# Target धूम्र
# Input: dhumravarn
# Target धुम्रवर्ण
# Input: dierdra
# Target डिएर्ड्रा
# Input: diksha
# Target दीक्षा
# Input: dilawar
# Target दिलवर
# Input: dilber
# Target दिलबर
# Input: dimple
# Target डिंपल
# Input: dipa
# Target दीपा
# Input: dishman
# Target दिश्मन
# Input: do qaidi
# Target दो कैदी
# Input: dobbelaar
# Target डोबेलार
# Input: doiwala
# Target दोइवाला
# Input: dominion
# Target डोमिनियन
# Input: donagh
# Target दोनघ
# Input: doyen
# Target डोएन
# Input: dozakh
# Target दोज़ख
# Input: draxis health
# Target ड्रेक्सिस हेल्थ
# Input: dudhani
# Target दूधानी
# Input: dudhia khurd
# Target दूधिया खुर्द
# Input: duduk
# Target डुदुक
# Input: dundlod
# Target दुंदलोद
# Input: dushmani
# Target दुश्मनी
# Input: edakkad
# Target इदाक्क्ड़
# Input: eenadu
# Target इनाडू
# Input: eisner awards
# Target ईस्नर अवार्ड्‍स
# Input: ek jaan hai hum
# Target एक जान हैं हम
# Input: elburz
# Target एल्बुर्ज़
# Input: electra
# Target इलेक्ट्रा
# Input: elias
# Target इलियास
# Input: elizabeth doll
# Target एलिज़ाबेथ डोल
# Input: emerson
# Target इमर्सन
# Input: emir
# Target एमिर
# Input: endeavour
# Target एण्डीवर
# Input: eolande
# Target इओलैंड
# Input: ethelda
# Target एथेल्डा
# Input: evelia
# Target इवेलिया
# Input: exfo electro-optical engineering
# Target ईएक्सएफ़ओ इलेक्ट्रो-ऑप्टिकल इंजीनियरिंग
# Input: exports
# Target एक्सपोर्ट्स
# Input: fadi
# Target फैदी
# Input: faiq
# Target फै़क
# Input: faizullapur
# Target फैज़ुलापुर
# Input: fakeehah
# Target फकीहाह
# Input: family of god
# Target फ़ैमिली ऑफ गॉड
# Input: farlington redoubt
# Target फार्लिंगटन रीडाउट
# Input: faulad
# Target फौलाद
# Input: fedora
# Target फेडोरा
# Input: felis shelf
# Target फ़िलीस श्चेल्फी
# Input: ferdinand
# Target फर्डीनांड
# Input: ferok
# Target फेरोक
# Input: fifty fifty
# Target फिफ्टी फिफ्टी
# Input: finlandia prize for literature
# Target फिनलैंडिया प्राइज़ फॉर लिट्रेचर
# Input: fiorenza
# Target फियोरेंज़ा
# Input: flora
# Target फ्लोरा
# Input: forbesganj
# Target फोर्ब्सगंज
# Input: fort assiniboine
# Target फोर्ट एसीनिबोइन
# Input: fort benghisa
# Target फोर्ट बेंघिसा
# Input: fort bokar
# Target फोर्ट बोकर
# Input: fort clark
# Target फोर्ट क्लार्क
# Input: fort columbia
# Target फोर्ट कोलंबिया
# Input: fort dauphin
# Target फोर्ट डॉफिन
# Input: fort honswijk
# Target फोर्ट हॉन्सविज़्क
# Input: fort manoel
# Target फोर्ट मैनोएल
# Input: fort marlborough
# Target फोर्ट मार्लबोरॉ
# Input: fort smith
# Target फोर्ट स्मिथ
# Input: fort tregantle
# Target फोर्ट ट्रेगैन्टल
# Input: fort wayne
# Target फोर्ट वेन
# Input: furkating junction
# Target फर्कटिंग जंक्शन
# Input: fusaylah
# Target फज़ेलाह
# Input: gagroli
# Target गगरोली
# Input: gahmar
# Target गेहमर
# Input: gajadant
# Target गजदंत
# Input: gajanan
# Target गजानन
# Input: gamini perera
# Target जेमिनी परेरा
# Input: gandak
# Target गंडक
# Input: ganeshvar
# Target गणेश्वर
# Input: ganga
# Target गंगा
# Input: gareth
# Target गैरेथ
# Input: gareth hopkins
# Target गैरेथ हॉप्किंस
# Input: garnett kruger
# Target गर्नेट क्रुगर
# Input: gauloise
# Target गॉलोइस
# Input: gaureeshankar
# Target गौरीशंकर
# Input: gavotte
# Target गैवोट
# Input: geoff boycott
# Target जिऑफ बॉयकॉट
# Input: george bernard shaw
# Target जॉर्ज बर्नार्ड शॉ
# Input: george van biesbroeck prize
# Target जॉर्ज वैन बिसब्रोएक प्राइज़
# Input: georgianna
# Target जार्जियाना
# Input: german
# Target जर्मन
# Input: ghar dwar
# Target घर द्वार
# Input: ghaso
# Target घासो
# Input: ghatam
# Target घातम
# Input: ghauth
# Target गौथ
# Input: ghazi
# Target ग़ाज़ी
# Input: ghorpuri
# Target घोरपुरी
# Input: ghufayrah
# Target ग़ुफयराह
# Input: ginny
# Target जीनी
# Input: giriraaj
# Target गिरिराज
# Input: girna
# Target गिर्ना
# Input: gizi
# Target गिज़ी
# Input: goa
# Target गोवा
# Input: godel prize award
# Target गोडल प्राइज़ अवार्ड
# Input: gomantak times
# Target गोमंतक टाइम्स
# Input: gopika
# Target गोपिका
# Input: govind
# Target गोविन्द
# Input: govindgarh malk
# Target गोविंदगढ़ माल्क
# Input: graeme porter
# Target ग्रीम पोर्टर
# Input: graeme swann
# Target ग्रीम स्वान
# Input: greg matthews
# Target ग्रेग मैथ्यूज
# Input: gridco
# Target ग्रिडको
# Input: griffiths
# Target ग्रिफिथ्स
# Input: grimes
# Target ग्रिम्स
# Input: grinham
# Target ग्रिनहैम
# Input: grissom
# Target ग्रिसम
# Input: grizzly
# Target ग्रिज़ली
# Input: groupe pinault print
# Target ग्रुप पिनॉल्ट प्रिंट
# Input: guadalupe
# Target गुडालुपे
# Input: guajira
# Target गुआजिरा
# Input: guarani
# Target गुरानी
# Input: guddi
# Target गुड्डी
# Input: guldhar
# Target गुलधर
# Input: gundardehi
# Target गुणदरदेही
# Input: gurgaon
# Target गुड़गाँव
# Input: guru
# Target गुरु
# Input: guru dakshina
# Target गुरु दक्षिणा
# Input: guru granth sahib
# Target गुरू ग्रंथ साहिब
# Input: gurudwara khandur sahib
# Target गुरूद्वारा खंडूर साहिब
# Input: gurudwara likhansar
# Target गुरूद्वारा लिखणसार
# Input: gurudwara thanda burj
# Target गुरूद्वारा ठंडा बुर्ज
# Input: hafizur rahman
# Target हफिज़ुर रहमान
# Input: hailakandi
# Target हलाकांडी
# Input: hajrah
# Target हजराह
# Input: hamid
# Target हमीद
# Input: hamidieh
# Target हैमीडीह
# Input: hannah
# Target हन्नाह
# Input: hanumaan
# Target हनुमान
# Input: hartford
# Target हार्टफ़ोर्ड
# Input: harvard university
# Target हावर्ड यूनिवर्सिटी
# Input: harvy
# Target हार्वी
# Input: hashid
# Target हशीद
# Input: hats' russian war
# Target हैट्स रशियन वार
# Input: haupango
# Target हॉपैंगो
# Input: hawwa
# Target हव्वा
# Input: heer ranjha
# Target हीर रांझा
# Input: hemang badani
# Target हेमंग बदानी
# Input: hemchand
# Target हेमचंद
# Input: henly
# Target हेनली
# Input: hera
# Target हीरा
# Input: hermes
# Target हर्मीस
# Input: hersey
# Target हार्से
# Input: hewlett - packard
# Target ह्यूलेट-पैकर्ड
# Input: highlands
# Target हाईलैंड्स
# Input: himaalay
# Target हिमालय
# Input: hindustan lever
# Target हिंदुस्तान लीवर
# Input: hisar
# Target हिसार
# Input: hoche
# Target हॉक
# Input: hollis
# Target हॉलिस
# Input: hollywood walk of fame
# Target हॉलीवुड वॉक ऑफ फेम
# Input: house of prayer lutheran
# Target हाउस ऑफ प्रेअर लुथेरान
# Input: hubayshah
# Target हुबायशाह
# Input: hum sub ustad hain
# Target हम सब उस्ताद हैं
# Input: huma
# Target हुमा
# Input: humayun
# Target हुमायूँ
# Input: huzayl
# Target हुज़ायल
# Input: ian redpath
# Target इआन रेडपाथ
# Input: idemitsu kosan
# Target आइडेमित्सु कोसान
# Input: ikhlas
# Target इखलास
# Input: iki
# Target इकी
# Input: iliamna
# Target लियाम्ना
# Input: incredimail
# Target इंक्रेडिमेल
# Input: indapurkar
# Target इंदापुरकर
# Input: inderdeep
# Target इन्दरदीप
# Input: induja
# Target इन्दुजा
# Input: indukala
# Target इन्दुकला
# Input: infotech enter
# Target इंफ़ोटेक एन्टर
# Input: iran ki ek raat
# Target ईरान की एक रात
# Input: itihaas
# Target इतिहास
# Input: izz
# Target इज़्ज़
# Input: jack heron
# Target जैक हेरन
# Input: jacqui
# Target जैकी
# Input: jagannath puri
# Target जगन्नाथ पुरी
# Input: jagdamba
# Target जगदंबा
# Input: jahdamah
# Target जहदमाह
# Input: jai
# Target जय
# Input: jainism
# Target जैनिज़्म
# Input: jaiprakash narayan
# Target जयप्रकाश नारायण
# Input: james laughlin award
# Target जेम्स लॉफलिन अवार्ड
# Input: janak
# Target जनक
# Input: janet rino
# Target जेनेट रीनो
# Input: javed miandad
# Target जावेद मियंदाद
# Input: jay vijay
# Target जय विजय
# Input: jayasekera
# Target जयसेकरा
# Input: jeanne
# Target जीनी
# Input: jeevan naiya
# Target जीवन नैया
# Input: jeevan prabhat
# Target जीवन प्रभात
# Input: jeevan rekha
# Target जीवन रेखा
# Input: jeff wilson
# Target जेफ विल्सन
# Input: jemma
# Target जेमा
# Input: jibran
# Target जिब्रान
# Input: jimmy hendricks
# Target जिमी हैंड्रिक्स
# Input: jimuta
# Target जिमुता
# Input: jinelle
# Target जिनेल
# Input: jivitesh
# Target जिवितेश
# Input: jocasta
# Target जोकस्ता
# Input: jogi
# Target जोगी
# Input: jograj
# Target जोगराज
# Input: john f. kennedy
# Target जॉन एफ. केनेडी
# Input: john penn
# Target जॉन पेन
# Input: jon kent
# Target जॉन केंट
# Input: josie
# Target जोसि
# Input: judaism
# Target जूदाइज़्म
# Input: jungle king
# Target जंगल किंग
# Input: justice choudhary
# Target जस्टिस चौधरी
# Input: jwalamukhi
# Target ज्वालामुखी
# Input: kaamanaa
# Target कामना
# Input: kaaran
# Target कारण
# Input: kachchi kali
# Target कच्ची कली
# Input: kacia
# Target केसिया
# Input: kailaash
# Target कैलाश
# Input: kaise kahoon
# Target कैसे कहूँ
# Input: kalea
# Target कैलिया
# Input: kamal
# Target कमल
# Input: kamesh
# Target कामेश
# Input: kamyab
# Target कामयाब
# Input: kanakpriya
# Target कनकप्रिया
# Input: kanchan aur ganga
# Target कंचन और गंगा
# Input: kanwal
# Target कंवल
# Input: karin
# Target कैरिन
# Input: kartik
# Target कार्तिक
# Input: kasia
# Target कैसिया
# Input: katak
# Target कटक
# Input: kattora
# Target कत्तौरा
# Input: katy
# Target कैटी
# Input: kaumudhi
# Target कौमुदी
# Input: kaustav
# Target कौस्तव
# Input: keene
# Target कीन
# Input: kennan
# Target केनन
# Input: keshihan
# Target केशिहन
# Input: kevin duers
# Target केविन डुअर्स
# Input: khahera
# Target खहेरा
# Input: kharqa
# Target ख़ार्का
# Input: khatoon
# Target खातून
# Input: khattda
# Target खट्टड़ा
# Input: khel kismat ka
# Target खेल किस्मत का
# Input: khoj
# Target खोज
# Input: khuddar
# Target खुद्दार
# Input: khufia mahal
# Target खुफिया महल
# Input: khuraymah
# Target खुरायमाह
# Input: khwaja mir dard
# Target ख्वाजा मीर दर्द
# Input: khwaja nizamuddin chishti
# Target ख्वाजा निज़ामुद्दीन चिस्ती
# Input: kintan
# Target किंतन
# Input: kiranmay
# Target किरण्मय
# Input: kiril
# Target किरिल
# Input: klamath
# Target क्लामथ
# Input: konark surya
# Target कोणार्क सूर्य
# Input: koning der nederlanden
# Target कॉनिंग दर नीदरलैंडन
# Input: kori
# Target कोरी
# Input: kristy
# Target क्रिस्टी
# Input: kufra
# Target कुफ़्रा
# Input: kumari
# Target कुमारी
# Input: kunte
# Target कुंटे
# Input: kuntee
# Target कुंती
# Input: kush
# Target कुश
# Input: kusumaadhiraaj
# Target कुसुमाधिराज
# Input: kyushu
# Target क्यूशू
# Input: laalamani
# Target लालमणि
# Input: lagu
# Target लागू
# Input: lahore fort
# Target लाहौर फोर्ट
# Input: lakshmishree
# Target लक्ष्मीश्री
# Input: lal kunwar
# Target लाल कुँवर
# Input: lal patthar
# Target लाल पत्थर
# Input: lalaatikaa
# Target ललाटिका
# Input: lalan
# Target ललन
# Input: lance klusener
# Target लैन्स क्लूजनर
# Input: landler
# Target लैंडर
# Input: larissa
# Target लैरीसा
# Input: latona
# Target लैटोना
# Input: lawaate
# Target लवाटे
# Input: lawrence school
# Target लॉरेंस स्कूल
# Input: layyah
# Target लय्याह
# Input: leatrix
# Target लीट्रिक्स
# Input: lebanon
# Target लेबनॉन
# Input: leelaaraam
# Target लीलाराम
# Input: lemhi
# Target लेम्ही
# Input: liberace
# Target लिब्रेस
# Input: light house
# Target लाइट हाउस
# Input: lilianna
# Target लिलियाना
# Input: linaeve
# Target लिनाएव
# Input: lincoln university
# Target लिंकन यूनिवर्सिटी
# Input: lion
# Target लायन
# Input: liverpool community
# Target लिवरपूल कम्युनिटी
# Input: lokmat
# Target लोकमत
# Input: los marmoles
# Target लॉस मार्मोल्स
# Input: lothringen
# Target लॉथरिंगन
# Input: love in simla
# Target लव इन शिमला
# Input: lucia
# Target ल्यूसी
# Input: luciano
# Target ल्युसिआनो
# Input: lucky number
# Target लकी नंबर
# Input: luktuke
# Target लुकतुके
# Input: maadhavee
# Target माधवी
# Input: macronix international
# Target मैक्रॉनिक्स इंटरनेशनल
# Input: madan manjari
# Target मदन मंजरी
# Input: madhu
# Target मधु
# Input: madivan
# Target मादिवन
# Input: mafizur rahman
# Target मफिज़र रहमान
# Input: maghavaajit
# Target मघवाजित
# Input: mahaashvetaa
# Target महाश्वेता
# Input: mahaavat
# Target महावत
# Input: mahabali hanuman
# Target महाबली हनुमान
# Input: mahasweta
# Target महाश्वेता
# Input: mahijuba
# Target महिजुबा
# Input: mahira
# Target महिरा
# Input: mahish
# Target महिश
# Input: mahotsaah
# Target महोत्साह
# Input: mainaa
# Target मैना
# Input: makayla
# Target मकायला
# Input: malayala manorama
# Target मालायला मनोरमा
# Input: malpasset dam
# Target मैल्पसेट डैम
# Input: mangatraam
# Target मंगतराम
# Input: manimuthar reservoir
# Target मणिमुथर रिज़रवायर
# Input: maniram
# Target मणिराम
# Input: manish
# Target मनीष
# Input: manmatha
# Target मन्मथ
# Input: manuhaar
# Target मनुहार
# Input: manzar
# Target मंज़र
# Input: mar mitenge
# Target मर मिटेंगे
# Input: marasi
# Target मरासी
# Input: mardav
# Target मार्दव
# Input: maricopa
# Target मेरीकोपा
# Input: marigaon
# Target मारीगाँव
# Input: marigold
# Target मैरीगोल्ड
# Input: marissa
# Target मैरिसा
# Input: martin suji
# Target मार्टिन सूजी
# Input: masada
# Target मसाडा
# Input: mastani
# Target मस्तानी
# Input: mateenadaas
# Target मतीनदास
# Input: maurilio
# Target मौरिलिओ
# Input: mawsil
# Target मावसिल
# Input: maxima
# Target मक्सिमा
# Input: mazda motor
# Target माज़दा मोटर
# Input: mednipur
# Target मेदनीपुर
# Input: meera shyam
# Target मीरा श्याम
# Input: meet one greet one
# Target मीट वन ग्रीट वन
# Input: mehmaan
# Target मेहमान
# Input: mehrunissa
# Target मेहरुन्निसा
# Input: melodeon
# Target मैलोडियन
# Input: mengkuang dam
# Target मेंगक्वांग डैम
# Input: mera muqadar
# Target मेरा मुक़द्दर
# Input: mera suhag
# Target मेरा सुहाग
# Input: meri asha
# Target मेरी आशा
# Input: meru betiri
# Target मेरु बेतिरी
# Input: messeturm
# Target मेसेटर्म
# Input: mevan pieris
# Target मेवन पाइरिस
# Input: mian mir
# Target मिलन मीर
# Input: michael bevan
# Target माइकल बेवन
# Input: mike atherton
# Target माइक एथर्टन
# Input: minjonet
# Target मिंजोनेट
# Input: modern youth
# Target मॉडर्न यूथ
# Input: monitor
# Target मॉनीटर
# Input: monrovia
# Target मोनरोविया
# Input: mookambika
# Target मूकांबिका
# Input: morag
# Target मोरग
# Input: mount abu
# Target माउंट आबू
# Input: mradul
# Target मृदुल
# Input: mudit
# Target मुदित
# Input: mudra
# Target मुद्रा
# Input: muhriz
# Target मुहरिज़
# Input: mujaddid
# Target मुजद्दिद
# Input: mukadam
# Target मुकादम
# Input: mukhataar
# Target मुखतार
# Input: mukulit
# Target मुकुलित
# Input: mukunda
# Target मुकुन्द
# Input: mukut
# Target मुकुट
# Input: municipal gallery of rhodes
# Target म्युन‍िस‍िपल गैलरी ऑफ रोड्स
# Input: munsif daily
# Target मुंसिफ डेल्ही
# Input: muqaddar
# Target मुकद्दर
# Input: muqtasid
# Target मुक़्तसिद
# Input: murari
# Target मुरारी
# Input: murti
# Target मूर्ति
# Input: mushtaq ahmed
# Target मुश्ताक अहमद
# Input: mustafeed
# Target मुस्तफीद
# Input: naatak
# Target नाटक
# Input: nabhan
# Target नभन
# Input: nahanni
# Target ना‍हान्नी
# Input: nai
# Target नाइ
# Input: naimish
# Target नैमिश
# Input: nairit
# Target नैरित
# Input: najiyah
# Target नाजिया
# Input: nanda devi
# Target नंदा देवी
# Input: nasa medal for exceptional scientific achievement
# Target नासा मेडल फॉर एक्सेप्शनल साइंटीफिक अचीवमेंट
# Input: nashwa
# Target नश्वा
# Input: nathan bracken
# Target नाथन ब्रेकन
# Input: national medal of science
# Target नेशनल मेडल ऑफ साइंस
# Input: naved ashraf
# Target नावेद अशरफ
# Input: naved latif
# Target नावेद लतीफ
# Input: naya rasta
# Target नय रास्ता
# Input: nazar ka shikar
# Target नज़र का शिकार
# Input: neelabja
# Target नीलाब्जा
# Input: neelmani
# Target नीलमणि
# Input: neemuch
# Target नीमच
# Input: neodymium
# Target नीयोडिमियम
# Input: newbery honor
# Target न्यूबेरी हॉनर
# Input: niamur rashid
# Target नियामुर रशीद
# Input: nice-systems limited
# Target नाइस-सिस्टम्स लिमिटेड
# Input: nicholas pirama
# Target निकोलस पिरामल
# Input: nikunja
# Target निकुंजा
# Input: nilagriv
# Target नीलाग्रीव
# Input: nilima
# Target नीलिमा
# Input: ninad
# Target निनाद
# Input: niraj
# Target नीरज
# Input: nityagopal
# Target नित्यगोपाल
# Input: nityanand
# Target नित्यानन्द
# Input: nityasundar
# Target नित्यसुन्दर
# Input: noleta
# Target नोलेटा
# Input: noopur
# Target नूपुर
# Input: noor jahan
# Target नूर जहाँ
# Input: noorie
# Target नूरी
# Input: noorjehan
# Target नूरजहाँ
# Input: nordland
# Target नॉरलैंड
# Input: oklahoma city
# Target ओक्लाहोमा सिटी
# Input: oliver cromwell
# Target ऑलीवर क्रॉमवेल
# Input: omar khaiyyam
# Target ओमर खैय्यम
# Input: ophira
# Target ओफिरा
# Input: orbotech
# Target ऑर्बोटेक
# Input: orchid chemical
# Target ऑर्किड केमिकल्स
# Input: order of the crown
# Target ऑडर ऑफ द क्राउन
# Input: origins award
# Target ऑरिजिन्स अवार्ड
# Input: orthofix
# Target ऑर्थोफ़िक्स
# Input: osman
# Target उस्मान
# Input: ova
# Target ओवा
# Input: pallab
# Target पल्लब
# Input: panama city
# Target पनामा सिटी
# Input: panchayat
# Target पंचायत
# Input: pandhari
# Target पंढरी
# Input: pannagesh
# Target पन्नागेश
# Input: parichay
# Target परिचय
# Input: paris orly
# Target पेरिस ऑरले
# Input: parivartan
# Target परिवर्तन
# Input: parma missionary baptist
# Target पार्मा मिशनरी बैपटिस्ट
# Input: pashupati
# Target पशुपति
# Input: patterson thompson
# Target पैटर्सन थॉमप्सन
# Input: peace
# Target पीस
# Input: pechiparai
# Target पेचीपराई
# Input: peder skram
# Target पेडर स्क्रेम
# Input: pendse
# Target पेंडसे
# Input: penganga
# Target पेनगंगा
# Input: pensioner
# Target पेंशनर
# Input: petrobrás
# Target पेट्रोब्रस
# Input: phadatare
# Target फडतरे
# Input: phagun
# Target फागुन
# Input: phil carlson
# Target फिल कार्लसन
# Input: phil defreitas
# Target फिल डेफ्रेटास
# Input: phil simmons
# Target फिल सिमंस
# Input: philadelphia
# Target फिलाडेल्फ़िया
# Input: phyliss
# Target फिलिस
# Input: physiology
# Target फिजियोलॉजी
# Input: pink
# Target पिंक
# Input: polly
# Target पोली
# Input: poojit
# Target पूजित
# Input: poonam ki raat
# Target पूनम की रात
# Input: powerful
# Target पावरफुल
# Input: prajaapat
# Target प्रजापत
# Input: prarthana
# Target प्रार्थना
# Input: prasannjit
# Target प्रसन्नजित
# Input: pratima
# Target प्रतिमा
# Input: praveen
# Target प्रवीण
# Input: pretorius
# Target प्रिटॉरियस
# Input: pro football hall of fame
# Target प्रो फुटबॉल हॉल ऑफ फेम
# Input: procter
# Target प्रॉक्टर
# Input: prometheus
# Target प्रोमिथेउस
# Input: pryor
# Target प्रयॉर
# Input: punarnava
# Target पुनर्नवा
# Input: pushparaaj
# Target पुष्पराज
# Input: pyar ka toofan
# Target प्यार का तूफान
# Input: pyas
# Target प्यास
# Input: qaidi
# Target कैदी
# Input: raagini
# Target रागिनी
# Input: raajamuni
# Target राजमुनि
# Input: raasavihaaree
# Target रासविहारी
# Input: raghavendra
# Target राघवेंद्र
# Input: raichur
# Target रायचूर
# Input: rain calcining
# Target रेन कैल्सिंइंग
# Input: raj nartaki
# Target राज नर्तकी
# Input: raje
# Target राजे
# Input: rajeshwar
# Target राजेश्वर
# Input: ram avtar
# Target राम अवतार
# Input: rambaan
# Target रामबाण
# Input: rambha
# Target रम्भा
# Input: ramuwalia
# Target रामूवालिया
# Input: ranajay
# Target रणजय
# Input: rance
# Target रैंस
# Input: randheer
# Target रणधीर
# Input: rasaal
# Target रसाल
# Input: rasheed
# Target रशीद
# Input: rasikaa
# Target रसिका
# Input: reporter raju
# Target रिपोर्टर राजू
# Input: reykjavik
# Target रिकज़विक
# Input: richmond
# Target रिचमंड
# Input: rick
# Target रिक
# Input: robin uthappa
# Target रॉबिन उथाप्पा
# Input: rochelle
# Target रोशेल
# Input: roden
# Target रोडन
# Input: roland butcher
# Target रॉलेंड बुचर
# Input: romantic india
# Target रोमांटिक इंडिया
# Input: romesh kaluwitharana
# Target रोमेश कालुविथराणा
# Input: roseanne
# Target रोज़ीन
# Input: roshanee
# Target रोशनी
# Input: rudy
# Target रुडी
# Input: rupaiya
# Target रुपैया
# Input: russell krovi
# Target रसेल क्रोवी
# Input: saadat
# Target सादात
# Input: sach
# Target सच
# Input: sachche ka bolbala
# Target सच्चे का बोलबाला
# Input: sachin tendulkar
# Target सचिन तेंडुलकर
# Input: sadiqah
# Target सदीकाह
# Input: saheb
# Target साहब
# Input: sailaab
# Target सैलाब
# Input: sailesh
# Target सैलेश
# Input: saint helens fort
# Target सेंट हेलेन्स फोर्ट
# Input: sainte marie
# Target सेंट मेरी
# Input: saipratap
# Target साईप्रताप
# Input: sajan
# Target सजन
# Input: sajeewa de silva
# Target सजीवा डे सिल्वा
# Input: sajni
# Target सजनी
# Input: salil ankola
# Target सलिल अंकोला
# Input: samaj patan
# Target समाज पतन
# Input: sambad
# Target संबद
# Input: sambaran
# Target समबरन
# Input: samrendru
# Target समरेंदु
# Input: san martino
# Target सैन मार्टिनो
# Input: san paolo imi
# Target सन पेओलो मी
# Input: sanghera
# Target संघेरा
# Input: sant ravidas ki amar kahani
# Target संत रविदास की अमर कहानी
# Input: santos
# Target सेंटोज़
# Input: sarayu
# Target सरयू
# Input: sareen
# Target सरीन
# Input: sariska
# Target सरिस्का
# Input: saskatchewan
# Target सैस्कैचवान
# Input: sati anjani
# Target सती अंजनी
# Input: sati nagkanaya
# Target सती नागकन्या
# Input: satnam overseas
# Target सतनाम ओवरसीस
# Input: satyaki
# Target सत्याकि
# Input: sau saal baad
# Target सौ साल बाद
# Input: saunders
# Target सॉन्डर्स
# Input: scotia sea
# Target स्कॉटिया सी
# Input: seemaant
# Target सीमांत
# Input: sekere
# Target सेकरे
# Input: seliya
# Target सेलिया
# Input: senegal
# Target सेनेगल
# Input: seringapatam
# Target सेरिंगापटम
# Input: sevaaraam
# Target सेवाराम
# Input: shaitan
# Target शैतान
# Input: shake hands
# Target शेक हैंड्‍स
# Input: shampa
# Target शम्पा
# Input: shamsheer e arab
# Target शमशीर ए अरब
# Input: shan
# Target शान
# Input: shanghai museum
# Target शंघाई म्युज़ियम
# Input: shanpaak
# Target शंपाक
# Input: sharadini
# Target शारदिनी
# Input: sharon stone
# Target शेरॉन स्टोन
# Input: shatrughn
# Target शत्रुघ्न
# Input: shery
# Target शेरी
# Input: shimane maru
# Target शिमेन मारू
# Input: shoaib akhtar
# Target शोएब खान
# Input: shoeb
# Target शोएब
# Input: shotput
# Target शॉटपुट
# Input: shreshth
# Target श्रेष्ठ
# Input: shridevi
# Target श्रीदेवी
# Input: shridhar
# Target श्रीधर
# Input: shripad
# Target श्रीपद
# Input: shu'a
# Target शुआ
# Input: shubhang
# Target शुभांग
# Input: shungare
# Target शुंगारे
# Input: shurayh
# Target शुरायह
# Input: shyaamaa
# Target श्यामा
# Input: sihlsee
# Target सिहल्सी
# Input: silvain
# Target सिल्वैन
# Input: silver standard resources
# Target सिल्वर स्टैंडर्ड रिसोर्सेज़
# Input: simon katich
# Target साइमन कैटिच
# Input: sipahiya
# Target सिपहिया
# Input: siraalee
# Target सिराली
# Input: siran
# Target सिरन
# Input: siusan
# Target सिउसन
# Input: skipper
# Target स्किपर
# Input: slowman
# Target स्लोमेन
# Input: sneha
# Target स्नेहा
# Input: snigdhaa
# Target स्निग्धा
# Input: sohani
# Target सोहनी
# Input: sohni
# Target सोहनी
# Input: solferino
# Target सोल्फेरिनो
# Input: som
# Target सोम
# Input: somakaantaa
# Target सोमकांता
# Input: southern iron
# Target साउदर्न आयरन
# Input: sowani
# Target सोवानी
# Input: sparsh
# Target स्पर्श
# Input: spathareion museum of the shadow theatre
# Target स्पाथेर‍ियन म्युज़ियम ऑफ द शैडो थ‍िएटर
# Input: stats chippac
# Target स्टेट्सचिपपैक
# Input: steve martin
# Target स्टीव मार्टिन
# Input: stevens
# Target स्टीवन्स
# Input: stolt-nielsen
# Target स्टॉल्ट निलसन
# Input: stride arcolab
# Target स्ट्राइड आर्कोलैब
# Input: subhaashachandr
# Target सुभाषचंद्र
# Input: suchi
# Target सुचि
# Input: sudarshan
# Target सुदर्शन
# Input: suhrewardi
# Target सुहरेवर्दी
# Input: sujaya
# Target सुजया
# Input: sukhija
# Target सुखीजा
# Input: sulaiman
# Target सुलेमान
# Input: sultanah
# Target सुल्तानाह
# Input: summerside united methodist
# Target समरसाइड यूनाइटेड मेथोडिस्ट
# Input: sun microsystems
# Target सन माइक्रोसिस्टम
# Input: sunopta
# Target सनऑप्टा
# Input: surgery
# Target सर्जरी
# Input: susan sarandon
# Target सुज़ेन सेरेन्डॉन
# Input: suwo
# Target सूवो
# Input: swan
# Target स्वान
# Input: syed akhtar imam quadri
# Target सय्यद अख्तर इमाम क़ादरी
# Input: syndicate bank
# Target सिंडीकेट बैंक
# Input: talakkad
# Target तलक्कड
# Input: talika
# Target तालिका
# Input: tanuj
# Target तनुज
# Input: tanwir
# Target तनवीर
# Input: target
# Target टारगेट
# Input: tariqah
# Target तारि़काह
# Input: tarulata
# Target तरुलता
# Input: taryn
# Target टैरिन
# Input: tata tea
# Target टाटा टी
# Input: tazwell
# Target टैज़वेल
# Input: tejaa
# Target तेजा
# Input: tejaswini
# Target तेजस्विनी
# Input: tel aviv
# Target तेल अविव
# Input: tera karam mera dharam
# Target तेरा करम मेरा धरम
# Input: thames valley university
# Target थेम्स वैली यूनिवर्सिटी
# Input: thar
# Target थार
# Input: the times of india
# Target द टाइम्स ऑफ इंडिया
# Input: thuringen
# Target थरिंगन
# Input: thyra
# Target थायरा
# Input: tilak
# Target तिलक
# Input: timin
# Target तिमिन
# Input: tirap
# Target तिरप
# Input: toiyabe
# Target तोईयाबे
# Input: tony
# Target टोनी
# Input: toofan
# Target तूफान
# Input: torie
# Target टोरी
# Input: tress
# Target ट्रेसी
# Input: trevelian
# Target ट्रेवेलियन
# Input: trinity biotech
# Target ट्रिनिटी बायोटेक
# Input: truda
# Target ट्रूडा
# Input: truly
# Target ट्रूली
# Input: trump world tower
# Target ट्रम्प वर्ल्ड टॉवर
# Input: tube investment
# Target ट्यूब इन्वेस्टमेंट
# Input: tungabhadra
# Target तुंगभद्रा
# Input: two prudential plaza
# Target टू प्रुडेन्शियल प्लाज़ा
# Input: ubeja
# Target उबेजा
# Input: umapati
# Target उमापति
# Input: ummayyah
# Target उम्मय्याह
# Input: university of alaska
# Target यूनिवर्सिटी ऑफ अलास्का
# Input: university of dundee
# Target यूनिवर्सिटी ऑफ डंडी
# Input: university of hull
# Target यूनिवर्सिटी ऑफ हल
# Input: university of keele
# Target यूनिवर्सिटी ऑफ कीले
# Input: university of sunderland
# Target यूनिवर्सिटी ऑफ सुंदरलैंड
# Input: urania
# Target यूरेनिया
# Input: ursala
# Target उर्सला
# Input: uttar kannada
# Target उत्तर कन्नड़
# Input: vajra
# Target वज्र
# Input: valentino
# Target वैलेंटिनो
# Input: valli
# Target वल्ली
# Input: van
# Target वन
# Input: vanoise
# Target वैनॉइस
# Input: vardha
# Target वर्धा
# Input: velaa
# Target वेला
# Input: venkatesh
# Target वेंकटेश
# Input: venkateshvar
# Target वेंकटेश्वर
# Input: veolia environnement
# Target वेओलिया एनवायरमेंट
# Input: vidya vardhaka sangha high school, bangalore
# Target विद्या वर्धक संघ हाई स्कूल, बैंगलोर
# Input: vidyut
# Target विद्युत
# Input: vijaynagar
# Target विजयनगर
# Input: vimohinee
# Target विमोहिनी
# Input: viplaav
# Target विप्लाव
# Input: viresh
# Target विरेश
# Input: vishalgad
# Target विशालगढ़
# Input: vishram
# Target विश्राम
# Input: visisht seva medal
# Target विशिष्ट सेवा मेडल
# Input: vittorio emanuele
# Target विक्टोरियो इमानुएल
# Input: vrandaavaneshvaree
# Target वृंदावनेश्वरी
# Input: vytis
# Target वायटिस
# Input: wachhar
# Target वच्चर
# Input: waite
# Target वैट
# Input: walker museum
# Target वॉकर म्युज़ियम
# Input: walkley award
# Target वॉक्ले अवार्ड
# Input: walt disney
# Target वॉल्ट डिज़्नी
# Input: warner
# Target वार्नर
# Input: washington
# Target वॉशिंगटन
# Input: watan ke rakhwale
# Target वतन के रखवाले
# Input: wazeera
# Target वज़ीरा
# Input: weddell
# Target वेडेल
# Input: willa
# Target विलार्ड
# Input: wockhardt
# Target वॉकहार्ड
# Input: woodward
# Target वुडवर्ड
# Input: yaqeen
# Target य़कीन
# Input: yaqub
# Target य़ाकुब
# Input: yar
# Target यार
# Input: yasir arafat
# Target यासिर अराफत
# Input: yehiam fort
# Target येहैम फोर्ट
# Input: yograj
# Target योगराज
# Input: yukon
# Target यूकॉन
# Input: yuvraj singh
# Target युवराज सिंह
# Input: zahoor elahi
# Target ज़हूर इलाही
# Input: zaleel
# Target ज़लील
# Input: zayb
# Target ज़ैब
# Input: zorion
# Target ज़ोरियन

# %% [markdown]
# ## Model's prediction output on Test data
# ### Decoding the input_tensor_test & target_tensor_test to see the output generated by the Model

# %%
# Inverse map the index to the word using the tokenizer
input_word_index = input_lang_tokenizer.word_index
input_index_word = dict([(index, word) for word, index in input_word_index.items()])

target_word_index = targ_lang_tokenizer.word_index
target_index_word = dict([(index, word) for word, index in target_word_index.items()])

# Get the predictions for the test data
predictions = model.predict(input_tensor_test)

# Function to convert the index to the word
def index_to_word(index):
  return target_index_word.get(index, '')

# Function to convert the prediction to the text
def prediction_to_text(prediction):
  text = ''
  for i in range(prediction.shape[0]):
    index = np.argmax(prediction[i])
    word = index_to_word(index)
    if word == 'endseq':
      return text
    text += word + ' '
  return text

# Get the predicted texts for the test data
predicted_texts = []
for i in range(predictions.shape[0]):
  prediction = predictions[i, :, :]
  text = prediction_to_text(prediction)
  predicted_texts.append(text)

# Print the input text, target text, and predicted text for 10 samples
for i in range(len(input_texts_test)):
  print("Input Text:", input_texts_test[i])
  #print("Target Text:", target_texts_test[i])
  print("Predicted Text:", predicted_texts[i])
  print()
# Out:
# 32/32 [==============================] - 5s 54ms/step
# Input Text: aachaaryanandana
# Predicted Text: मेरी
#
# Input Text: aachaarysut
# Predicted Text: सिटी
#
# Input Text: aacharynandan
# Predicted Text: तूफान
#
# Input Text: aacharynandanaa
# Predicted Text: फिफ्टी
#
# Input Text: aadamkhor
# Predicted Text: सेंट
#
# Input Text: aag aur shola
# Predicted Text: सन और शोएब
#
# Input Text: aaj ki baat
# Predicted Text: मेरा अवार्ड आशा
#
# Input Text: aaj ki taza khabar
# Predicted Text: मेरा अवार्ड आचार्यसुत
#
# Input Text: aakanksha
# Predicted Text: चोर
#
# Input Text: aan
# Predicted Text: एबीसो
#
# Input Text: aankhon dekhi
# Predicted Text: प्रो ताज़ा
#
# Input Text: aansoo ban gaye phool
# Predicted Text:   खबर
#
# Input Text: aashaa
# Predicted Text: स्वान
#
# Input Text: aatank
# Predicted Text: आन
#
# Input Text: ab kya hoga
# Predicted Text: आँखों देखी आँसू
#
# Input Text: abdul haakim
# Predicted Text: अब्दुल बन
#
# Input Text: abdul hannan
# Predicted Text: अब्दुल घासो
#
# Input Text: abdul muhasin
# Predicted Text: अब्दुल एण्ड
#
# Input Text: abdul muiz
# Predicted Text: अब्दुल पर
#
# Input Text: abdul wakil
# Predicted Text: अब्दुल बर्न
#
# Input Text: aberdeen
# Predicted Text: आतंक
#
# Input Text: abha
# Predicted Text: आकांक्षा
#
# Input Text: abhiman
# Predicted Text: होगा
#
# Input Text: abhinanda
# Predicted Text: मुईज़
#
# Input Text: abisso
# Predicted Text: एबरडीन
#
# Input Text: abu mansur daqiqi
# Predicted Text: डे अबू दक़ीक़ी
#
# Input Text: abul fazal
# Predicted Text: फ़ूल अग्नि
#
# Input Text: acharysuta
# Predicted Text: नावेद
#
# Input Text: achhnera junction
# Predicted Text: बलिल जंक्शन
#
# Input Text: achindr
# Predicted Text: क्या
#
# Input Text: adhip
# Predicted Text: हाकिम
#
# Input Text: aditya
# Predicted Text:
#
# Input Text: admiralty
# Predicted Text: वकील
#
# Input Text: afasaana
# Predicted Text: अधिप
#
# Input Text: afsana
# Predicted Text: अभिमान
#
# Input Text: agar tum na hote
# Predicted Text: अगर तुम लुटेरा
#
# Input Text: aglaia
# Predicted Text:
#
# Input Text: agni chakra
# Predicted Text: मोहम्मद होते
#
# Input Text: agrima
# Predicted Text: अबुल
#
# Input Text: akalmash
# Predicted Text: अमेरिकन
#
# Input Text: akarshan
# Predicted Text: एग्लेइया
#
# Input Text: akeel
# Predicted Text: फजल
#
# Input Text: akhila
# Predicted Text: ऑफ
#
# Input Text: akila daily
# Predicted Text:  घर
#
# Input Text: akmal
# Predicted Text: अकीला
#
# Input Text: alan wells
# Predicted Text: दुश्मनी लेटर्स
#
# Input Text: alarice
# Predicted Text:
#
# Input Text: alaska
# Predicted Text:
#
# Input Text: albertsons
# Predicted Text: अनुसूया
#
# Input Text: alboran
# Predicted Text: सोहनी
#
# Input Text: alexavier
# Predicted Text: अपने
#
# Input Text: alima
# Predicted Text: अल्बोरान
#
# Input Text: allegheny
# Predicted Text: अलीमा
#
# Input Text: allstate
# Predicted Text: एडमिरैल्टी
#
# Input Text: ally
# Predicted Text: अल्लेगहेन्ये
#
# Input Text: aloysius
# Predicted Text: वन
#
# Input Text: aluabari road
# Predicted Text: एली भद्राचलम
#
# Input Text: amalie
# Predicted Text:
#
# Input Text: amaryllis
# Predicted Text: रोड
#
# Input Text: ambala
# Predicted Text: अभिनन्दा
#
# Input Text: ameeri
# Predicted Text:
#
# Input Text: american academy of arts and letters fiction award
# Predicted Text: अमीरी आसिफ ऑफ  अस्लाना   की
#
# Input Text: amrapali
# Predicted Text: फिक्शन
#
# Input Text: amrit
# Predicted Text: आम्रपाली
#
# Input Text: anal
# Predicted Text: अवनींद्र
#
# Input Text: andha intequam
# Predicted Text: अमृत इंतेक़ाम
#
# Input Text: angelica
# Predicted Text: एंजेलिका
#
# Input Text: anilatmaj
# Predicted Text: बालासोर
#
# Input Text: anirvaan
# Predicted Text: बलिल
#
# Input Text: anisaa
# Predicted Text: अनिलात्मज
#
# Input Text: anjum
# Predicted Text: अनिर्वाण
#
# Input Text: annabella
# Predicted Text: कॉड
#
# Input Text: annapurna
# Predicted Text: फ़ूल
#
# Input Text: anthony stuart
# Predicted Text: अंजुम धूम्र
#
# Input Text: anupshahr
# Predicted Text: अन्नाबेला
#
# Input Text: anusooyaa
# Predicted Text: अन्नाबेला
#
# Input Text: anuvaa
# Predicted Text: मर
#
# Input Text: anwar
# Predicted Text: एंथनी
#
# Input Text: apna ghar
# Predicted Text: बसित अलास्का
#
# Input Text: apne dam par
# Predicted Text:  डेल्ही अनवर
#
# Input Text: apollo tyres
# Predicted Text: पर भामिनी
#
# Input Text: ara
# Predicted Text:
#
# Input Text: arbon
# Predicted Text: एग्लेइया
#
# Input Text: archon
# Predicted Text: आरा
#
# Input Text: argheshwar
# Predicted Text: मुईज़
#
# Input Text: arivalagan
# Predicted Text: आर्कन
#
# Input Text: arnetha
# Predicted Text: अर्नेठा
#
# Input Text: arnie
# Predicted Text: भचउ
#
# Input Text: artemas
# Predicted Text: ब्रिटिश
#
# Input Text: arya
# Predicted Text: अलोयसियस
#
# Input Text: asad
# Predicted Text: अलुयाबरी
#
# Input Text: asahi india
# Predicted Text: आर्टेमस इंडिया
#
# Input Text: asaoti
# Predicted Text: गए
#
# Input Text: ashantha de mel
# Predicted Text: डोबेलार एक आसही
#
# Input Text: ashivan
# Predicted Text:
#
# Input Text: asia
# Predicted Text: अशांथा
#
# Input Text: asif mohammad
# Predicted Text: मेल
#
# Input Text: aslana
# Predicted Text: अकेडमी
#
# Input Text: atchafalaya
# Predicted Text: लियाम्ना
#
# Input Text: athar ali khan
# Predicted Text: आसिया द
#
# Input Text: atharvan
# Predicted Text: ब्लूमबर्ग
#
# Input Text: attacker
# Predicted Text: अटचाफल्या
#
# Input Text: attur
# Predicted Text:
#
# Input Text: aurum
# Predicted Text: अटैकर
#
# Input Text: avani
# Predicted Text: बॉन्गाईगांव
#
# Input Text: avanindra
# Predicted Text:
#
# Input Text: azraqi
# Predicted Text: अज़राकी
#
# Input Text: baap beti
# Predicted Text: बाप अली
#
# Input Text: baaqir
# Predicted Text: बुक
#
# Input Text: baat ek raat ke
# Predicted Text: आशा रात  फिल
#
# Input Text: babel
# Predicted Text: बादशाहनगर
#
# Input Text: badar
# Predicted Text:
#
# Input Text: badreeprasaad
# Predicted Text: बगावत
#
# Input Text: badshahnagar
# Predicted Text: बाजवा
#
# Input Text: baghawat
# Predicted Text: बालक
#
# Input Text: bahuroop
# Predicted Text: यूनिवर्सिटी
#
# Input Text: bajwa
# Predicted Text: अकमाल
#
# Input Text: balak dhruv
# Predicted Text: बेट्स बयाना
#
# Input Text: balasor
# Predicted Text:
#
# Input Text: balil
# Predicted Text: मारीगाँव
#
# Input Text: balqees
# Predicted Text: बंसी
#
# Input Text: banajit
# Predicted Text:
#
# Input Text: banff
# Predicted Text:
#
# Input Text: bangui
# Predicted Text: अछनेरा
#
# Input Text: banke lal
# Predicted Text: दम धरम
#
# Input Text: bansi
# Predicted Text: जेमा
#
# Input Text: bansilaal
# Predicted Text:
#
# Input Text: baragaon
# Predicted Text: प्रिंट
#
# Input Text: bardoli
# Predicted Text: यूनिवर्सिटी
#
# Input Text: bareth
# Predicted Text: बरचा
#
# Input Text: barhan
# Predicted Text: एल्बर्टसन्स
#
# Input Text: basit ali
# Predicted Text: भोली द
#
# Input Text: batool
# Predicted Text:
#
# Input Text: batra
# Predicted Text: आदमखोर
#
# Input Text: bayana junction
# Predicted Text: भाई जंक्शन
#
# Input Text: bearn
# Predicted Text:
#
# Input Text: bees saal baad
# Predicted Text: भामिनी  बेटी
#
# Input Text: behake kadam
# Predicted Text: भंडारदरा कैला
#
# Input Text: bekhbar
# Predicted Text: भटपुर
#
# Input Text: belgaum
# Predicted Text: असौती
#
# Input Text: berchha
# Predicted Text: भेल
#
# Input Text: beti
# Predicted Text: अली
#
# Input Text: bhaarateey
# Predicted Text: लुथेरान
#
# Input Text: bhachau
# Predicted Text: अशिवन
#
# Input Text: bhadkamkar
# Predicted Text: भोंगीर
#
# Input Text: bhadrachalam
# Predicted Text: सिरन
#
# Input Text: bhagyawati
# Predicted Text: भूधर
#
# Input Text: bhai saheb
# Predicted Text:  बाद
#
# Input Text: bhamini
# Predicted Text: बिक्रम
#
# Input Text: bhandardara
# Predicted Text: बिल्हौर
#
# Input Text: bhanuprasad
# Predicted Text: ब्लू
#
# Input Text: bhatpur
# Predicted Text: सैम्मी
#
# Input Text: bhedi lutera
# Predicted Text: मस्जिद अथर्वन
#
# Input Text: bhel
# Predicted Text: मियंदाद
#
# Input Text: bheroolaal
# Predicted Text: सजीवा
#
# Input Text: bhilainagar
# Predicted Text: फोर्ट
#
# Input Text: bhildi
# Predicted Text: बूट
#
# Input Text: bholi
# Predicted Text: पॉलिश
#
# Input Text: bhongir
# Predicted Text: ऑरम
#
# Input Text: bhootnath
# Predicted Text: अवनि
#
# Input Text: bhudhar
# Predicted Text: बॉजमेन
#
# Input Text: bhuranyu
# Predicted Text:
#
# Input Text: bichia
# Predicted Text: ब्रेंडन
#
# Input Text: bikram
# Predicted Text:
#
# Input Text: bilhaur
# Predicted Text:
#
# Input Text: bisla
# Predicted Text:
#
# Input Text: bismarck
# Predicted Text: बाकिर
#
# Input Text: bloomberg tower
# Predicted Text: बाबेल वन
#
# Input Text: blue dart
# Predicted Text: बदर ब्रूक्स
#
# Input Text: bombay masjid
# Predicted Text: टॉवर
#
# Input Text: bombay war
# Predicted Text: टॉवर ब्रेकन
#
# Input Text: bongaigaon
# Predicted Text: ब्रूस
#
# Input Text: boot polish
# Predicted Text: बुदालुर अंधा
#
# Input Text: bozeman
# Predicted Text:
#
# Input Text: bracken
# Predicted Text: वार
#
# Input Text: brazosport
# Predicted Text:
#
# Input Text: brendon bracewell
# Predicted Text: क्रिस्टी क्रिस्टी
#
# Input Text: british book awards
# Predicted Text:  अट्‍टूर चाइना
#
# Input Text: brookes
# Predicted Text: कैडमियम
#
# Input Text: bruce medal
# Predicted Text: बल्कीस मेडल
#
# Input Text: budalur
# Predicted Text: कैला
#
# Input Text: bunny hop
# Predicted Text:
#
# Input Text: burnett
# Predicted Text: बगावत
#
# Input Text: burrows
# Predicted Text: कार्सन
#
# Input Text: bushra
# Predicted Text: कास्पियन
#
# Input Text: cadmium
# Predicted Text: विजय
#
# Input Text: caitir
# Predicted Text: कैस्किल
#
# Input Text: cala
# Predicted Text: मैक्रॉनिक्स
#
# Input Text: camila
# Predicted Text: सेंटाइम्स
#
# Input Text: cape cod
# Predicted Text:  अंधा
#
# Input Text: cape maclear
# Predicted Text:
#
# Input Text: caraf
# Predicted Text: एथेल्डा
#
# Input Text: carr
# Predicted Text: चाहा
#
# Input Text: carson
# Predicted Text: चक्रपाणि
#
# Input Text: caspian
# Predicted Text:
#
# Input Text: cathy betts
# Predicted Text: चमिंडा सोहनी
#
# Input Text: catskill
# Predicted Text: फेरोक
#
# Input Text: centimes
# Predicted Text:
#
# Input Text: central michigan university
# Predicted Text:  मेरीकोपा यूनिवर्सिटी
#
# Input Text: chaad
# Predicted Text:
#
# Input Text: chabbra
# Predicted Text:
#
# Input Text: chaha
# Predicted Text: अवार्ड
#
# Input Text: chainwa
# Predicted Text:
#
# Input Text: chakrapani
# Predicted Text:
#
# Input Text: chakravarty rajagopalachari
# Predicted Text: चंद्रगुप्त
#
# Input Text: chaksu
# Predicted Text: अचिंद्र
#
# Input Text: chaminda vaas
# Predicted Text: बुद्धिका डार्विन
#
# Input Text: chamomile
# Predicted Text: चारुशीला
#
# Input Text: champaka ramanayake
# Predicted Text: बहके
#
# Input Text: chandan ka palna
# Predicted Text:  का ब्रिटिश
#
# Input Text: chandragupta
# Predicted Text:
#
# Input Text: chaparmukh junction
# Predicted Text:  जंक्शन
#
# Input Text: chaphekar
# Predicted Text: ग्रिडको
#
# Input Text: charitha buddhika
# Predicted Text: डे गुरु
#
# Input Text: charles darwin
# Predicted Text:  एडमिरैल्टी
#
# Input Text: charusheela
# Predicted Text: यूनिवर्सिटी
#
# Input Text: chester
# Predicted Text: खान
#
# Input Text: chichagof
# Predicted Text: रिवर
#
# Input Text: chikmangloor
# Predicted Text: कोलम्बिया
#
# Input Text: china finance online
# Predicted Text: अवार्ड्‍स आशा आभा
#
# Input Text: china grentech corporation limited
# Predicted Text: अवार्ड्‍स कॉम्पटन  बॉम्बे
#
# Input Text: chinna
# Predicted Text: क्रूक
#
# Input Text: chinnar reservoir
# Predicted Text: कहानी लिमिटेड
#
# Input Text: chitahra
# Predicted Text: कॉस्को
#
# Input Text: chor chor
# Predicted Text: रिज़रवायर रिज़रवायर
#
# Input Text: chordophone
# Predicted Text: क्रेग
#
# Input Text: christy hefner
# Predicted Text: ईवंस क्रेडिट
#
# Input Text: chubb
# Predicted Text: हार्से
#
# Input Text: clara
# Predicted Text: हाईलैंड्स
#
# Input Text: clarence
# Predicted Text: दैन‍िक
#
# Input Text: clayland
# Predicted Text: हॉक
#
# Input Text: cleta
# Predicted Text: महात्मा
#
# Input Text: cobalt
# Predicted Text: अवार्ड
#
# Input Text: coborne
# Predicted Text:
#
# Input Text: collis king
# Predicted Text: रानी किंग
#
# Input Text: colorado kettle river
# Predicted Text: हिम्मतवाली बगावत सेंटाइम्स
#
# Input Text: columbia
# Predicted Text: बैपटिस्ट
#
# Input Text: comfort
# Predicted Text: दरबान
#
# Input Text: compton crook award
# Predicted Text:   की
#
# Input Text: cormac
# Predicted Text: डैरिन
#
# Input Text: cosco
# Predicted Text: गॉ
#
# Input Text: craig evans
# Predicted Text: बिस्ला
#
# Input Text: cranfield university
# Predicted Text: डैरन यूनिवर्सिटी
#
# Input Text: credit susse
# Predicted Text:  रात
#
# Input Text: cricket
# Predicted Text: मुर्रे
#
# Input Text: cricketer
# Predicted Text:
#
# Input Text: cybille
# Predicted Text: रसाल
#
# Input Text: cyprus
# Predicted Text: नारायण
#
# Input Text: dabolim
# Predicted Text: सेंट्रल
#
# Input Text: dainik janambhumi
# Predicted Text: डेविड
#
# Input Text: dak babu
# Predicted Text: डी का
#
# Input Text: daku aur mahatma
# Predicted Text: डाकू और
#
# Input Text: daku hasina
# Predicted Text: डाकू बूट
#
# Input Text: daku rani himmatwali
# Predicted Text: डाकू अज़राकी दीपमाला
#
# Input Text: dalauda
# Predicted Text: देखा
#
# Input Text: daleville baptist
# Predicted Text:
#
# Input Text: damaad
# Predicted Text: कैंनटॉनमेंट
#
# Input Text: dang
# Predicted Text: डेलोरेस
#
# Input Text: darban
# Predicted Text: ख़ार्का
#
# Input Text: darin
# Predicted Text: डेमी
#
# Input Text: darren gough
# Predicted Text: हैं
#
# Input Text: darren sammy
# Predicted Text: हैं वॉल्ट
#
# Input Text: darrin murray
# Predicted Text:  जोसि
#
# Input Text: darwaza
# Predicted Text: जंगल
#
# Input Text: dasha
# Predicted Text: परदेस
#
# Input Text: david terbrugge
# Predicted Text: देस्वाल डेस्वेल
#
# Input Text: de zeven provincien
# Predicted Text: एक एक देविंदरपाल
#
# Input Text: deepabali
# Predicted Text:
#
# Input Text: deepamala
# Predicted Text: देवप्रयाग
#
# Input Text: dekha jayega
# Predicted Text: कत्तौरा धाम
#
# Input Text: delhi cantonment
# Predicted Text:  गंगा
#
# Input Text: delores
# Predicted Text: काँटा
#
# Input Text: demi moore
# Predicted Text: भारतीय अचिंद्र
#
# Input Text: derick
# Predicted Text: केविन
#
# Input Text: des pardes
# Predicted Text: वीर धरनगांव
#
# Input Text: deswal
# Predicted Text: धोबी
#
# Input Text: deswell
# Predicted Text: अन्नाबेला
#
# Input Text: deuel
# Predicted Text: धुम्रवर्ण
#
# Input Text: deuskar
# Predicted Text:
#
# Input Text: devinderpal
# Predicted Text: बॉरोज
#
# Input Text: devnarayan
# Predicted Text: डिएर्ड्रा
#
# Input Text: devprayag
# Predicted Text: डेल्ही
#
# Input Text: devvrat
# Predicted Text: लक्ष्मीश्री
#
# Input Text: dhadvaiwale
# Predicted Text: दिलवर
#
# Input Text: dham
# Predicted Text: ध्रुव
#
# Input Text: dhamkee
# Predicted Text: बुशरा
#
# Input Text: dharam kanta
# Predicted Text: प्राइज़
#
# Input Text: dharam veer
# Predicted Text: प्राइज़
#
# Input Text: dharangaon
# Predicted Text: दो
#
# Input Text: dhobi doctor
# Predicted Text: दोइवाला फिल
#
# Input Text: dhriti
# Predicted Text: दोनघ
#
# Input Text: dhumr
# Predicted Text: ड्रेक्सिस
#
# Input Text: dhumravarn
# Predicted Text: लिब्रेस
#
# Input Text: dierdra
# Predicted Text: बनजित
#
# Input Text: diksha
# Predicted Text: खुर्द
#
# Input Text: dilawar
# Predicted Text: लिनाएव
#
# Input Text: dilber
# Predicted Text:
#
# Input Text: dimple
# Predicted Text: कैराफ
#
# Input Text: dipa
# Predicted Text:
#
# Input Text: dishman
# Predicted Text: अनीसा
#
# Input Text: do qaidi
# Predicted Text: ईस्नर ऑफ
#
# Input Text: dobbelaar
# Predicted Text: जान
#
# Input Text: doiwala
# Predicted Text: एल्बुर्ज़
#
# Input Text: dominion
# Predicted Text: बर्न
#
# Input Text: donagh
# Predicted Text: एलिज़ाबेथ
#
# Input Text: doyen
# Predicted Text: डोल
#
# Input Text: dozakh
# Predicted Text:
#
# Input Text: draxis health
# Predicted Text: एण्डीवर
#
# Input Text: dudhani
# Predicted Text: इवेलिया
#
# Input Text: dudhia khurd
# Predicted Text:  इंजीनियरिंग
#
# Input Text: duduk
# Predicted Text:
#
# Input Text: dundlod
# Predicted Text:
#
# Input Text: dushmani
# Predicted Text: राजगोपालाचारी
#
# Input Text: edakkad
# Predicted Text: फैदी
#
# Input Text: eenadu
# Predicted Text: फैज़ुलापुर
#
# Input Text: eisner awards
# Predicted Text:  चाइना
#
# Input Text: ek jaan hai hum
# Predicted Text: रात एबरडीन डे
#
# Input Text: elburz
# Predicted Text:
#
# Input Text: electra
# Predicted Text: फेडोरा
#
# Input Text: elias
# Predicted Text: बरागांव
#
# Input Text: elizabeth doll
# Predicted Text: फ़िलीस बाबू
#
# Input Text: emerson
# Predicted Text: फिनलैंडिया
#
# Input Text: emir
# Predicted Text: वार
#
# Input Text: endeavour
# Predicted Text: कैमोमाइल
#
# Input Text: eolande
# Predicted Text: फियोरेंज़ा
#
# Input Text: ethelda
# Predicted Text:
#
# Input Text: evelia
# Predicted Text:
#
# Input Text: exfo electro-optical engineering
# Predicted Text: मुक़्तसिद
#
# Input Text: exports
# Predicted Text:
#
# Input Text: fadi
# Predicted Text: लकी
#
# Input Text: faiq
# Predicted Text:
#
# Input Text: faizullapur
# Predicted Text:
#
# Input Text: fakeehah
# Predicted Text:
#
# Input Text: family of god
# Predicted Text: गजानन ऑफ परेरा
#
# Input Text: farlington redoubt
# Predicted Text: गंडक
#
# Input Text: faulad
# Predicted Text:
#
# Input Text: fedora
# Predicted Text: हॉप्किंस
#
# Input Text: felis shelf
# Predicted Text: क्रुगर पर
#
# Input Text: ferdinand
# Predicted Text: बॉयकॉट
#
# Input Text: ferok
# Predicted Text: बिसब्रोएक
#
# Input Text: fifty fifty
# Predicted Text: फॉर फॉर
#
# Input Text: finlandia prize for literature
# Predicted Text:  अभिनन्दा मुहासिन
#
# Input Text: fiorenza
# Predicted Text: द्वार
#
# Input Text: flora
# Predicted Text:
#
# Input Text: forbesganj
# Predicted Text: अदित्या
#
# Input Text: fort assiniboine
# Predicted Text: फोर्ट कदम
#
# Input Text: fort benghisa
# Predicted Text: फोर्ट दीक्षा
#
# Input Text: fort bokar
# Predicted Text: फोर्ट
#
# Input Text: fort clark
# Predicted Text: फोर्ट कोरी
#
# Input Text: fort columbia
# Predicted Text: फोर्ट फोर्ट
#
# Input Text: fort dauphin
# Predicted Text: फोर्ट फोर्ट
#
# Input Text: fort honswijk
# Predicted Text: फोर्ट ग्रेग
#
# Input Text: fort manoel
# Predicted Text: फोर्ट चोर
#
# Input Text: fort marlborough
# Predicted Text: फोर्ट ब्रेसवेल
#
# Input Text: fort smith
# Predicted Text: फोर्ट
#
# Input Text: fort tregantle
# Predicted Text: फोर्ट डिएर्ड्रा
#
# Input Text: fort wayne
# Predicted Text: फोर्ट
#
# Input Text: furkating junction
# Predicted Text: ग्रुप जंक्शन
#
# Input Text: fusaylah
# Predicted Text: पिनॉल्ट
#
# Input Text: gagroli
# Predicted Text: पेडर
#
# Input Text: gahmar
# Predicted Text: गुडालुपे
#
# Input Text: gajadant
# Predicted Text: बेखबर
#
# Input Text: gajanan
# Predicted Text: क्लेटा
#
# Input Text: gamini perera
# Predicted Text: पूजित
#
# Input Text: gandak
# Predicted Text:
#
# Input Text: ganeshvar
# Predicted Text:
#
# Input Text: ganga
# Predicted Text: जॉर्ज
#
# Input Text: gareth
# Predicted Text: आदमखोर
#
# Input Text: gareth hopkins
# Predicted Text: आदमखोर लेटर्स
#
# Input Text: garnett kruger
# Predicted Text: प्यास द
#
# Input Text: gauloise
# Predicted Text:
#
# Input Text: gaureeshankar
# Predicted Text: राघवेंद्र
#
# Input Text: gavotte
# Predicted Text: बुर्ज
#
# Input Text: geoff boycott
# Predicted Text:
#
# Input Text: george bernard shaw
# Predicted Text: फेम  हमीद
#
# Input Text: george van biesbroeck prize
# Predicted Text: फेम जीनी  अफसाना
#
# Input Text: georgianna
# Predicted Text: अर्घेश्वर
#
# Input Text: german
# Predicted Text: हन्नाह
#
# Input Text: ghar dwar
# Predicted Text: अलास्का हार्टफ़ोर्ड
#
# Input Text: ghaso
# Predicted Text: हावर्ड
#
# Input Text: ghatam
# Predicted Text: हार्वी
#
# Input Text: ghauth
# Predicted Text: हशीद
#
# Input Text: ghazi
# Predicted Text: अवार्ड
#
# Input Text: ghorpuri
# Predicted Text: सदीकाह
#
# Input Text: ghufayrah
# Predicted Text: सैलेश
#
# Input Text: ginny
# Predicted Text: पतन
#
# Input Text: giriraaj
# Predicted Text:
#
# Input Text: girna
# Predicted Text: सलिल
#
# Input Text: gizi
# Predicted Text: रांझा
#
# Input Text: goa
# Predicted Text:
#
# Input Text: godel prize award
# Predicted Text: स्वान अफसाना की
#
# Input Text: gomantak times
# Predicted Text:  मीर
#
# Input Text: gopika
# Predicted Text: असद
#
# Input Text: govind
# Predicted Text: गर्नेट
#
# Input Text: govindgarh malk
# Predicted Text: सीमांत बुक
#
# Input Text: graeme porter
# Predicted Text: टाइम्स कामयाब
#
# Input Text: graeme swann
# Predicted Text: टाइम्स सायबिल
#
# Input Text: greg matthews
# Predicted Text: हिंदुस्तान क्रिकेट
#
# Input Text: gridco
# Predicted Text:
#
# Input Text: griffiths
# Predicted Text: शत्रुघ्न
#
# Input Text: grimes
# Predicted Text: हॉलिस
#
# Input Text: grinham
# Predicted Text:
#
# Input Text: grissom
# Predicted Text: मेरीकोपा
#
# Input Text: grizzly
# Predicted Text: हसीना
#
# Input Text: groupe pinault print
# Predicted Text:  दिश्मन
#
# Input Text: guadalupe
# Predicted Text: चितहरा
#
# Input Text: guajira
# Predicted Text: इआन
#
# Input Text: guarani
# Predicted Text:
#
# Input Text: guddi
# Predicted Text:
#
# Input Text: guldhar
# Predicted Text:
#
# Input Text: gundardehi
# Predicted Text: ट्रेवेलियन
#
# Input Text: gurgaon
# Predicted Text: इकी
#
# Input Text: guru
# Predicted Text: गुरूद्वारा
#
# Input Text: guru dakshina
# Predicted Text: गुरूद्वारा
#
# Input Text: guru granth sahib
# Predicted Text: गुरूद्वारा  ग्रीम
#
# Input Text: gurudwara khandur sahib
# Predicted Text: जीवन सैस्कैचवान ग्रीम
#
# Input Text: gurudwara likhansar
# Predicted Text: जीवन एमेरीलिस
#
# Input Text: gurudwara thanda burj
# Predicted Text: जीवन चार्ल्स कैदी
#
# Input Text: hafizur rahman
# Predicted Text: इन्दुजा रशीद
#
# Input Text: hailakandi
# Predicted Text: इन्दुकला
#
# Input Text: hajrah
# Predicted Text:
#
# Input Text: hamid
# Predicted Text: एन्टर
#
# Input Text: hamidieh
# Predicted Text: ईरान
#
# Input Text: hannah
# Predicted Text: इतिहास
#
# Input Text: hanumaan
# Predicted Text: थायरा
#
# Input Text: hartford
# Predicted Text: हेरन
#
# Input Text: harvard university
# Predicted Text:  यूनिवर्सिटी
#
# Input Text: harvy
# Predicted Text: जगन्नाथ
#
# Input Text: hashid
# Predicted Text: जगदंबा
#
# Input Text: hats' russian war
# Predicted Text:  की ब्रेकन
#
# Input Text: haupango
# Predicted Text:
#
# Input Text: hawwa
# Predicted Text:
#
# Input Text: heer ranjha
# Predicted Text: जेम्स जनक
#
# Input Text: hemang badani
# Predicted Text: तेजा
#
# Input Text: hemchand
# Predicted Text: रीनो
#
# Input Text: henly
# Predicted Text:
#
# Input Text: hera
# Predicted Text: प्रभात
#
# Input Text: hermes
# Predicted Text: रेखा
#
# Input Text: hersey
# Predicted Text: जेफ
#
# Input Text: hewlett - packard
# Predicted Text: बायोटेक धुम्रवर्ण कैमिला
#
# Input Text: highlands
# Predicted Text: हैंड्रिक्स
#
# Input Text: himaalay
# Predicted Text:
#
# Input Text: hindustan lever
# Predicted Text: जिनेल डेमी
#
# Input Text: hisar
# Predicted Text: हाई
#
# Input Text: hoche
# Predicted Text: जिवितेश
#
# Input Text: hollis
# Predicted Text: वॉकर
#
# Input Text: hollywood walk of fame
# Predicted Text: जोकस्ता जस्टिस ऑफ गुरु
#
# Input Text: house of prayer lutheran
# Predicted Text: फिफ्टी ऑफ  भेरूलाल
#
# Input Text: hubayshah
# Predicted Text: यार
#
# Input Text: hum sub ustad hain
# Predicted Text: साहिब गोविन्द
#
# Input Text: huma
# Predicted Text: चौधरी
#
# Input Text: humayun
# Predicted Text: थायरा
#
# Input Text: huzayl
# Predicted Text: कच्ची
#
# Input Text: ian redpath
# Predicted Text: डूएल डॉरेन
#
# Input Text: idemitsu kosan
# Predicted Text: धरम
#
# Input Text: ikhlas
# Predicted Text: कॉर्मेक
#
# Input Text: iki
# Predicted Text:
#
# Input Text: iliamna
# Predicted Text:
#
# Input Text: incredimail
# Predicted Text:
#
# Input Text: indapurkar
# Predicted Text: कनकप्रिया
#
# Input Text: inderdeep
# Predicted Text:
#
# Input Text: induja
# Predicted Text: देवव्रत
#
# Input Text: indukala
# Predicted Text: कैरिन
#
# Input Text: infotech enter
# Predicted Text:
#
# Input Text: iran ki ek raat
# Predicted Text: कार्तिक अवार्ड रात
#
# Input Text: itihaas
# Predicted Text: कैसिया
#
# Input Text: izz
# Predicted Text:
#
# Input Text: jack heron
# Predicted Text:  गए
#
# Input Text: jacqui
# Predicted Text: कौस्तव
#
# Input Text: jagannath puri
# Predicted Text:
#
# Input Text: jagdamba
# Predicted Text: देवनारायण
#
# Input Text: jahdamah
# Predicted Text: खहेरा
#
# Input Text: jai
# Predicted Text:
#
# Input Text: jainism
# Predicted Text: खातून
#
# Input Text: jaiprakash narayan
# Predicted Text: डेल्ही किस्मत
#
# Input Text: james laughlin award
# Predicted Text:   की
#
# Input Text: janak
# Predicted Text: खोज
#
# Input Text: janet rino
# Predicted Text: खुफिया
#
# Input Text: javed miandad
# Predicted Text:  महल
#
# Input Text: jay vijay
# Predicted Text:  निज़ामुद्दीन
#
# Input Text: jayasekera
# Predicted Text: किंतन
#
# Input Text: jeanne
# Predicted Text: मेडल
#
# Input Text: jeevan naiya
# Predicted Text: जॉन किरण्मय
#
# Input Text: jeevan prabhat
# Predicted Text: जॉन
#
# Input Text: jeevan rekha
# Predicted Text: जॉन लॉफलिन
#
# Input Text: jeff wilson
# Predicted Text: दर चक्र
#
# Input Text: jemma
# Predicted Text: नीदरलैंडन
#
# Input Text: jibran
# Predicted Text:
#
# Input Text: jimmy hendricks
# Predicted Text:
#
# Input Text: jimuta
# Predicted Text: कुंटे
#
# Input Text: jinelle
# Predicted Text: कुसुमाधिराज
#
# Input Text: jivitesh
# Predicted Text: क्यूशू
#
# Input Text: jocasta
# Predicted Text: लालमणि
#
# Input Text: jogi
# Predicted Text:
#
# Input Text: jograj
# Predicted Text:
#
# Input Text: john f. kennedy
# Predicted Text: सती पत्थर चाइना
#
# Input Text: john penn
# Predicted Text: सती
#
# Input Text: jon kent
# Predicted Text: लैन्स
#
# Input Text: josie
# Predicted Text:
#
# Input Text: judaism
# Predicted Text: कैतिर
#
# Input Text: jungle king
# Predicted Text: डोएन इलेक्ट्रा
#
# Input Text: justice choudhary
# Predicted Text:
#
# Input Text: jwalamukhi
# Predicted Text: लवाटे
#
# Input Text: kaamanaa
# Predicted Text:
#
# Input Text: kaaran
# Predicted Text:
#
# Input Text: kachchi kali
# Predicted Text: लीट्रिक्स डेस्वेल
#
# Input Text: kacia
# Predicted Text: लेम्ही
#
# Input Text: kailaash
# Predicted Text: दूधानी
#
# Input Text: kaise kahoon
# Predicted Text:
#
# Input Text: kalea
# Predicted Text:
#
# Input Text: kamal
# Predicted Text: लिवरपूल
#
# Input Text: kamesh
# Predicted Text: दुंदलोद
#
# Input Text: kamyab
# Predicted Text:
#
# Input Text: kanakpriya
# Predicted Text: लॉस
#
# Input Text: kanchan aur ganga
# Predicted Text: मार्मोल्स और अफसाना
#
# Input Text: kanwal
# Predicted Text: गए
#
# Input Text: karin
# Predicted Text:
#
# Input Text: kartik
# Predicted Text:
#
# Input Text: kasia
# Predicted Text: लव
#
# Input Text: katak
# Predicted Text:
#
# Input Text: kattora
# Predicted Text: इन
#
# Input Text: katy
# Predicted Text: आकांक्षा
#
# Input Text: kaumudhi
# Predicted Text: लकी
#
# Input Text: kaustav
# Predicted Text:
#
# Input Text: keene
# Predicted Text:
#
# Input Text: kennan
# Predicted Text: लुकतुके
#
# Input Text: keshihan
# Predicted Text:
#
# Input Text: kevin duers
# Predicted Text:
#
# Input Text: khahera
# Predicted Text: मादिवन
#
# Input Text: kharqa
# Predicted Text:
#
# Input Text: khatoon
# Predicted Text:
#
# Input Text: khattda
# Predicted Text: महावत
#
# Input Text: khel kismat ka
# Predicted Text: ख़ार्का जीवन का
#
# Input Text: khoj
# Predicted Text: महाबली
#
# Input Text: khuddar
# Predicted Text: महिरा
#
# Input Text: khufia mahal
# Predicted Text:
#
# Input Text: khuraymah
# Predicted Text: मकायला
#
# Input Text: khwaja mir dard
# Predicted Text: गंगा गैरेथ मालायला
#
# Input Text: khwaja nizamuddin chishti
# Predicted Text: गंगा सेंट लेटर्स
#
# Input Text: kintan
# Predicted Text: छाबड़ा
#
# Input Text: kiranmay
# Predicted Text: मंगतराम
#
# Input Text: kiril
# Predicted Text: मणिमुथर
#
# Input Text: klamath
# Predicted Text: आदमखोर
#
# Input Text: konark surya
# Predicted Text: मनीष
#
# Input Text: koning der nederlanden
# Predicted Text:  इलेक्ट्रो-ऑप्टिकल मिटेंगे
#
# Input Text: kori
# Predicted Text:
#
# Input Text: kristy
# Predicted Text: मार्दव
#
# Input Text: kufra
# Predicted Text:
#
# Input Text: kumari
# Predicted Text: मेरीकोपा
#
# Input Text: kunte
# Predicted Text: मैरीगोल्ड
#
# Input Text: kuntee
# Predicted Text:
#
# Input Text: kush
# Predicted Text: मसाडा
#
# Input Text: kusumaadhiraaj
# Predicted Text: थायरा
#
# Input Text: kyushu
# Predicted Text: मतीनदास
#
# Input Text: laalamani
# Predicted Text: फै़क
#
# Input Text: lagu
# Predicted Text: फकीहाह
#
# Input Text: lahore fort
# Predicted Text:  फोर्ट
#
# Input Text: lakshmishree
# Predicted Text: मुक़्तसिद
#
# Input Text: lal kunwar
# Predicted Text: धरम अचिंद्र
#
# Input Text: lal patthar
# Predicted Text: धरम लेटर्स
#
# Input Text: lalaatikaa
# Predicted Text: मेहरुन्निसा
#
# Input Text: lalan
# Predicted Text:
#
# Input Text: lance klusener
# Predicted Text: मैलोडियन हैं
#
# Input Text: landler
# Predicted Text: श्चेल्फी
#
# Input Text: larissa
# Predicted Text: मुक़द्दर
#
# Input Text: latona
# Predicted Text: फर्डीनांड
#
# Input Text: lawaate
# Predicted Text: घर
#
# Input Text: lawrence school
# Predicted Text: पाइरिस बन
#
# Input Text: layyah
# Predicted Text: माइकल
#
# Input Text: leatrix
# Predicted Text: माइक
#
# Input Text: lebanon
# Predicted Text: वास
#
# Input Text: leelaaraam
# Predicted Text:
#
# Input Text: lemhi
# Predicted Text: बरेथ
#
# Input Text: liberace
# Predicted Text:
#
# Input Text: light house
# Predicted Text:  तेंडुलकर
#
# Input Text: lilianna
# Predicted Text: लकी
#
# Input Text: linaeve
# Predicted Text:
#
# Input Text: lincoln university
# Predicted Text:  यूनिवर्सिटी
#
# Input Text: lion
# Predicted Text: अन्नाबेला
#
# Input Text: liverpool community
# Predicted Text:
#
# Input Text: lokmat
# Predicted Text:
#
# Input Text: los marmoles
# Predicted Text: पैटर्सन पैटर्सन
#
# Input Text: lothringen
# Predicted Text:
#
# Input Text: love in simla
# Predicted Text:
#
# Input Text: lucia
# Predicted Text:
#
# Input Text: luciano
# Predicted Text:
#
# Input Text: lucky number
# Predicted Text:
#
# Input Text: luktuke
# Predicted Text: मुकद्दर
#
# Input Text: maadhavee
# Predicted Text:
#
# Input Text: macronix international
# Predicted Text: जेमिनी मूर्ति
#
# Input Text: madan manjari
# Predicted Text:
#
# Input Text: madhu
# Predicted Text:
#
# Input Text: madivan
# Predicted Text:
#
# Input Text: mafizur rahman
# Predicted Text:
#
# Input Text: maghavaajit
# Predicted Text: नैरित
#
# Input Text: mahaashvetaa
# Predicted Text:
#
# Input Text: mahaavat
# Predicted Text:
#
# Input Text: mahabali hanuman
# Predicted Text: चरिथा शॉ
#
# Input Text: mahasweta
# Predicted Text: वैन
#
# Input Text: mahijuba
# Predicted Text: बत्रा
#
# Input Text: mahira
# Predicted Text: एक्सेप्शनल
#
# Input Text: mahish
# Predicted Text: साइंटीफिक
#
# Input Text: mahotsaah
# Predicted Text: अशरफ
#
# Input Text: mainaa
# Predicted Text:
#
# Input Text: makayla
# Predicted Text:
#
# Input Text: malayala manorama
# Predicted Text:
#
# Input Text: malpasset dam
# Predicted Text:
#
# Input Text: mangatraam
# Predicted Text: ग़ाज़ी
#
# Input Text: manimuthar reservoir
# Predicted Text:
#
# Input Text: maniram
# Predicted Text: न्यूबेरी
#
# Input Text: manish
# Predicted Text: ग़ुफयराह
#
# Input Text: manmatha
# Predicted Text: गिरिराज
#
# Input Text: manuhaar
# Predicted Text:
#
# Input Text: manzar
# Predicted Text:
#
# Input Text: mar mitenge
# Predicted Text: अदित्या
#
# Input Text: marasi
# Predicted Text:
#
# Input Text: mardav
# Predicted Text: नित्यसुन्दर
#
# Input Text: maricopa
# Predicted Text: गोडल
#
# Input Text: marigaon
# Predicted Text: थायरा
#
# Input Text: marigold
# Predicted Text: नूरजहाँ
#
# Input Text: marissa
# Predicted Text:
#
# Input Text: martin suji
# Predicted Text: हनुमान
#
# Input Text: masada
# Predicted Text:
#
# Input Text: mastani
# Predicted Text:
#
# Input Text: mateenadaas
# Predicted Text: ओमर
#
# Input Text: maurilio
# Predicted Text: खैय्यम
#
# Input Text: mawsil
# Predicted Text:
#
# Input Text: maxima
# Predicted Text: ऑर्बोटेक
#
# Input Text: mazda motor
# Predicted Text: केमिकल्स बयाना
#
# Input Text: mednipur
# Predicted Text: माल्क
#
# Input Text: meera shyam
# Predicted Text: चितहरा वायटिस
#
# Input Text: meet one greet one
# Predicted Text: ग्रिम्स क्रिस्टी मार्टिनो क्रिस्टी
#
# Input Text: mehmaan
# Predicted Text:
#
# Input Text: mehrunissa
# Predicted Text: पंढरी
#
# Input Text: melodeon
# Predicted Text: अपना
#
# Input Text: mengkuang dam
# Predicted Text: पेरिस डेल्ही
#
# Input Text: mera muqadar
# Predicted Text: चक्रपाणि
#
# Input Text: mera suhag
# Predicted Text: चक्रपाणि परिवर्तन
#
# Input Text: meri asha
# Predicted Text: पार्मा मिशनरी
#
# Input Text: meru betiri
# Predicted Text: पैटर्सन
#
# Input Text: messeturm
# Predicted Text:
#
# Input Text: mevan pieris
# Predicted Text:
#
# Input Text: mian mir
# Predicted Text: पेंडसे जन्मभूमि
#
# Input Text: michael bevan
# Predicted Text: यूनिवर्सिटी क्लेलैंड
#
# Input Text: mike atherton
# Predicted Text: एडमिरैल्टी अकमाल
#
# Input Text: minjonet
# Predicted Text:
#
# Input Text: modern youth
# Predicted Text: कार्लसन
#
# Input Text: monitor
# Predicted Text: ब्रिटिश
#
# Input Text: monrovia
# Predicted Text:
#
# Input Text: mookambika
# Predicted Text: म्युज़ियम
#
# Input Text: morag
# Predicted Text: रम्भा
#
# Input Text: mount abu
# Predicted Text: कैमोमाइल डे
#
# Input Text: mradul
# Predicted Text: पूनम
#
# Input Text: mudit
# Predicted Text: अछनेरा
#
# Input Text: mudra
# Predicted Text:
#
# Input Text: muhriz
# Predicted Text:
#
# Input Text: mujaddid
# Predicted Text:
#
# Input Text: mukadam
# Predicted Text: फुटबॉल
#
# Input Text: mukhataar
# Predicted Text: प्रयॉर
#
# Input Text: mukulit
# Predicted Text: खंडूर
#
# Input Text: mukunda
# Predicted Text:
#
# Input Text: mukut
# Predicted Text: रागिनी
#
# Input Text: municipal gallery of rhodes
# Predicted Text: राजमुनि एबीसो ऑफ कीले
#
# Input Text: munsif daily
# Predicted Text: कैल्सिंइंग घर
#
# Input Text: muqaddar
# Predicted Text:
#
# Input Text: muqtasid
# Predicted Text:
#
# Input Text: murari
# Predicted Text: नर्तकी
#
# Input Text: murti
# Predicted Text: रम्भा
#
# Input Text: mushtaq ahmed
# Predicted Text: रामूवालिया हैन्फ़र
#
# Input Text: mustafeed
# Predicted Text: मुक़्तसिद
#
# Input Text: naatak
# Predicted Text: रिपोर्टर
#
# Input Text: nabhan
# Predicted Text:
#
# Input Text: nahanni
# Predicted Text: रिक
#
# Input Text: nai
# Predicted Text:
#
# Input Text: naimish
# Predicted Text:
#
# Input Text: nairit
# Predicted Text:
#
# Input Text: najiyah
# Predicted Text: अन्नाबेला
#
# Input Text: nanda devi
# Predicted Text:  रोशनी
#
# Input Text: nasa medal for exceptional scientific achievement
# Predicted Text:  मेडल धोबी भेरूलाल की
#
# Input Text: nashwa
# Predicted Text: बोलबाला
#
# Input Text: nathan bracken
# Predicted Text: सैलाब वार
#
# Input Text: national medal of science
# Predicted Text:  अब्दुल ऑफ आँसू
#
# Input Text: naved ashraf
# Predicted Text: आग आग
#
# Input Text: naved latif
# Predicted Text: आग
#
# Input Text: naya rasta
# Predicted Text:
#
# Input Text: nazar ka shikar
# Predicted Text: सिल्वा का
#
# Input Text: neelabja
# Predicted Text: अंकोला
#
# Input Text: neelmani
# Predicted Text: ऑर्किड
#
# Input Text: neemuch
# Predicted Text:
#
# Input Text: neodymium
# Predicted Text: संबद
#
# Input Text: newbery honor
# Predicted Text:  सैन
#
# Input Text: niamur rashid
# Predicted Text: मेरा सायबिल
#
# Input Text: nice-systems limited
# Predicted Text:
#
# Input Text: nicholas pirama
# Predicted Text: सरयू सायप्रस
#
# Input Text: nikunja
# Predicted Text: सरिस्का
#
# Input Text: nilagriv
# Predicted Text: नागकन्या
#
# Input Text: nilima
# Predicted Text:
#
# Input Text: ninad
# Predicted Text: हेमचंद
#
# Input Text: niraj
# Predicted Text:
#
# Input Text: nityagopal
# Predicted Text: सी
#
# Input Text: nityanand
# Predicted Text:
#
# Input Text: nityasundar
# Predicted Text: सायबिल
#
# Input Text: noleta
# Predicted Text:
#
# Input Text: noopur
# Predicted Text:
#
# Input Text: noor jahan
# Predicted Text: शैतान सायप्रस
#
# Input Text: noorie
# Predicted Text:
#
# Input Text: noorjehan
# Predicted Text: अवार्ड
#
# Input Text: nordland
# Predicted Text:
#
# Input Text: oklahoma city
# Predicted Text: शंघाई शोला
#
# Input Text: oliver cromwell
# Predicted Text: जन्मभूमि डाक
#
# Input Text: omar khaiyyam
# Predicted Text: अंबाला भिलाईनगर
#
# Input Text: ophira
# Predicted Text:
#
# Input Text: orbotech
# Predicted Text: शेरी
#
# Input Text: orchid chemical
# Predicted Text:
#
# Input Text: order of the crown
# Predicted Text: श्रेष्ठ ऑफ घर श्रीदेवी
#
# Input Text: origins award
# Predicted Text: इवेलिया की
#
# Input Text: orthofix
# Predicted Text: श्रीपद
#
# Input Text: osman
# Predicted Text: प्रेअर
#
# Input Text: ova
# Predicted Text: शुआ
#
# Input Text: pallab
# Predicted Text: शुंगारे
#
# Input Text: panama city
# Predicted Text:
#
# Input Text: panchayat
# Predicted Text:
#
# Input Text: pandhari
# Predicted Text: उस्ताद
#
# Input Text: pannagesh
# Predicted Text: श्यामा
#
# Input Text: parichay
# Predicted Text: सिहल्सी
#
# Input Text: paris orly
# Predicted Text: सिल्वैन सिल्वैन
#
# Input Text: parivartan
# Predicted Text: असौती
#
# Input Text: parma missionary baptist
# Predicted Text:  वर्ल्ड कैदी
#
# Input Text: pashupati
# Predicted Text: सिराली
#
# Input Text: patterson thompson
# Predicted Text: सिउसन अथर्वन
#
# Input Text: peace
# Predicted Text: रेडपाथ
#
# Input Text: pechiparai
# Predicted Text:
#
# Input Text: peder skram
# Predicted Text: स्लोमेन जगदंबा
#
# Input Text: pendse
# Predicted Text:
#
# Input Text: penganga
# Predicted Text:
#
# Input Text: pensioner
# Predicted Text:
#
# Input Text: petrobrás
# Predicted Text: इखलास
#
# Input Text: phadatare
# Predicted Text: सोम
#
# Input Text: phagun
# Predicted Text: सायबिल
#
# Input Text: phil carlson
# Predicted Text: आचार्यनंदना आचार्यसुता
#
# Input Text: phil defreitas
# Predicted Text: आचार्यनंदना आचार्यसुता
#
# Input Text: phil simmons
# Predicted Text: आचार्यनंदना
#
# Input Text: philadelphia
# Predicted Text: आयरन
#
# Input Text: phyliss
# Predicted Text:
#
# Input Text: physiology
# Predicted Text: स्पर्श
#
# Input Text: pink
# Predicted Text: इंक्रेडिमेल
#
# Input Text: polly
# Predicted Text: इंक्रेडिमेल
#
# Input Text: poojit
# Predicted Text: स्पाथेर‍ियन
#
# Input Text: poonam ki raat
# Predicted Text: शैडो अवार्ड गुरूद्वारा
#
# Input Text: powerful
# Predicted Text: स्टेट्सचिपपैक
#
# Input Text: prajaapat
# Predicted Text: स्टीवन्स
#
# Input Text: prarthana
# Predicted Text: स्टॉल्ट
#
# Input Text: prasannjit
# Predicted Text: निलसन
#
# Input Text: pratima
# Predicted Text: धरम
#
# Input Text: praveen
# Predicted Text:
#
# Input Text: pretorius
# Predicted Text:
#
# Input Text: pro football hall of fame
# Predicted Text: सुभाषचंद्र  चक्रपाणि ऑफ
#
# Input Text: procter
# Predicted Text:
#
# Input Text: prometheus
# Predicted Text: मकायला
#
# Input Text: pryor
# Predicted Text: सुजया
#
# Input Text: punarnava
# Predicted Text:
#
# Input Text: pushparaaj
# Predicted Text:
#
# Input Text: pyar ka toofan
# Predicted Text: सुलेमान का जय
#
# Input Text: pyas
# Predicted Text: समरसाइड
#
# Input Text: qaidi
# Predicted Text: हम
#
# Input Text: raagini
# Predicted Text:
#
# Input Text: raajamuni
# Predicted Text: मेथोडिस्ट
#
# Input Text: raasavihaaree
# Predicted Text: ऑफ
#
# Input Text: raghavendra
# Predicted Text: सनऑप्टा
#
# Input Text: raichur
# Predicted Text:
#
# Input Text: rain calcining
# Predicted Text:  ब्लूमबर्ग
#
# Input Text: raj nartaki
# Predicted Text: डेल्ही डेल्ही
#
# Input Text: raje
# Predicted Text:
#
# Input Text: rajeshwar
# Predicted Text: क़ादरी
#
# Input Text: ram avtar
# Predicted Text: बैंक डंग
#
# Input Text: rambaan
# Predicted Text:
#
# Input Text: rambha
# Predicted Text:
#
# Input Text: ramuwalia
# Predicted Text: टैरिन
#
# Input Text: ranajay
# Predicted Text:
#
# Input Text: rance
# Predicted Text: टी
#
# Input Text: randheer
# Predicted Text: फिल
#
# Input Text: rasaal
# Predicted Text:
#
# Input Text: rasheed
# Predicted Text: तेजस्विनी
#
# Input Text: rasikaa
# Predicted Text:
#
# Input Text: reporter raju
# Predicted Text:
#
# Input Text: reykjavik
# Predicted Text:
#
# Input Text: richmond
# Predicted Text: जावेद
#
# Input Text: rick
# Predicted Text: जयसेकरा
#
# Input Text: robin uthappa
# Predicted Text: नैया
#
# Input Text: rochelle
# Predicted Text:
#
# Input Text: roden
# Predicted Text: डार्ट
#
# Input Text: roland butcher
# Predicted Text: थरिंगन
#
# Input Text: romantic india
# Predicted Text: तिलक इंडिया
#
# Input Text: romesh kaluwitharana
# Predicted Text: तिमिन
#
# Input Text: roseanne
# Predicted Text: तिरप
#
# Input Text: roshanee
# Predicted Text: तोईयाबे
#
# Input Text: rudy
# Predicted Text:
#
# Input Text: rupaiya
# Predicted Text:
#
# Input Text: russell krovi
# Predicted Text: टोरी
#
# Input Text: saadat
# Predicted Text: ट्रूडा
#
# Input Text: sach
# Predicted Text:
#
# Input Text: sachche ka bolbala
# Predicted Text: बोलबाला
#
# Input Text: sachin tendulkar
# Predicted Text: इन्वेस्टमेंट
#
# Input Text: sadiqah
# Predicted Text: प्लाज़ा
#
# Input Text: saheb
# Predicted Text: बाद
#
# Input Text: sailaab
# Predicted Text: हीरा
#
# Input Text: sailesh
# Predicted Text: उबेजा
#
# Input Text: saint helens fort
# Predicted Text: उमापति नावेद फोर्ट
#
# Input Text: sainte marie
# Predicted Text: डंडी हल
#
# Input Text: saipratap
# Predicted Text:
#
# Input Text: sajan
# Predicted Text:
#
# Input Text: sajeewa de silva
# Predicted Text: उत्तर एक अवार्ड
#
# Input Text: sajni
# Predicted Text: जाएगा
#
# Input Text: salil ankola
# Predicted Text: जाएगा लेटर्स
#
# Input Text: samaj patan
# Predicted Text: वर्धा
#
# Input Text: sambad
# Predicted Text: वेंकटेश
#
# Input Text: sambaran
# Predicted Text: वेंकटेश्वर
#
# Input Text: samrendru
# Predicted Text:
#
# Input Text: san martino
# Predicted Text: ख्वाजा क्रेग
#
# Input Text: san paolo imi
# Predicted Text: ख्वाजा घर
#
# Input Text: sanghera
# Predicted Text: विश्राम
#
# Input Text: sant ravidas ki amar kahani
# Predicted Text:   अवार्ड वर्धक
#
# Input Text: santos
# Predicted Text: जीवन
#
# Input Text: sarayu
# Predicted Text:
#
# Input Text: sareen
# Predicted Text:
#
# Input Text: sariska
# Predicted Text: वॉक्ले
#
# Input Text: saskatchewan
# Predicted Text: जगदंबा
#
# Input Text: sati anjani
# Predicted Text: महाश्वेता कंचन
#
# Input Text: sati nagkanaya
# Predicted Text: महाश्वेता शॉ
#
# Input Text: satnam overseas
# Predicted Text:
#
# Input Text: satyaki
# Predicted Text: वज़ीरा
#
# Input Text: sau saal baad
# Predicted Text:  खान बेटी
#
# Input Text: saunders
# Predicted Text: वेडेल
#
# Input Text: scotia sea
# Predicted Text:  की
#
# Input Text: seemaant
# Predicted Text:
#
# Input Text: sekere
# Predicted Text:
#
# Input Text: seliya
# Predicted Text: जस्टिस
#
# Input Text: senegal
# Predicted Text:
#
# Input Text: seringapatam
# Predicted Text: यूकॉन
#
# Input Text: sevaaraam
# Predicted Text: सिटी
#
# Input Text: shaitan
# Predicted Text:
#
# Input Text: shake hands
# Predicted Text:  भद्राचलम
#
# Input Text: shampa
# Predicted Text: ज़लील
#
# Input Text: shamsheer e arab
# Predicted Text: ज़ैब आसिया
#
# Input Text: shan
# Predicted Text:
#
# Input Text: shanghai museum
# Predicted Text:  वन
#
# Input Text: shanpaak
# Predicted Text: अली
#
# Input Text: sharadini
# Predicted Text:
#
# Input Text: sharon stone
# Predicted Text: लुटेरा
#
# Input Text: shatrughn
# Predicted Text:
#
# Input Text: shery
# Predicted Text:
#
# Input Text: shimane maru
# Predicted Text:
#
# Input Text: shoaib akhtar
# Predicted Text:
#
# Input Text: shoeb
# Predicted Text: यूनिवर्सिटी
#
# Input Text: shotput
# Predicted Text:
#
# Input Text: shreshth
# Predicted Text:
#
# Input Text: shridevi
# Predicted Text: कैटी
#
# Input Text: shridhar
# Predicted Text:
#
# Input Text: shripad
# Predicted Text:
#
# Input Text: shu'a
# Predicted Text:
#
# Input Text: shubhang
# Predicted Text:
#
# Input Text: shungare
# Predicted Text:
#
# Input Text: shurayh
# Predicted Text:
#
# Input Text: shyaamaa
# Predicted Text: थायरा
#
# Input Text: sihlsee
# Predicted Text: ख़ार्का
#
# Input Text: silvain
# Predicted Text:
#
# Input Text: silver standard resources
# Predicted Text:  तेजा
#
# Input Text: simon katich
# Predicted Text:
#
# Input Text: sipahiya
# Predicted Text:
#
# Input Text: siraalee
# Predicted Text:
#
# Input Text: siran
# Predicted Text:
#
# Input Text: siusan
# Predicted Text:
#
# Input Text: skipper
# Predicted Text:
#
# Input Text: slowman
# Predicted Text:
#
# Input Text: sneha
# Predicted Text: डुअर्स
#
# Input Text: snigdhaa
# Predicted Text: मुक़्तसिद
#
# Input Text: sohani
# Predicted Text: डॉरेन
#
# Input Text: sohni
# Predicted Text: हन्नान
#
# Input Text: solferino
# Predicted Text:
#
# Input Text: som
# Predicted Text:
#
# Input Text: somakaantaa
# Predicted Text:
#
# Input Text: southern iron
# Predicted Text: शोएब
#
# Input Text: sowani
# Predicted Text: मेरा
#
# Input Text: sparsh
# Predicted Text:
#
# Input Text: spathareion museum of the shadow theatre
# Predicted Text:  वन ऑफ घर रशीद कीले
#
# Input Text: stats chippac
# Predicted Text:  गए
#
# Input Text: steve martin
# Predicted Text:  हनुमान
#
# Input Text: stevens
# Predicted Text:
#
# Input Text: stolt-nielsen
# Predicted Text:
#
# Input Text: stride arcolab
# Predicted Text:
#
# Input Text: subhaashachandr
# Predicted Text: आन
#
# Input Text: suchi
# Predicted Text:
#
# Input Text: sudarshan
# Predicted Text:
#
# Input Text: suhrewardi
# Predicted Text:
#
# Input Text: sujaya
# Predicted Text:
#
# Input Text: sukhija
# Predicted Text: सायप्रस
#
# Input Text: sulaiman
# Predicted Text:
#
# Input Text: sultanah
# Predicted Text: चिस्ती
#
# Input Text: summerside united methodist
# Predicted Text: मेरीकोपा
#
# Input Text: sun microsystems
# Predicted Text:
#
# Input Text: sunopta
# Predicted Text:
#
# Input Text: surgery
# Predicted Text:
#
# Input Text: susan sarandon
# Predicted Text: अलेक्जेवियर
#
# Input Text: suwo
# Predicted Text:
#
# Input Text: swan
# Predicted Text: क्लामथ
#
# Input Text: syed akhtar imam quadri
# Predicted Text:  मार्टिन बेटी
#
# Input Text: syndicate bank
# Predicted Text:  सूर्य
#
# Input Text: talakkad
# Predicted Text:
#
# Input Text: talika
# Predicted Text: खुरायमाह
#
# Input Text: tanuj
# Predicted Text:
#
# Input Text: tanwir
# Predicted Text:
#
# Input Text: target
# Predicted Text: अखिला
#
# Input Text: tariqah
# Predicted Text:
#
# Input Text: tarulata
# Predicted Text:
#
# Input Text: taryn
# Predicted Text:
#
# Input Text: tata tea
# Predicted Text:  आरा
#
# Input Text: tazwell
# Predicted Text:
#
# Input Text: tejaa
# Predicted Text:
#
# Input Text: tejaswini
# Predicted Text:
#
# Input Text: tel aviv
# Predicted Text:  फेम
#
# Input Text: tera karam mera dharam
# Predicted Text:  धूम्र चक्रपाणि
#
# Input Text: thames valley university
# Predicted Text:  बद्रीप्रसाद यूनिवर्सिटी
#
# Input Text: thar
# Predicted Text:
#
# Input Text: the times of india
# Predicted Text: आज मीर ऑफ इंडिया
#
# Input Text: thuringen
# Predicted Text: थायरा
#
# Input Text: thyra
# Predicted Text:
#
# Input Text: tilak
# Predicted Text:
#
# Input Text: timin
# Predicted Text:
#
# Input Text: tirap
# Predicted Text:
#
# Input Text: toiyabe
# Predicted Text:
#
# Input Text: tony
# Predicted Text:
#
# Input Text: toofan
# Predicted Text: जय
#
# Input Text: torie
# Predicted Text:
#
# Input Text: tress
# Predicted Text:
#
# Input Text: trevelian
# Predicted Text:
#
# Input Text: trinity biotech
# Predicted Text: कुमारी फ़ाइनेंस
#
# Input Text: truda
# Predicted Text: जनक
#
# Input Text: truly
# Predicted Text:
#
# Input Text: trump world tower
# Predicted Text:  महिश साल
#
# Input Text: tube investment
# Predicted Text:  होते
#
# Input Text: tungabhadra
# Predicted Text:
#
# Input Text: two prudential plaza
# Predicted Text:  यासिर ग्रीम
#
# Input Text: ubeja
# Predicted Text:
#
# Input Text: umapati
# Predicted Text:
#
# Input Text: ummayyah
# Predicted Text:
#
# Input Text: university of alaska
# Predicted Text: यूनिवर्सिटी ऑफ बात
#
# Input Text: university of dundee
# Predicted Text: यूनिवर्सिटी ऑफ
#
# Input Text: university of hull
# Predicted Text: यूनिवर्सिटी ऑफ लागू
#
# Input Text: university of keele
# Predicted Text: यूनिवर्सिटी ऑफ सादात
#
# Input Text: university of sunderland
# Predicted Text: यूनिवर्सिटी ऑफ घर
#
# Input Text: urania
# Predicted Text:
#
# Input Text: ursala
# Predicted Text:
#
# Input Text: uttar kannada
# Predicted Text: गुड़गाँव दिलबर
#
# Input Text: vajra
# Predicted Text: कुँवर
#
# Input Text: valentino
# Predicted Text:
#
# Input Text: valli
# Predicted Text:
#
# Input Text: van
# Predicted Text: जीनी
#
# Input Text: vanoise
# Predicted Text:
#
# Input Text: vardha
# Predicted Text:
#
# Input Text: velaa
# Predicted Text:
#
# Input Text: venkatesh
# Predicted Text:
#
# Input Text: venkateshvar
# Predicted Text:
#
# Input Text: veolia environnement
# Predicted Text:
#
# Input Text: vidya vardhaka sangha high school, bangalore
# Predicted Text:      प्यास
#
# Input Text: vidyut
# Predicted Text:
#
# Input Text: vijaynagar
# Predicted Text:
#
# Input Text: vimohinee
# Predicted Text:
#
# Input Text: viplaav
# Predicted Text:
#
# Input Text: viresh
# Predicted Text: डेरिन
#
# Input Text: vishalgad
# Predicted Text:
#
# Input Text: vishram
# Predicted Text:
#
# Input Text: visisht seva medal
# Predicted Text:   मेडल
#
# Input Text: vittorio emanuele
# Predicted Text:  सेंट्रल
#
# Input Text: vrandaavaneshvaree
# Predicted Text: लैंडर
#
# Input Text: vytis
# Predicted Text:
#
# Input Text: wachhar
# Predicted Text:
#
# Input Text: waite
# Predicted Text: कैतिर
#
# Input Text: walker museum
# Predicted Text:  वन
#
# Input Text: walkley award
# Predicted Text:  की
#
# Input Text: walt disney
# Predicted Text:
#
# Input Text: warner
# Predicted Text:
#
# Input Text: washington
# Predicted Text:
#
# Input Text: watan ke rakhwale
# Predicted Text:
#
# Input Text: wazeera
# Predicted Text:
#
# Input Text: weddell
# Predicted Text: लैटोना
#
# Input Text: willa
# Predicted Text:
#
# Input Text: wockhardt
# Predicted Text:
#
# Input Text: woodward
# Predicted Text:
#
# Input Text: yaqeen
# Predicted Text:
#
# Input Text: yaqub
# Predicted Text:
#
# Input Text: yar
# Predicted Text:
#
# Input Text: yasir arafat
# Predicted Text:
#
# Input Text: yehiam fort
# Predicted Text:  फोर्ट
#
# Input Text: yograj
# Predicted Text: लेबनॉन
#
# Input Text: yukon
# Predicted Text:
#
# Input Text: yuvraj singh
# Predicted Text:
#
# Input Text: zahoor elahi
# Predicted Text:  मैकलियर
#
# Input Text: zaleel
# Predicted Text:
#
# Input Text: zayb
# Predicted Text:
#
# Input Text: zorion
# Predicted Text: लाइट

# %% [markdown]
# ## Predicting a Word given by User Manually

# %%
# Inverse map the index to the word using the tokenizer
input_word_index = input_lang_tokenizer.word_index
input_index_word = dict([(index, word) for word, index in input_word_index.items()])

target_word_index = targ_lang_tokenizer.word_index
target_index_word = dict([(index, word) for word, index in target_word_index.items()])

# Function to convert the index to the word
def index_to_word(index):
  return target_index_word.get(index, '')

# Function to convert the prediction to the text
def prediction_to_text(prediction):
  text = ''
  for i in range(prediction.shape[0]):
    index = np.argmax(prediction[i])
    word = index_to_word(index)
    if word == 'endseq':
      return text
    text += word + ' '
  return text

# Get manual input from the user
t = int(input("Enter number of words you want to predict"))

print("Model Predictions: ")

for i in range(t):
    input_text = input("Enter a word: ")


# Convert the manual input to a tensor
    input_tensor = input_lang_tokenizer.texts_to_sequences([input_text])
    input_tensor = tf.keras.preprocessing.sequence.pad_sequences(input_tensor, maxlen=input_tensor_test.shape[0], padding='post')
    input_tensor = np.array(input_tensor)

# Get the prediction for the manual input
    prediction = model.predict(input_tensor)



# # Get the predicted text for the manual input
    predicted_text = prediction_to_text(prediction[0])

# # Print the manual input and the predicted text
    print("Input Text:", input_text)
    print("Predicted Text:", predicted_text)
# Out:
# Enter number of words you want to predict2
# Model Predictions:
# Enter a word: daku
# 1/1 [==============================] - 0s 377ms/step
# Input Text: daku
# Predicted Text: डाकू
# Enter a word: guru
# 1/1 [==============================] - 0s 318ms/step
# Input Text: guru
# Predicted Text: गुरूद्वारा
