# %%
import xml.etree.ElementTree as ET  #5
import numpy as np
import tensorflow as tf

# Load the data from the XML file
def load_data(filename):
    tree = ET.parse(filename)
    root = tree.getroot()
    input_texts = []
    target_texts = []
    for i, item in enumerate(root):
        input_text = item[0].text
        target_text = item[1].text
        input_texts.append(input_text)
        target_texts.append(target_text)
    return input_texts, target_texts

# Tokenize the text data
def tokenize(lang):
    lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='')
    lang_tokenizer.fit_on_texts(lang)
    tensor = lang_tokenizer.texts_to_sequences(lang)
    tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor, padding='post')
    return tensor, lang_tokenizer

# Load and tokenize the data
input_texts, target_texts = load_data('NEWS2018_M-EnHi_trn.xml')
input_tensor, inp_lang_tokenizer = tokenize(input_texts)
target_tensor, targ_lang_tokenizer = tokenize(target_texts)

# Calculate max length of input and target tensors
max_length_inp, max_length_tar = input_tensor.shape[1], target_tensor.shape[1]

# Convert the target tensor to have the expected shape
target_tensor = tf.keras.utils.to_categorical(target_tensor, num_classes=len(targ_lang_tokenizer.word_index) + 1)
target_tensor = tf.keras.preprocessing.sequence.pad_sequences(target_tensor, maxlen=max_length_inp, padding='post')

# Create the RNN model
def create_model(inp_vocab_size, tar_vocab_size, max_length_inp, max_length_tar):
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Embedding(inp_vocab_size, 128, input_length=max_length_inp))
    model.add(tf.keras.layers.GRU(128, return_sequences=True))
    model.add(tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(tar_vocab_size, activation='softmax')))
    return model


model = create_model(len(inp_lang_tokenizer.word_index) + 1, len(targ_lang_tokenizer.word_index) + 1, max_length_inp, max_length_tar)

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Fit the model
history = model.fit(input_tensor, target_tensor, epochs=40, batch_size=128, validation_split=0.2)
# Out:
# Epoch 1/40
# 81/81 [==============================] - 63s 752ms/step - loss: 4.1808 - accuracy: 0.8406 - val_loss: 1.5030 - val_accuracy: 0.8557
# Epoch 2/40
# 81/81 [==============================] - 58s 717ms/step - loss: 1.4284 - accuracy: 0.8515 - val_loss: 1.4135 - val_accuracy: 0.8557
# Epoch 3/40
# 81/81 [==============================] - 56s 696ms/step - loss: 1.3879 - accuracy: 0.8516 - val_loss: 1.4086 - val_accuracy: 0.8557
# Epoch 4/40
# 81/81 [==============================] - 59s 735ms/step - loss: 1.3730 - accuracy: 0.8515 - val_loss: 1.4083 - val_accuracy: 0.8557
# Epoch 5/40
# 81/81 [==============================] - 57s 709ms/step - loss: 1.3611 - accuracy: 0.8514 - val_loss: 1.4111 - val_accuracy: 0.8556
# Epoch 6/40
# 81/81 [==============================] - 59s 723ms/step - loss: 1.3481 - accuracy: 0.8514 - val_loss: 1.4097 - val_accuracy: 0.8557
# Epoch 7/40
# 81/81 [==============================] - 57s 709ms/step - loss: 1.3328 - accuracy: 0.8514 - val_loss: 1.4027 - val_accuracy: 0.8557
# Epoch 8/40
# 81/81 [==============================] - 59s 724ms/step - loss: 1.3126 - accuracy: 0.8514 - val_loss: 1.3970 - val_accuracy: 0.8557
# Epoch 9/40
# 81/81 [==============================] - 57s 703ms/step - loss: 1.2913 - accuracy: 0.8515 - val_loss: 1.3945 - val_accuracy: 0.8556
# Epoch 10/40
# 81/81 [==============================] - 53s 656ms/step - loss: 1.2697 - accuracy: 0.8523 - val_loss: 1.3932 - val_accuracy: 0.8577
# Epoch 11/40
# 81/81 [==============================] - 55s 685ms/step - loss: 1.2484 - accuracy: 0.8551 - val_loss: 1.3938 - val_accuracy: 0.8584
# Epoch 12/40
# 81/81 [==============================] - 57s 710ms/step - loss: 1.2273 - accuracy: 0.8562 - val_loss: 1.3948 - val_accuracy: 0.8586
# Epoch 13/40
# 81/81 [==============================] - 57s 709ms/step - loss: 1.2069 - accuracy: 0.8570 - val_loss: 1.3968 - val_accuracy: 0.8588
# Epoch 14/40
# 81/81 [==============================] - 57s 707ms/step - loss: 1.1876 - accuracy: 0.8576 - val_loss: 1.3987 - val_accuracy: 0.8588
# Epoch 15/40
# 81/81 [==============================] - 62s 760ms/step - loss: 1.1685 - accuracy: 0.8586 - val_loss: 1.4033 - val_accuracy: 0.8590
# Epoch 16/40
# 81/81 [==============================] - 64s 793ms/step - loss: 1.1490 - accuracy: 0.8593 - val_loss: 1.4062 - val_accuracy: 0.8591
# Epoch 17/40
# 81/81 [==============================] - 57s 706ms/step - loss: 1.1290 - accuracy: 0.8601 - val_loss: 1.4079 - val_accuracy: 0.8597
# Epoch 18/40
# 81/81 [==============================] - 58s 712ms/step - loss: 1.1078 - accuracy: 0.8613 - val_loss: 1.4093 - val_accuracy: 0.8610
# Epoch 19/40
# 81/81 [==============================] - 57s 702ms/step - loss: 1.0845 - accuracy: 0.8628 - val_loss: 1.4095 - val_accuracy: 0.8611
# Epoch 20/40
# 81/81 [==============================] - 63s 774ms/step - loss: 1.0579 - accuracy: 0.8644 - val_loss: 1.4100 - val_accuracy: 0.8616
# Epoch 21/40
# 81/81 [==============================] - 59s 734ms/step - loss: 1.0275 - accuracy: 0.8661 - val_loss: 1.4096 - val_accuracy: 0.8640
# Epoch 22/40
# 81/81 [==============================] - 60s 737ms/step - loss: 0.9932 - accuracy: 0.8678 - val_loss: 1.4114 - val_accuracy: 0.8648
# Epoch 23/40
# 81/81 [==============================] - 58s 723ms/step - loss: 0.9562 - accuracy: 0.8693 - val_loss: 1.4121 - val_accuracy: 0.8664
# Epoch 24/40
# 81/81 [==============================] - 57s 704ms/step - loss: 0.9164 - accuracy: 0.8713 - val_loss: 1.4149 - val_accuracy: 0.8672
# Epoch 25/40
# 81/81 [==============================] - 57s 707ms/step - loss: 0.8737 - accuracy: 0.8736 - val_loss: 1.4177 - val_accuracy: 0.8684
# Epoch 26/40
# 81/81 [==============================] - 55s 680ms/step - loss: 0.8266 - accuracy: 0.8766 - val_loss: 1.4185 - val_accuracy: 0.8695
# Epoch 27/40
# 81/81 [==============================] - 56s 694ms/step - loss: 0.7745 - accuracy: 0.8803 - val_loss: 1.4193 - val_accuracy: 0.8701
# Epoch 28/40
# 81/81 [==============================] - 57s 701ms/step - loss: 0.7165 - accuracy: 0.8854 - val_loss: 1.4212 - val_accuracy: 0.8707
# Epoch 29/40
# 81/81 [==============================] - 56s 699ms/step - loss: 0.6537 - accuracy: 0.8932 - val_loss: 1.4216 - val_accuracy: 0.8718
# Epoch 30/40
# 81/81 [==============================] - 57s 709ms/step - loss: 0.5874 - accuracy: 0.9049 - val_loss: 1.4220 - val_accuracy: 0.8727
# Epoch 31/40
# 81/81 [==============================] - 56s 692ms/step - loss: 0.5190 - accuracy: 0.9219 - val_loss: 1.4221 - val_accuracy: 0.8735
# Epoch 32/40
# 81/81 [==============================] - 57s 700ms/step - loss: 0.4494 - accuracy: 0.9434 - val_loss: 1.4228 - val_accuracy: 0.8745
# Epoch 33/40
# 81/81 [==============================] - 58s 717ms/step - loss: 0.3805 - accuracy: 0.9635 - val_loss: 1.4224 - val_accuracy: 0.8750
# Epoch 34/40
# 81/81 [==============================] - 56s 697ms/step - loss: 0.3130 - accuracy: 0.9784 - val_loss: 1.4232 - val_accuracy: 0.8754
# Epoch 35/40
# 81/81 [==============================] - 56s 696ms/step - loss: 0.2504 - accuracy: 0.9868 - val_loss: 1.4238 - val_accuracy: 0.8762
# Epoch 36/40
# 81/81 [==============================] - 58s 718ms/step - loss: 0.1950 - accuracy: 0.9911 - val_loss: 1.4244 - val_accuracy: 0.8766
# Epoch 37/40
# 81/81 [==============================] - 59s 725ms/step - loss: 0.1488 - accuracy: 0.9938 - val_loss: 1.4254 - val_accuracy: 0.8767
# Epoch 38/40
# 81/81 [==============================] - 57s 704ms/step - loss: 0.1130 - accuracy: 0.9951 - val_loss: 1.4259 - val_accuracy: 0.8768
# Epoch 39/40
# 81/81 [==============================] - 57s 701ms/step - loss: 0.0864 - accuracy: 0.9960 - val_loss: 1.4271 - val_accuracy: 0.8772
# Epoch 40/40
# 81/81 [==============================] - 56s 693ms/step - loss: 0.0672 - accuracy: 0.9965 - val_loss: 1.4274 - val_accuracy: 0.8774

# %% [markdown]
# - Model's Accuracy on Training data is 99%
# - Loss on Training data is 0.067

# %%
# Saving the model

model.save('RNN-wordTranslator.h5')

# %% [markdown]
# ## Evaluating on Test Data

# %%
# # Loading the Model
from tensorflow.keras.models import load_model

model = load_model('RNN-wordTranslator.h5')

# %% [markdown]
# ## Calculating Model's loss and Accuray on Testing data

# %%
# Load and tokenize the test data
input_texts_test, target_texts_test = load_data('NEWS2018_M-EnHi_dev.xml')
input_tensor_test, input_lang_tokenizer = tokenize(input_texts_test)
target_tensor_test, targ_lang_tokenizer = tokenize(target_texts_test)

# Get the number of unique words in the target language
tar_vocab_size = len(targ_lang_tokenizer.word_index) + 1

# Convert the target tensor to have the expected shape
final_layer_output_shape = model.layers[-1].output_shape
target_tensor_test = tf.keras.preprocessing.sequence.pad_sequences(target_tensor_test, maxlen=final_layer_output_shape[1], padding='post')
target_tensor_test = tf.keras.utils.to_categorical(target_tensor_test, num_classes=final_layer_output_shape[2])

# Pad the input tensor to have the expected shape
input_tensor_test = tf.keras.preprocessing.sequence.pad_sequences(input_tensor_test, maxlen=final_layer_output_shape[1], padding='post')

# Evaluate the model on the test data
test_loss, test_acc = model.evaluate(input_tensor_test, target_tensor_test)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
# Out:
# 32/32 [==============================] - 2s 35ms/step - loss: 1.7828 - accuracy: 0.8644
# Test loss: 1.782827377319336
# Test accuracy: 0.8644000291824341

# %% [markdown]
# - Loss on Testing data is 1.78
# - Models accuracy on testing data is 0.8644

# %% [markdown]
# ## Model's prediction output on Test data

# %%
# Inverse map the index to the word using the tokenizer
input_word_index = input_lang_tokenizer.word_index
input_index_word = dict([(index, word) for word, index in input_word_index.items()])

target_word_index = targ_lang_tokenizer.word_index
target_index_word = dict([(index, word) for word, index in target_word_index.items()])

# Get the predictions for the test data
predictions = model.predict(input_tensor_test)

# Function to convert the index to the word
def index_to_word(index):
  return target_index_word.get(index, '')

# Function to convert the prediction to the text
def prediction_to_text(prediction):
  text = ''
  for i in range(prediction.shape[0]):
    index = np.argmax(prediction[i])
    word = index_to_word(index)
    if word == 'endseq':
      return text
    text += word + ' '
  return text

# Get the predicted texts for the test data
predicted_texts = []
for i in range(predictions.shape[0]):
  prediction = predictions[i, :, :]
  text = prediction_to_text(prediction)
  predicted_texts.append(text)

# Print the input text, target text, and predicted text for 10 samples
for i in range(len(input_texts_test)):
  print("Input Text:", input_texts_test[i])
  print("Target Text:", target_texts_test[i])
  print("Predicted Text:", predicted_texts[i])
  print()
# Out:
# 32/32 [==============================] - 1s 13ms/step
# Input Text: aachaaryanandana
# Target Text: आचार्यनंदना
# Predicted Text: मेरी
#
# Input Text: aachaarysut
# Target Text: आचार्यसुत
# Predicted Text: सिटी
#
# Input Text: aacharynandan
# Target Text: आचार्यनंदन
# Predicted Text: तूफान
#
# Input Text: aacharynandanaa
# Target Text: आचार्यनंदना
# Predicted Text: फिफ्टी
#
# Input Text: aadamkhor
# Target Text: आदमखोर
# Predicted Text: सेंट
#
# Input Text: aag aur shola
# Target Text: आग और शोला
# Predicted Text: सन और शोएब
#
# Input Text: aaj ki baat
# Target Text: आज की बात
# Predicted Text: मेरा अवार्ड आशा
#
# Input Text: aaj ki taza khabar
# Target Text: आज की ताज़ा खबर
# Predicted Text: मेरा अवार्ड आचार्यसुत आचार्यनंदन
#
# Input Text: aakanksha
# Target Text: आकांक्षा
# Predicted Text: चोर
#
# Input Text: aan
# Target Text: आन
# Predicted Text: एबीसो
#
# Input Text: aankhon dekhi
# Target Text: आँखों देखी
# Predicted Text: प्रो ताज़ा
#
# Input Text: aansoo ban gaye phool
# Target Text: आँसू बन गए फ़ूल
# Predicted Text: अन्नाबेला  खबर डैम
#
# Input Text: aashaa
# Target Text: आशा
# Predicted Text: स्वान
#
# Input Text: aatank
# Target Text: आतंक
# Predicted Text: आन
#
# Input Text: ab kya hoga
# Target Text: अब क्या होगा
# Predicted Text: आँखों बयाना आँसू
#
# Input Text: abdul haakim
# Target Text: अब्दुल हाकिम
# Predicted Text: अब्दुल बन
#
# Input Text: abdul hannan
# Target Text: अब्दुल हन्नान
# Predicted Text: अब्दुल गिरिराज
#
# Input Text: abdul muhasin
# Target Text: अब्दुल मुहासिन
# Predicted Text: अब्दुल
#
# Input Text: abdul muiz
# Target Text: अब्दुल मुईज़
# Predicted Text: अब्दुल चक्र
#
# Input Text: abdul wakil
# Target Text: अब्दुल वकील
# Predicted Text: अब्दुल अग्रिमा
#
# Input Text: aberdeen
# Target Text: एबरडीन
# Predicted Text: आतंक
#
# Input Text: abha
# Target Text: आभा
# Predicted Text: आकांक्षा
#
# Input Text: abhiman
# Target Text: अभिमान
# Predicted Text: होगा
#
# Input Text: abhinanda
# Target Text: अभिनन्दा
# Predicted Text: मुईज़
#
# Input Text: abisso
# Target Text: एबीसो
# Predicted Text: एबरडीन
#
# Input Text: abu mansur daqiqi
# Target Text: अबू मंसूर दक़ीक़ी
# Predicted Text: डे अबू दक़ीक़ी
#
# Input Text: abul fazal
# Target Text: अबुल फजल
# Predicted Text: फ़ूल शॉ
#
# Input Text: acharysuta
# Target Text: आचार्यसुता
# Predicted Text: नावेद
#
# Input Text: achhnera junction
# Target Text: अछनेरा जंक्शन
# Predicted Text: आकर्षण जंक्शन
#
# Input Text: achindr
# Target Text: अचिंद्र
# Predicted Text: क्या
#
# Input Text: adhip
# Target Text: अधिप
# Predicted Text: हाकिम
#
# Input Text: aditya
# Target Text: अदित्या
# Predicted Text:
#
# Input Text: admiralty
# Target Text: एडमिरैल्टी
# Predicted Text: वकील
#
# Input Text: afasaana
# Target Text: अफसाना
# Predicted Text: अधिप
#
# Input Text: afsana
# Target Text: अफसाना
# Predicted Text: अभिमान
#
# Input Text: agar tum na hote
# Target Text: अगर तुम न होते
# Predicted Text: अगर तुम अनल
#
# Input Text: aglaia
# Target Text: एग्लेइया
# Predicted Text: भेरूलाल
#
# Input Text: agni chakra
# Target Text: अग्नि चक्र
# Predicted Text: मोहम्मद होते
#
# Input Text: agrima
# Target Text: अग्रिमा
# Predicted Text: अबुल
#
# Input Text: akalmash
# Target Text: अकल्मश
# Predicted Text: अमेरिकन
#
# Input Text: akarshan
# Target Text: आकर्षण
# Predicted Text: एग्लेइया
#
# Input Text: akeel
# Target Text: अकील
# Predicted Text: फजल
#
# Input Text: akhila
# Target Text: अखिला
# Predicted Text:
#
# Input Text: akila daily
# Target Text: अकीला डेल्ही
# Predicted Text:  घर
#
# Input Text: akmal
# Target Text: अकमाल
# Predicted Text: अकीला
#
# Input Text: alan wells
# Target Text: ऐलन वेल्स
# Predicted Text: दुश्मनी ऐलन
#
# Input Text: alarice
# Target Text: एलेराइस
# Predicted Text:
#
# Input Text: alaska
# Target Text: अलास्का
# Predicted Text:
#
# Input Text: albertsons
# Target Text: एल्बर्टसन्स
# Predicted Text: अनुसूया
#
# Input Text: alboran
# Target Text: अल्बोरान
# Predicted Text: सोहनी
#
# Input Text: alexavier
# Target Text: अलेक्जेवियर
# Predicted Text: अपने
#
# Input Text: alima
# Target Text: अलीमा
# Predicted Text: अल्बोरान
#
# Input Text: allegheny
# Target Text: अल्लेगहेन्ये
# Predicted Text: अलीमा
#
# Input Text: allstate
# Target Text: ऑलस्टेट
# Predicted Text: अरिवलगन
#
# Input Text: ally
# Target Text: एली
# Predicted Text: अल्लेगहेन्ये
#
# Input Text: aloysius
# Target Text: अलोयसियस
# Predicted Text: एर्नी
#
# Input Text: aluabari road
# Target Text: अलुयाबरी रोड
# Predicted Text: एली भद्राचलम
#
# Input Text: amalie
# Target Text: एमेली
# Predicted Text:
#
# Input Text: amaryllis
# Target Text: एमेरीलिस
# Predicted Text: रोड
#
# Input Text: ambala
# Target Text: अंबाला
# Predicted Text: अभिनन्दा
#
# Input Text: ameeri
# Target Text: अमीरी
# Predicted Text:
#
# Input Text: american academy of arts and letters fiction award
# Target Text: अमेरिकन अकेडमी ऑफ आर्ट्‍स एण्ड लेटर्स फिक्शन अवार्ड
# Predicted Text: अमीरी आसिफ ऑफ मेरा अस्लाना लेटर्स टारगेट की
#
# Input Text: amrapali
# Target Text: आम्रपाली
# Predicted Text: फिक्शन
#
# Input Text: amrit
# Target Text: अमृत
# Predicted Text: आम्रपाली
#
# Input Text: anal
# Target Text: अनल
# Predicted Text: अवनींद्र
#
# Input Text: andha intequam
# Target Text: अंधा इंतेक़ाम
# Predicted Text: अमृत इंतेक़ाम
#
# Input Text: angelica
# Target Text: एंजेलिका
# Predicted Text: एंजेलिका
#
# Input Text: anilatmaj
# Target Text: अनिलात्मज
# Predicted Text: बालासोर
#
# Input Text: anirvaan
# Target Text: अनिर्वाण
# Predicted Text: बलिल
#
# Input Text: anisaa
# Target Text: अनीसा
# Predicted Text: अनिलात्मज
#
# Input Text: anjum
# Target Text: अंजुम
# Predicted Text: अनिर्वाण
#
# Input Text: annabella
# Target Text: अन्नाबेला
# Predicted Text: कॉड
#
# Input Text: annapurna
# Target Text: अन्नपूर्णा
# Predicted Text: अवतार
#
# Input Text: anthony stuart
# Target Text: एंथनी स्टुआर्ट
# Predicted Text: अंजुम चाड
#
# Input Text: anupshahr
# Target Text: अनुपशहर
# Predicted Text: अन्नाबेला
#
# Input Text: anusooyaa
# Target Text: अनुसूया
# Predicted Text: अन्नाबेला
#
# Input Text: anuvaa
# Target Text: अनुवा
# Predicted Text: मर
#
# Input Text: anwar
# Target Text: अनवर
# Predicted Text: एंथनी
#
# Input Text: apna ghar
# Target Text: अपना घर
# Predicted Text: बसित अलास्का
#
# Input Text: apne dam par
# Target Text: अपने दम पर
# Predicted Text:  डेल्ही अनवर
#
# Input Text: apollo tyres
# Target Text: अपोलो टायर्स
# Predicted Text: पर
#
# Input Text: ara
# Target Text: आरा
# Predicted Text: अपोलो
#
# Input Text: arbon
# Target Text: आर्बन
# Predicted Text: गोपिका
#
# Input Text: archon
# Target Text: आर्कन
# Predicted Text: आरा
#
# Input Text: argheshwar
# Target Text: अर्घेश्वर
# Predicted Text:
#
# Input Text: arivalagan
# Target Text: अरिवलगन
# Predicted Text: आर्कन
#
# Input Text: arnetha
# Target Text: अर्नेठा
# Predicted Text: अर्नेठा
#
# Input Text: arnie
# Target Text: एर्नी
# Predicted Text: भचउ
#
# Input Text: artemas
# Target Text: आर्टेमस
# Predicted Text: ब्रिटिश
#
# Input Text: arya
# Target Text: आर्य
# Predicted Text: अलोयसियस
#
# Input Text: asad
# Target Text: असद
# Predicted Text: अलुयाबरी
#
# Input Text: asahi india
# Target Text: आसही इंडिया
# Predicted Text: आर्टेमस इंडिया
#
# Input Text: asaoti
# Target Text: असौती
# Predicted Text: गए
#
# Input Text: ashantha de mel
# Target Text: अशांथा डे मेल
# Predicted Text: डोबेलार एक आसही
#
# Input Text: ashivan
# Target Text: अशिवन
# Predicted Text: एमेरीलिस
#
# Input Text: asia
# Target Text: आसिया
# Predicted Text: अशांथा
#
# Input Text: asif mohammad
# Target Text: आसिफ मोहम्मद
# Predicted Text: मेल
#
# Input Text: aslana
# Target Text: अस्लाना
# Predicted Text: अकेडमी
#
# Input Text: atchafalaya
# Target Text: अटचाफल्या
# Predicted Text: लियाम्ना
#
# Input Text: athar ali khan
# Target Text: आथर अली खान
# Predicted Text: आसिया द सेंटाइम्स
#
# Input Text: atharvan
# Target Text: अथर्वन
# Predicted Text: ब्लूमबर्ग
#
# Input Text: attacker
# Target Text: अटैकर
# Predicted Text: अटचाफल्या
#
# Input Text: attur
# Target Text: अट्‍टूर
# Predicted Text: आथर
#
# Input Text: aurum
# Target Text: ऑरम
# Predicted Text: अटैकर
#
# Input Text: avani
# Target Text: अवनि
# Predicted Text: बॉन्गाईगांव
#
# Input Text: avanindra
# Target Text: अवनींद्र
# Predicted Text:
#
# Input Text: azraqi
# Target Text: अज़राकी
# Predicted Text: अज़राकी
#
# Input Text: baap beti
# Target Text: बाप बेटी
# Predicted Text: बाप अली
#
# Input Text: baaqir
# Target Text: बाकिर
# Predicted Text: बुक
#
# Input Text: baat ek raat ke
# Target Text: बात एक रात की
# Predicted Text: आशा रात  फिल
#
# Input Text: babel
# Target Text: बाबेल
# Predicted Text: बादशाहनगर
#
# Input Text: badar
# Target Text: बदर
# Predicted Text:
#
# Input Text: badreeprasaad
# Target Text: बद्रीप्रसाद
# Predicted Text: बगावत
#
# Input Text: badshahnagar
# Target Text: बादशाहनगर
# Predicted Text: बाजवा
#
# Input Text: baghawat
# Target Text: बगावत
# Predicted Text: बालक
#
# Input Text: bahuroop
# Target Text: बहुरूप
# Predicted Text:
#
# Input Text: bajwa
# Target Text: बाजवा
# Predicted Text: अकमाल
#
# Input Text: balak dhruv
# Target Text: बालक ध्रुव
# Predicted Text: बेट्स गैरेथ
#
# Input Text: balasor
# Target Text: बालासोर
# Predicted Text: बैंगई
#
# Input Text: balil
# Target Text: बलिल
# Predicted Text: मारीगाँव
#
# Input Text: balqees
# Target Text: बल्कीस
# Predicted Text: बंसी
#
# Input Text: banajit
# Target Text: बनजित
# Predicted Text: डार्ट
#
# Input Text: banff
# Target Text: बन्फ़
# Predicted Text:
#
# Input Text: bangui
# Target Text: बैंगई
# Predicted Text: अछनेरा
#
# Input Text: banke lal
# Target Text: बाँके लाल
# Predicted Text: दम धरम
#
# Input Text: bansi
# Target Text: बंसी
# Predicted Text: जेमा
#
# Input Text: bansilaal
# Target Text: बंसीलाल
# Predicted Text:
#
# Input Text: baragaon
# Target Text: बरागांव
# Predicted Text: पेट्रोब्रस
#
# Input Text: bardoli
# Target Text: बरदोली
# Predicted Text:
#
# Input Text: bareth
# Target Text: बरेथ
# Predicted Text: बरचा
#
# Input Text: barhan
# Target Text: बरहान
# Predicted Text: एल्बर्टसन्स
#
# Input Text: basit ali
# Target Text: बसित अली
# Predicted Text: भोली द
#
# Input Text: batool
# Target Text: बतूल
# Predicted Text:
#
# Input Text: batra
# Target Text: बत्रा
# Predicted Text: भडकमकर
#
# Input Text: bayana junction
# Target Text: बयाना जंक्शन
# Predicted Text: भाई जंक्शन
#
# Input Text: bearn
# Target Text: बर्न
# Predicted Text: कुंती
#
# Input Text: bees saal baad
# Target Text: बीस साल बाद
# Predicted Text: भामिनी खान बेटी
#
# Input Text: behake kadam
# Target Text: बहके कदम
# Predicted Text: भंडारदरा धडवईवाले
#
# Input Text: bekhbar
# Target Text: बेखबर
# Predicted Text: भटपुर
#
# Input Text: belgaum
# Target Text: बेलगॉम
# Predicted Text: असौती
#
# Input Text: berchha
# Target Text: बरचा
# Predicted Text: भेल
#
# Input Text: beti
# Target Text: बेटी
# Predicted Text: अली
#
# Input Text: bhaarateey
# Target Text: भारतीय
# Predicted Text: लुथेरान
#
# Input Text: bhachau
# Target Text: भचउ
# Predicted Text: अशिवन
#
# Input Text: bhadkamkar
# Target Text: भडकमकर
# Predicted Text: भोंगीर
#
# Input Text: bhadrachalam
# Target Text: भद्राचलम
# Predicted Text:
#
# Input Text: bhagyawati
# Target Text: भाग्यवती
# Predicted Text: भूधर
#
# Input Text: bhai saheb
# Target Text: भाई साहब
# Predicted Text:  बाद
#
# Input Text: bhamini
# Target Text: भामिनी
# Predicted Text: बिक्रम
#
# Input Text: bhandardara
# Target Text: भंडारदरा
# Predicted Text: बिल्हौर
#
# Input Text: bhanuprasad
# Target Text: भानुप्रसाद
# Predicted Text: ब्लू
#
# Input Text: bhatpur
# Target Text: भटपुर
# Predicted Text: सैम्मी
#
# Input Text: bhedi lutera
# Target Text: भेदी लुटेरा
# Predicted Text: मस्जिद अथर्वन
#
# Input Text: bhel
# Target Text: भेल
# Predicted Text: मियंदाद
#
# Input Text: bheroolaal
# Target Text: भेरूलाल
# Predicted Text: क्रैनफील्ड
#
# Input Text: bhilainagar
# Target Text: भिलाईनगर
# Predicted Text:
#
# Input Text: bhildi
# Target Text: भीलड़ी
# Predicted Text: बूट
#
# Input Text: bholi
# Target Text: भोली
# Predicted Text: पॉलिश
#
# Input Text: bhongir
# Target Text: भोंगीर
# Predicted Text: ऑरम
#
# Input Text: bhootnath
# Target Text: भूतनाथ
# Predicted Text: अवनि
#
# Input Text: bhudhar
# Target Text: भूधर
# Predicted Text: बॉजमेन
#
# Input Text: bhuranyu
# Target Text: भूरण्यु
# Predicted Text:
#
# Input Text: bichia
# Target Text: बिछिया
# Predicted Text: ब्रेंडन
#
# Input Text: bikram
# Target Text: बिक्रम
# Predicted Text:
#
# Input Text: bilhaur
# Target Text: बिल्हौर
# Predicted Text:
#
# Input Text: bisla
# Target Text: बिस्ला
# Predicted Text:
#
# Input Text: bismarck
# Target Text: बिस्मार्क
# Predicted Text: बाकिर
#
# Input Text: bloomberg tower
# Target Text: ब्लूमबर्ग टॉवर
# Predicted Text: बाबेल साल
#
# Input Text: blue dart
# Target Text: ब्लू डार्ट
# Predicted Text: बदर ब्रूक्स
#
# Input Text: bombay masjid
# Target Text: बॉम्बे मस्जिद
# Predicted Text: टॉवर बद्रीप्रसाद
#
# Input Text: bombay war
# Target Text: बॉम्बे वार
# Predicted Text: टॉवर ब्रेकन
#
# Input Text: bongaigaon
# Target Text: बॉन्गाईगांव
# Predicted Text: ब्रूस
#
# Input Text: boot polish
# Target Text: बूट पॉलिश
# Predicted Text: बुदालुर अंधा
#
# Input Text: bozeman
# Target Text: बॉजमेन
# Predicted Text:
#
# Input Text: bracken
# Target Text: ब्रेकन
# Predicted Text: वार
#
# Input Text: brazosport
# Target Text: ब्राझोस्पोर्ट
# Predicted Text:
#
# Input Text: brendon bracewell
# Target Text: ब्रेंडन ब्रेसवेल
# Predicted Text: क्रिस्टी सोहनी
#
# Input Text: british book awards
# Target Text: ब्रिटिश बुक अवार्ड्‍स
# Predicted Text:   चाइना
#
# Input Text: brookes
# Target Text: ब्रूक्स
# Predicted Text: कैडमियम
#
# Input Text: bruce medal
# Target Text: ब्रूस मेडल
# Predicted Text: बल्कीस मेडल
#
# Input Text: budalur
# Target Text: बुदालुर
# Predicted Text: कैला
#
# Input Text: bunny hop
# Target Text: बनी हॉप
# Predicted Text: कैमिला अखिला
#
# Input Text: burnett
# Target Text: बरनेट
# Predicted Text: वतन
#
# Input Text: burrows
# Target Text: बॉरोज
# Predicted Text: कार्सन
#
# Input Text: bushra
# Target Text: बुशरा
# Predicted Text: कास्पियन
#
# Input Text: cadmium
# Target Text: कैडमियम
# Predicted Text: सेरेन्डॉन
#
# Input Text: caitir
# Target Text: कैतिर
# Predicted Text: कैस्किल
#
# Input Text: cala
# Target Text: कैला
# Predicted Text: मैक्रॉनिक्स
#
# Input Text: camila
# Target Text: कैमिला
# Predicted Text: सेंटाइम्स
#
# Input Text: cape cod
# Target Text: केप कॉड
# Predicted Text: बॉम्बे सेंट्रल
#
# Input Text: cape maclear
# Target Text: केप मैकलियर
# Predicted Text: बॉम्बे मिशिगन
#
# Input Text: caraf
# Target Text: कैराफ
# Predicted Text: एथेल्डा
#
# Input Text: carr
# Target Text: कार
# Predicted Text: चाहा
#
# Input Text: carson
# Target Text: कार्सन
# Predicted Text: चक्रपाणि
#
# Input Text: caspian
# Target Text: कास्पियन
# Predicted Text: बंसीलाल
#
# Input Text: cathy betts
# Target Text: कॅथे बेट्स
# Predicted Text: चमिंडा सोहनी
#
# Input Text: catskill
# Target Text: कैस्किल
# Predicted Text: फेरोक
#
# Input Text: centimes
# Target Text: सेंटाइम्स
# Predicted Text: मंजरी
#
# Input Text: central michigan university
# Target Text: सेंट्रल मिशिगन यूनिवर्सिटी
# Predicted Text:   यूनिवर्सिटी
#
# Input Text: chaad
# Target Text: चाड
# Predicted Text:
#
# Input Text: chabbra
# Target Text: छाबड़ा
# Predicted Text: लीट्रिक्स
#
# Input Text: chaha
# Target Text: चाहा
# Predicted Text: अन्नाबेला
#
# Input Text: chainwa
# Target Text: चैनवा
# Predicted Text: लकी
#
# Input Text: chakrapani
# Target Text: चक्रपाणि
# Predicted Text:
#
# Input Text: chakravarty rajagopalachari
# Target Text: चक्रवर्ती राजगोपालाचारी
# Predicted Text: चंद्रगुप्त
#
# Input Text: chaksu
# Target Text: चाकसू
# Predicted Text: अचिंद्र
#
# Input Text: chaminda vaas
# Target Text: चमिंडा वास
# Predicted Text: बुद्धिका डार्विन
#
# Input Text: chamomile
# Target Text: कैमोमाइल
# Predicted Text: चारुशीला
#
# Input Text: champaka ramanayake
# Target Text: चंपका रामनायक
# Predicted Text: बहके
#
# Input Text: chandan ka palna
# Target Text: चंदन का पालना
# Predicted Text:  का लालमणि
#
# Input Text: chandragupta
# Target Text: चंद्रगुप्त
# Predicted Text:
#
# Input Text: chaparmukh junction
# Target Text: चपरमुख जंक्शन
# Predicted Text:  समरसाइड
#
# Input Text: chaphekar
# Target Text: चाफेकर
# Predicted Text: ग्रिडको
#
# Input Text: charitha buddhika
# Target Text: चरिथा बुद्धिका
# Predicted Text:  शुब
#
# Input Text: charles darwin
# Target Text: चार्ल्स डार्विन
# Predicted Text:  एडमिरैल्टी
#
# Input Text: charusheela
# Target Text: चारुशीला
# Predicted Text:
#
# Input Text: chester
# Target Text: चेस्टर
# Predicted Text: हाउस
#
# Input Text: chichagof
# Target Text: चिचागॉफ़
# Predicted Text: रिवर
#
# Input Text: chikmangloor
# Target Text: चिकमंगलूर
# Predicted Text: कोलम्बिया
#
# Input Text: china finance online
# Target Text: चाइना फ़ाइनेंस ऑनलाइन
# Predicted Text: अवार्ड्‍स भाग्यवती कम्फर्ट
#
# Input Text: china grentech corporation limited
# Target Text: चाइना ग्रेन्टेक कॉर्पोरेशन लिमिटेड
# Predicted Text: अवार्ड्‍स कॉम्पटन  केप
#
# Input Text: chinna
# Target Text: चिन्ना
# Predicted Text: क्रूक
#
# Input Text: chinnar reservoir
# Target Text: चिन्नार रिज़रवायर
# Predicted Text: कहानी लिमिटेड
#
# Input Text: chitahra
# Target Text: चितहरा
# Predicted Text: कॉस्को
#
# Input Text: chor chor
# Target Text: चोर चोर
# Predicted Text: रिज़रवायर रिज़रवायर
#
# Input Text: chordophone
# Target Text: कॉरडोफोन
# Predicted Text: क्रेग
#
# Input Text: christy hefner
# Target Text: क्रिस्टी हैन्फ़र
# Predicted Text: ईवंस
#
# Input Text: chubb
# Target Text: शुब
# Predicted Text: हार्से
#
# Input Text: clara
# Target Text: क्लारा
# Predicted Text: हाईलैंड्स
#
# Input Text: clarence
# Target Text: क्लारेंस
# Predicted Text: दैन‍िक
#
# Input Text: clayland
# Target Text: क्लेलैंड
# Predicted Text: हॉक
#
# Input Text: cleta
# Target Text: क्लेटा
# Predicted Text: महात्मा
#
# Input Text: cobalt
# Target Text: कोबाल्ट
# Predicted Text: सब
#
# Input Text: coborne
# Target Text: कॉबॉर्न
# Predicted Text: सिपहिया
#
# Input Text: collis king
# Target Text: कॉलिस किंग
# Predicted Text: रानी किंग
#
# Input Text: colorado kettle river
# Target Text: कोलोरैडो केटल रिवर
# Predicted Text: हिम्मतवाली गुरु डेलविले
#
# Input Text: columbia
# Target Text: कोलम्बिया
# Predicted Text: बैपटिस्ट
#
# Input Text: comfort
# Target Text: कम्फर्ट
# Predicted Text: दरबान
#
# Input Text: compton crook award
# Target Text: कॉम्पटन क्रूक अवार्ड
# Predicted Text:   की
#
# Input Text: cormac
# Target Text: कॉर्मेक
# Predicted Text: डैरिन
#
# Input Text: cosco
# Target Text: कॉस्को
# Predicted Text: गॉ
#
# Input Text: craig evans
# Target Text: क्रेग ईवंस
# Predicted Text: बिस्ला
#
# Input Text: cranfield university
# Target Text: क्रैनफील्ड यूनिवर्सिटी
# Predicted Text: डैरन यूनिवर्सिटी
#
# Input Text: credit susse
# Target Text: क्रेडिट सुसे
# Predicted Text:  डेरिन
#
# Input Text: cricket
# Target Text: क्रिकेट
# Predicted Text: मुर्रे
#
# Input Text: cricketer
# Target Text: क्रिकेटर
# Predicted Text:
#
# Input Text: cybille
# Target Text: सायबिल
# Predicted Text: जयप्रकाश
#
# Input Text: cyprus
# Target Text: सायप्रस
# Predicted Text: नारायण
#
# Input Text: dabolim
# Target Text: दबोलिम
# Predicted Text:
#
# Input Text: dainik janambhumi
# Target Text: दैन‍िक जन्मभूमि
# Predicted Text: डेविड
#
# Input Text: dak babu
# Target Text: डाक बाबू
# Predicted Text: डी खंडूर
#
# Input Text: daku aur mahatma
# Target Text: डाकू और महात्मा
# Predicted Text: डाकू और
#
# Input Text: daku hasina
# Target Text: डाकू हसीना
# Predicted Text: डाकू कोरी
#
# Input Text: daku rani himmatwali
# Target Text: डाकू रानी हिम्मतवाली
# Predicted Text: डाकू बिसब्रोएक दीपमाला
#
# Input Text: dalauda
# Target Text: दलौदा
# Predicted Text: देखा
#
# Input Text: daleville baptist
# Target Text: डेलविले बैपटिस्ट
# Predicted Text:  प्यास
#
# Input Text: damaad
# Target Text: दामाद
# Predicted Text: कैंनटॉनमेंट
#
# Input Text: dang
# Target Text: डंग
# Predicted Text: डेलोरेस
#
# Input Text: darban
# Target Text: दरबान
# Predicted Text: ख़ार्का
#
# Input Text: darin
# Target Text: डैरिन
# Predicted Text: डेमी
#
# Input Text: darren gough
# Target Text: डॉरेन गॉ
# Predicted Text: हैं
#
# Input Text: darren sammy
# Target Text: डैरन सैम्मी
# Predicted Text: हैं मंज़र
#
# Input Text: darrin murray
# Target Text: डेरिन मुर्रे
# Predicted Text: डेरिक जोसि
#
# Input Text: darwaza
# Target Text: दरवाज़ा
# Predicted Text: जंगल
#
# Input Text: dasha
# Target Text: डैश
# Predicted Text: परदेस
#
# Input Text: david terbrugge
# Target Text: डेविड टर्ब्रग
# Predicted Text: देस्वाल डेस्वेल
#
# Input Text: de zeven provincien
# Target Text: डी ज़ेवेन प्रोविंसियन
# Predicted Text: एक  फ़ाइनेंस
#
# Input Text: deepabali
# Target Text: दीपाबाली
# Predicted Text:
#
# Input Text: deepamala
# Target Text: दीपमाला
# Predicted Text: देवप्रयाग
#
# Input Text: dekha jayega
# Target Text: देखा जाएगा
# Predicted Text: कत्तौरा क्रिस्टी
#
# Input Text: delhi cantonment
# Target Text: डेल्ही कैंनटॉनमेंट
# Predicted Text:  मैथ्यूज
#
# Input Text: delores
# Target Text: डेलोरेस
# Predicted Text: काँटा
#
# Input Text: demi moore
# Target Text: डेमी मूर
# Predicted Text: भारतीय अचिंद्र
#
# Input Text: derick
# Target Text: डेरिक
# Predicted Text: केविन
#
# Input Text: des pardes
# Target Text: देस परदेस
# Predicted Text: वीर
#
# Input Text: deswal
# Target Text: देस्वाल
# Predicted Text: धोबी
#
# Input Text: deswell
# Target Text: डेस्वेल
# Predicted Text:
#
# Input Text: deuel
# Target Text: डूएल
# Predicted Text:
#
# Input Text: deuskar
# Target Text: देऊसकर
# Predicted Text: कुफ़्रा
#
# Input Text: devinderpal
# Target Text: देविंदरपाल
# Predicted Text: बॉरोज
#
# Input Text: devnarayan
# Target Text: देवनारायण
# Predicted Text: डिएर्ड्रा
#
# Input Text: devprayag
# Target Text: देवप्रयाग
# Predicted Text:
#
# Input Text: devvrat
# Target Text: देवव्रत
# Predicted Text: लक्ष्मीश्री
#
# Input Text: dhadvaiwale
# Target Text: धडवईवाले
# Predicted Text: दिलवर
#
# Input Text: dham
# Target Text: धाम
# Predicted Text: ध्रुव
#
# Input Text: dhamkee
# Target Text: धमकी
# Predicted Text: बुशरा
#
# Input Text: dharam kanta
# Target Text: धरम काँटा
# Predicted Text: प्राइज़
#
# Input Text: dharam veer
# Target Text: धरम वीर
# Predicted Text: प्राइज़ दीपा
#
# Input Text: dharangaon
# Target Text: धरनगांव
# Predicted Text: दो
#
# Input Text: dhobi doctor
# Target Text: धोबी डॉक्टर
# Predicted Text: दोइवाला फिल
#
# Input Text: dhriti
# Target Text: धृति
# Predicted Text: दोनघ
#
# Input Text: dhumr
# Target Text: धूम्र
# Predicted Text: ड्रेक्सिस
#
# Input Text: dhumravarn
# Target Text: धुम्रवर्ण
# Predicted Text: लिब्रेस
#
# Input Text: dierdra
# Target Text: डिएर्ड्रा
# Predicted Text: बनजित
#
# Input Text: diksha
# Target Text: दीक्षा
# Predicted Text: खुर्द
#
# Input Text: dilawar
# Target Text: दिलवर
# Predicted Text: लिनाएव
#
# Input Text: dilber
# Target Text: दिलबर
# Predicted Text:
#
# Input Text: dimple
# Target Text: डिंपल
# Predicted Text: कैराफ
#
# Input Text: dipa
# Target Text: दीपा
# Predicted Text: इदाक्क्ड़
#
# Input Text: dishman
# Target Text: दिश्मन
# Predicted Text: अनीसा
#
# Input Text: do qaidi
# Target Text: दो कैदी
# Predicted Text: ईस्नर
#
# Input Text: dobbelaar
# Target Text: डोबेलार
# Predicted Text: जान
#
# Input Text: doiwala
# Target Text: दोइवाला
# Predicted Text: एल्बुर्ज़
#
# Input Text: dominion
# Target Text: डोमिनियन
# Predicted Text: बर्न
#
# Input Text: donagh
# Target Text: दोनघ
# Predicted Text: एलिज़ाबेथ
#
# Input Text: doyen
# Target Text: डोएन
# Predicted Text: डोल
#
# Input Text: dozakh
# Target Text: दोज़ख
# Predicted Text:
#
# Input Text: draxis health
# Target Text: ड्रेक्सिस हेल्थ
# Predicted Text: एण्डीवर
#
# Input Text: dudhani
# Target Text: दूधानी
# Predicted Text: इवेलिया
#
# Input Text: dudhia khurd
# Target Text: दूधिया खुर्द
# Predicted Text:  इंजीनियरिंग
#
# Input Text: duduk
# Target Text: डुदुक
# Predicted Text:
#
# Input Text: dundlod
# Target Text: दुंदलोद
# Predicted Text: जोगराज
#
# Input Text: dushmani
# Target Text: दुश्मनी
# Predicted Text: राजगोपालाचारी
#
# Input Text: edakkad
# Target Text: इदाक्क्ड़
# Predicted Text: फैदी
#
# Input Text: eenadu
# Target Text: इनाडू
# Predicted Text: फैज़ुलापुर
#
# Input Text: eisner awards
# Target Text: ईस्नर अवार्ड्‍स
# Predicted Text:  चाइना
#
# Input Text: ek jaan hai hum
# Target Text: एक जान हैं हम
# Predicted Text: रात फौलाद अशांथा द
#
# Input Text: elburz
# Target Text: एल्बुर्ज़
# Predicted Text:
#
# Input Text: electra
# Target Text: इलेक्ट्रा
# Predicted Text: फेडोरा
#
# Input Text: elias
# Target Text: इलियास
# Predicted Text: बरागांव
#
# Input Text: elizabeth doll
# Target Text: एलिज़ाबेथ डोल
# Predicted Text: फ़िलीस बरदोली
#
# Input Text: emerson
# Target Text: इमर्सन
# Predicted Text: फिनलैंडिया
#
# Input Text: emir
# Target Text: एमिर
# Predicted Text: फकीहाह
#
# Input Text: endeavour
# Target Text: एण्डीवर
# Predicted Text: कैमोमाइल
#
# Input Text: eolande
# Target Text: इओलैंड
# Predicted Text: फियोरेंज़ा
#
# Input Text: ethelda
# Target Text: एथेल्डा
# Predicted Text: ज्वालामुखी
#
# Input Text: evelia
# Target Text: इवेलिया
# Predicted Text: मेरीकोपा
#
# Input Text: exfo electro-optical engineering
# Target Text: ईएक्सएफ़ओ इलेक्ट्रो-ऑप्टिकल इंजीनियरिंग
# Predicted Text: प्रवीण मंजरी
#
# Input Text: exports
# Target Text: एक्सपोर्ट्स
# Predicted Text:
#
# Input Text: fadi
# Target Text: फैदी
# Predicted Text:
#
# Input Text: faiq
# Target Text: फै़क
# Predicted Text: लीट्रिक्स
#
# Input Text: faizullapur
# Target Text: फैज़ुलापुर
# Predicted Text: रात
#
# Input Text: fakeehah
# Target Text: फकीहाह
# Predicted Text: बायोटेक
#
# Input Text: family of god
# Target Text: फ़ैमिली ऑफ गॉड
# Predicted Text: गजानन ऑफ कुसुमाधिराज
#
# Input Text: farlington redoubt
# Target Text: फार्लिंगटन रीडाउट
# Predicted Text: गंडक
#
# Input Text: faulad
# Target Text: फौलाद
# Predicted Text: अनुवा
#
# Input Text: fedora
# Target Text: फेडोरा
# Predicted Text: हॉप्किंस
#
# Input Text: felis shelf
# Target Text: फ़िलीस श्चेल्फी
# Predicted Text: क्रुगर कैदी
#
# Input Text: ferdinand
# Target Text: फर्डीनांड
# Predicted Text: बॉयकॉट
#
# Input Text: ferok
# Target Text: फेरोक
# Predicted Text:
#
# Input Text: fifty fifty
# Target Text: फिफ्टी फिफ्टी
# Predicted Text: फॉर फॉर
#
# Input Text: finlandia prize for literature
# Target Text: फिनलैंडिया प्राइज़ फॉर लिट्रेचर
# Predicted Text: चार्ल्स अफसाना मुहासिन कैला
#
# Input Text: fiorenza
# Target Text: फियोरेंज़ा
# Predicted Text: द्वार
#
# Input Text: flora
# Target Text: फ्लोरा
# Predicted Text: अब्दुल
#
# Input Text: forbesganj
# Target Text: फोर्ब्सगंज
# Predicted Text: अदित्या
#
# Input Text: fort assiniboine
# Target Text: फोर्ट एसीनिबोइन
# Predicted Text: फोर्ट क्लेलैंड
#
# Input Text: fort benghisa
# Target Text: फोर्ट बेंघिसा
# Predicted Text: फोर्ट नंबर
#
# Input Text: fort bokar
# Target Text: फोर्ट बोकर
# Predicted Text: फोर्ट द
#
# Input Text: fort clark
# Target Text: फोर्ट क्लार्क
# Predicted Text: फोर्ट फ़ाइनेंस
#
# Input Text: fort columbia
# Target Text: फोर्ट कोलंबिया
# Predicted Text: फोर्ट बैपटिस्ट
#
# Input Text: fort dauphin
# Target Text: फोर्ट डॉफिन
# Predicted Text: फोर्ट
#
# Input Text: fort honswijk
# Target Text: फोर्ट हॉन्सविज़्क
# Predicted Text: फोर्ट माइक्रोसिस्टम
#
# Input Text: fort manoel
# Target Text: फोर्ट मैनोएल
# Predicted Text: फोर्ट
#
# Input Text: fort marlborough
# Target Text: फोर्ट मार्लबोरॉ
# Predicted Text: फोर्ट ग्रिफिथ्स
#
# Input Text: fort smith
# Target Text: फोर्ट स्मिथ
# Predicted Text: फोर्ट
#
# Input Text: fort tregantle
# Target Text: फोर्ट ट्रेगैन्टल
# Predicted Text: फोर्ट
#
# Input Text: fort wayne
# Target Text: फोर्ट वेन
# Predicted Text: फोर्ट हैन्फ़र
#
# Input Text: furkating junction
# Target Text: फर्कटिंग जंक्शन
# Predicted Text: ग्रुप जंक्शन
#
# Input Text: fusaylah
# Target Text: फज़ेलाह
# Predicted Text: पिनॉल्ट
#
# Input Text: gagroli
# Target Text: गगरोली
# Predicted Text: पेडर
#
# Input Text: gahmar
# Target Text: गेहमर
# Predicted Text: गुडालुपे
#
# Input Text: gajadant
# Target Text: गजदंत
# Predicted Text: बेखबर
#
# Input Text: gajanan
# Target Text: गजानन
# Predicted Text:
#
# Input Text: gamini perera
# Target Text: जेमिनी परेरा
# Predicted Text: पूजित
#
# Input Text: gandak
# Target Text: गंडक
# Predicted Text: बरेथ
#
# Input Text: ganeshvar
# Target Text: गणेश्वर
# Predicted Text:
#
# Input Text: ganga
# Target Text: गंगा
# Predicted Text: जॉर्ज
#
# Input Text: gareth
# Target Text: गैरेथ
# Predicted Text: आदमखोर
#
# Input Text: gareth hopkins
# Target Text: गैरेथ हॉप्किंस
# Predicted Text: आदमखोर डैरन
#
# Input Text: garnett kruger
# Target Text: गर्नेट क्रुगर
# Predicted Text: प्यास आम्रपाली
#
# Input Text: gauloise
# Target Text: गॉलोइस
# Predicted Text: हीर
#
# Input Text: gaureeshankar
# Target Text: गौरीशंकर
# Predicted Text: राघवेंद्र
#
# Input Text: gavotte
# Target Text: गैवोट
# Predicted Text: बुर्ज
#
# Input Text: geoff boycott
# Target Text: जिऑफ बॉयकॉट
# Predicted Text:  हजराह
#
# Input Text: george bernard shaw
# Target Text: जॉर्ज बर्नार्ड शॉ
# Predicted Text: फेम  हमीद
#
# Input Text: george van biesbroeck prize
# Target Text: जॉर्ज वैन बिसब्रोएक प्राइज़
# Predicted Text: फेम जीनी महिजुबा अफसाना
#
# Input Text: georgianna
# Target Text: जार्जियाना
# Predicted Text: अर्घेश्वर
#
# Input Text: german
# Target Text: जर्मन
# Predicted Text: हन्नाह
#
# Input Text: ghar dwar
# Target Text: घर द्वार
# Predicted Text: अलास्का हार्टफ़ोर्ड
#
# Input Text: ghaso
# Target Text: घासो
# Predicted Text: हावर्ड
#
# Input Text: ghatam
# Target Text: घातम
# Predicted Text: हार्वी
#
# Input Text: ghauth
# Target Text: गौथ
# Predicted Text: हशीद
#
# Input Text: ghazi
# Target Text: ग़ाज़ी
# Predicted Text:
#
# Input Text: ghorpuri
# Target Text: घोरपुरी
# Predicted Text: सदीकाह
#
# Input Text: ghufayrah
# Target Text: ग़ुफयराह
# Predicted Text: सैलेश
#
# Input Text: ginny
# Target Text: जीनी
# Predicted Text: पतन
#
# Input Text: giriraaj
# Target Text: गिरिराज
# Predicted Text:
#
# Input Text: girna
# Target Text: गिर्ना
# Predicted Text: सलिल
#
# Input Text: gizi
# Target Text: गिज़ी
# Predicted Text: रांझा
#
# Input Text: goa
# Target Text: गोवा
# Predicted Text:
#
# Input Text: godel prize award
# Target Text: गोडल प्राइज़ अवार्ड
# Predicted Text:  अफसाना की
#
# Input Text: gomantak times
# Target Text: गोमंतक टाइम्स
# Predicted Text:  मीर
#
# Input Text: gopika
# Target Text: गोपिका
# Predicted Text: असद
#
# Input Text: govind
# Target Text: गोविन्द
# Predicted Text: वर्ल्ड
#
# Input Text: govindgarh malk
# Target Text: गोविंदगढ़ माल्क
# Predicted Text: सीमांत ह्यूलेट-पैकर्ड
#
# Input Text: graeme porter
# Target Text: ग्रीम पोर्टर
# Predicted Text: टाइम्स हिमालय
#
# Input Text: graeme swann
# Target Text: ग्रीम स्वान
# Predicted Text: टाइम्स अचिंद्र
#
# Input Text: greg matthews
# Target Text: ग्रेग मैथ्यूज
# Predicted Text: हिंदुस्तान फिल
#
# Input Text: gridco
# Target Text: ग्रिडको
# Predicted Text:
#
# Input Text: griffiths
# Target Text: ग्रिफिथ्स
# Predicted Text: शत्रुघ्न
#
# Input Text: grimes
# Target Text: ग्रिम्स
# Predicted Text: हॉलिस
#
# Input Text: grinham
# Target Text: ग्रिनहैम
# Predicted Text:
#
# Input Text: grissom
# Target Text: ग्रिसम
# Predicted Text:
#
# Input Text: grizzly
# Target Text: ग्रिज़ली
# Predicted Text: हसीना
#
# Input Text: groupe pinault print
# Target Text: ग्रुप पिनॉल्ट प्रिंट
# Predicted Text:
#
# Input Text: guadalupe
# Target Text: गुडालुपे
# Predicted Text:
#
# Input Text: guajira
# Target Text: गुआजिरा
# Predicted Text:
#
# Input Text: guarani
# Target Text: गुरानी
# Predicted Text:
#
# Input Text: guddi
# Target Text: गुड्डी
# Predicted Text: अब्दुल
#
# Input Text: guldhar
# Target Text: गुलधर
# Predicted Text:
#
# Input Text: gundardehi
# Target Text: गुणदरदेही
# Predicted Text: ट्रेवेलियन
#
# Input Text: gurgaon
# Target Text: गुड़गाँव
# Predicted Text:
#
# Input Text: guru
# Target Text: गुरु
# Predicted Text: गुरूद्वारा
#
# Input Text: guru dakshina
# Target Text: गुरु दक्षिणा
# Predicted Text: गुरूद्वारा बिस्मार्क
#
# Input Text: guru granth sahib
# Target Text: गुरू ग्रंथ साहिब
# Predicted Text: गुरूद्वारा  ग्रीम
#
# Input Text: gurudwara khandur sahib
# Target Text: गुरूद्वारा खंडूर साहिब
# Predicted Text: जीवन डंग ग्रीम
#
# Input Text: gurudwara likhansar
# Target Text: गुरूद्वारा लिखणसार
# Predicted Text: जीवन अखिला
#
# Input Text: gurudwara thanda burj
# Target Text: गुरूद्वारा ठंडा बुर्ज
# Predicted Text: जीवन  बुक
#
# Input Text: hafizur rahman
# Target Text: हफिज़ुर रहमान
# Predicted Text: इन्दुजा रशीद
#
# Input Text: hailakandi
# Target Text: हलाकांडी
# Predicted Text: इन्दुकला
#
# Input Text: hajrah
# Target Text: हजराह
# Predicted Text:
#
# Input Text: hamid
# Target Text: हमीद
# Predicted Text: एन्टर
#
# Input Text: hamidieh
# Target Text: हैमीडीह
# Predicted Text: ईरान
#
# Input Text: hannah
# Target Text: हन्नाह
# Predicted Text: इतिहास
#
# Input Text: hanumaan
# Target Text: हनुमान
# Predicted Text: चाकसू
#
# Input Text: hartford
# Target Text: हार्टफ़ोर्ड
# Predicted Text: हेरन
#
# Input Text: harvard university
# Target Text: हावर्ड यूनिवर्सिटी
# Predicted Text:  यूनिवर्सिटी
#
# Input Text: harvy
# Target Text: हार्वी
# Predicted Text: जगन्नाथ
#
# Input Text: hashid
# Target Text: हशीद
# Predicted Text: जगदंबा
#
# Input Text: hats' russian war
# Target Text: हैट्स रशियन वार
# Predicted Text:  की ब्रेकन
#
# Input Text: haupango
# Target Text: हॉपैंगो
# Predicted Text:
#
# Input Text: hawwa
# Target Text: हव्वा
# Predicted Text:
#
# Input Text: heer ranjha
# Target Text: हीर रांझा
# Predicted Text: जेम्स जनक
#
# Input Text: hemang badani
# Target Text: हेमंग बदानी
# Predicted Text:
#
# Input Text: hemchand
# Target Text: हेमचंद
# Predicted Text: रीनो
#
# Input Text: henly
# Target Text: हेनली
# Predicted Text:
#
# Input Text: hera
# Target Text: हीरा
# Predicted Text: प्रभात
#
# Input Text: hermes
# Target Text: हर्मीस
# Predicted Text: रेखा
#
# Input Text: hersey
# Target Text: हार्से
# Predicted Text: जेफ
#
# Input Text: hewlett - packard
# Target Text: ह्यूलेट-पैकर्ड
# Predicted Text: बायोटेक  जिमी
#
# Input Text: highlands
# Target Text: हाईलैंड्स
# Predicted Text: हैंड्रिक्स
#
# Input Text: himaalay
# Target Text: हिमालय
# Predicted Text:
#
# Input Text: hindustan lever
# Target Text: हिंदुस्तान लीवर
# Predicted Text: जिनेल
#
# Input Text: hisar
# Target Text: हिसार
# Predicted Text: हाई
#
# Input Text: hoche
# Target Text: हॉक
# Predicted Text: जिवितेश
#
# Input Text: hollis
# Target Text: हॉलिस
# Predicted Text: वॉकर
#
# Input Text: hollywood walk of fame
# Target Text: हॉलीवुड वॉक ऑफ फेम
# Predicted Text: जोकस्ता इंजीनियरिंग ऑफ गुरु
#
# Input Text: house of prayer lutheran
# Target Text: हाउस ऑफ प्रेअर लुथेरान
# Predicted Text:  ऑफ हावर्ड
#
# Input Text: hubayshah
# Target Text: हुबायशाह
# Predicted Text: यार
#
# Input Text: hum sub ustad hain
# Target Text: हम सब उस्ताद हैं
# Predicted Text: साहिब केंट जूदाइज़्म
#
# Input Text: huma
# Target Text: हुमा
# Predicted Text: चौधरी
#
# Input Text: humayun
# Target Text: हुमायूँ
# Predicted Text:
#
# Input Text: huzayl
# Target Text: हुज़ायल
# Predicted Text:
#
# Input Text: ian redpath
# Target Text: इआन रेडपाथ
# Predicted Text: डूएल कली
#
# Input Text: idemitsu kosan
# Target Text: आइडेमित्सु कोसान
# Predicted Text: देऊसकर
#
# Input Text: ikhlas
# Target Text: इखलास
# Predicted Text: कॉर्मेक
#
# Input Text: iki
# Target Text: इकी
# Predicted Text:
#
# Input Text: iliamna
# Target Text: लियाम्ना
# Predicted Text:
#
# Input Text: incredimail
# Target Text: इंक्रेडिमेल
# Predicted Text: फै़क
#
# Input Text: indapurkar
# Target Text: इंदापुरकर
# Predicted Text: कनकप्रिया
#
# Input Text: inderdeep
# Target Text: इन्दरदीप
# Predicted Text: कंचन
#
# Input Text: induja
# Target Text: इन्दुजा
# Predicted Text: देवव्रत
#
# Input Text: indukala
# Target Text: इन्दुकला
# Predicted Text: कैरिन
#
# Input Text: infotech enter
# Target Text: इंफ़ोटेक एन्टर
# Predicted Text:
#
# Input Text: iran ki ek raat
# Target Text: ईरान की एक रात
# Predicted Text: कार्तिक अवार्ड रात
#
# Input Text: itihaas
# Target Text: इतिहास
# Predicted Text: कैसिया
#
# Input Text: izz
# Target Text: इज़्ज़
# Predicted Text:
#
# Input Text: jack heron
# Target Text: जैक हेरन
# Predicted Text:
#
# Input Text: jacqui
# Target Text: जैकी
# Predicted Text: कौस्तव
#
# Input Text: jagannath puri
# Target Text: जगन्नाथ पुरी
# Predicted Text:
#
# Input Text: jagdamba
# Target Text: जगदंबा
# Predicted Text: देवनारायण
#
# Input Text: jahdamah
# Target Text: जहदमाह
# Predicted Text: खहेरा
#
# Input Text: jai
# Target Text: जय
# Predicted Text:
#
# Input Text: jainism
# Target Text: जैनिज़्म
# Predicted Text: खातून
#
# Input Text: jaiprakash narayan
# Target Text: जयप्रकाश नारायण
# Predicted Text: बनी किस्मत
#
# Input Text: james laughlin award
# Target Text: जेम्स लॉफलिन अवार्ड
# Predicted Text:   की
#
# Input Text: janak
# Target Text: जनक
# Predicted Text: खोज
#
# Input Text: janet rino
# Target Text: जेनेट रीनो
# Predicted Text: खुफिया
#
# Input Text: javed miandad
# Target Text: जावेद मियंदाद
# Predicted Text:  महल
#
# Input Text: jay vijay
# Target Text: जय विजय
# Predicted Text:  निज़ामुद्दीन
#
# Input Text: jayasekera
# Target Text: जयसेकरा
# Predicted Text: किंतन
#
# Input Text: jeanne
# Target Text: जीनी
# Predicted Text:
#
# Input Text: jeevan naiya
# Target Text: जीवन नैया
# Predicted Text: जॉन जनक
#
# Input Text: jeevan prabhat
# Target Text: जीवन प्रभात
# Predicted Text: जॉन
#
# Input Text: jeevan rekha
# Target Text: जीवन रेखा
# Predicted Text: जॉन
#
# Input Text: jeff wilson
# Target Text: जेफ विल्सन
# Predicted Text: दर द
#
# Input Text: jemma
# Target Text: जेमा
# Predicted Text: नीदरलैंडन
#
# Input Text: jibran
# Target Text: जिब्रान
# Predicted Text:
#
# Input Text: jimmy hendricks
# Target Text: जिमी हैंड्रिक्स
# Predicted Text:  जिमी
#
# Input Text: jimuta
# Target Text: जिमुता
# Predicted Text: कुंटे
#
# Input Text: jinelle
# Target Text: जिनेल
# Predicted Text: कुसुमाधिराज
#
# Input Text: jivitesh
# Target Text: जिवितेश
# Predicted Text: क्यूशू
#
# Input Text: jocasta
# Target Text: जोकस्ता
# Predicted Text: लालमणि
#
# Input Text: jogi
# Target Text: जोगी
# Predicted Text:
#
# Input Text: jograj
# Target Text: जोगराज
# Predicted Text:
#
# Input Text: john f. kennedy
# Target Text: जॉन एफ. केनेडी
# Predicted Text: सती पत्थर टारगेट
#
# Input Text: john penn
# Target Text: जॉन पेन
# Predicted Text: सती अनुवा
#
# Input Text: jon kent
# Target Text: जॉन केंट
# Predicted Text: लैन्स
#
# Input Text: josie
# Target Text: जोसि
# Predicted Text:
#
# Input Text: judaism
# Target Text: जूदाइज़्म
# Predicted Text: कैतिर
#
# Input Text: jungle king
# Target Text: जंगल किंग
# Predicted Text: डोएन किंग
#
# Input Text: justice choudhary
# Target Text: जस्टिस चौधरी
# Predicted Text:
#
# Input Text: jwalamukhi
# Target Text: ज्वालामुखी
# Predicted Text: लवाटे
#
# Input Text: kaamanaa
# Target Text: कामना
# Predicted Text:
#
# Input Text: kaaran
# Target Text: कारण
# Predicted Text:
#
# Input Text: kachchi kali
# Target Text: कच्ची कली
# Predicted Text: लीट्रिक्स
#
# Input Text: kacia
# Target Text: केसिया
# Predicted Text: लेम्ही
#
# Input Text: kailaash
# Target Text: कैलाश
# Predicted Text: दूधानी
#
# Input Text: kaise kahoon
# Target Text: कैसे कहूँ
# Predicted Text:
#
# Input Text: kalea
# Target Text: कैलिया
# Predicted Text:
#
# Input Text: kamal
# Target Text: कमल
# Predicted Text: लिवरपूल
#
# Input Text: kamesh
# Target Text: कामेश
# Predicted Text: दुंदलोद
#
# Input Text: kamyab
# Target Text: कामयाब
# Predicted Text: कम्युनिटी
#
# Input Text: kanakpriya
# Target Text: कनकप्रिया
# Predicted Text: लॉस
#
# Input Text: kanchan aur ganga
# Target Text: कंचन और गंगा
# Predicted Text: मार्मोल्स और जॉर्ज
#
# Input Text: kanwal
# Target Text: कंवल
# Predicted Text: गए
#
# Input Text: karin
# Target Text: कैरिन
# Predicted Text:
#
# Input Text: kartik
# Target Text: कार्तिक
# Predicted Text:
#
# Input Text: kasia
# Target Text: कैसिया
# Predicted Text: लव
#
# Input Text: katak
# Target Text: कटक
# Predicted Text:
#
# Input Text: kattora
# Target Text: कत्तौरा
# Predicted Text: इन
#
# Input Text: katy
# Target Text: कैटी
# Predicted Text: गोडल
#
# Input Text: kaumudhi
# Target Text: कौमुदी
# Predicted Text: लकी
#
# Input Text: kaustav
# Target Text: कौस्तव
# Predicted Text:
#
# Input Text: keene
# Target Text: कीन
# Predicted Text:
#
# Input Text: kennan
# Target Text: केनन
# Predicted Text: लुकतुके
#
# Input Text: keshihan
# Target Text: केशिहन
# Predicted Text:
#
# Input Text: kevin duers
# Target Text: केविन डुअर्स
# Predicted Text:  इनाडू
#
# Input Text: khahera
# Target Text: खहेरा
# Predicted Text: मादिवन
#
# Input Text: kharqa
# Target Text: ख़ार्का
# Predicted Text:
#
# Input Text: khatoon
# Target Text: खातून
# Predicted Text:
#
# Input Text: khattda
# Target Text: खट्टड़ा
# Predicted Text: महावत
#
# Input Text: khel kismat ka
# Target Text: खेल किस्मत का
# Predicted Text:   का
#
# Input Text: khoj
# Target Text: खोज
# Predicted Text: महाबली
#
# Input Text: khuddar
# Target Text: खुद्दार
# Predicted Text: महिरा
#
# Input Text: khufia mahal
# Target Text: खुफिया महल
# Predicted Text:
#
# Input Text: khuraymah
# Target Text: खुरायमाह
# Predicted Text: मकायला
#
# Input Text: khwaja mir dard
# Target Text: ख्वाजा मीर दर्द
# Predicted Text:  गैरेथ मालायला
#
# Input Text: khwaja nizamuddin chishti
# Target Text: ख्वाजा निज़ामुद्दीन चिस्ती
# Predicted Text:  वर्धक
#
# Input Text: kintan
# Target Text: किंतन
# Predicted Text: छाबड़ा
#
# Input Text: kiranmay
# Target Text: किरण्मय
# Predicted Text: मंगतराम
#
# Input Text: kiril
# Target Text: किरिल
# Predicted Text: मणिमुथर
#
# Input Text: klamath
# Target Text: क्लामथ
# Predicted Text: नित्यसुन्दर
#
# Input Text: konark surya
# Target Text: कोणार्क सूर्य
# Predicted Text: मनीष नज़र
#
# Input Text: koning der nederlanden
# Target Text: कॉनिंग दर नीदरलैंडन
# Predicted Text:  इलेक्ट्रो-ऑप्टिकल मिटेंगे
#
# Input Text: kori
# Target Text: कोरी
# Predicted Text:
#
# Input Text: kristy
# Target Text: क्रिस्टी
# Predicted Text: मार्दव
#
# Input Text: kufra
# Target Text: कुफ़्रा
# Predicted Text:
#
# Input Text: kumari
# Target Text: कुमारी
# Predicted Text: मेरीकोपा
#
# Input Text: kunte
# Target Text: कुंटे
# Predicted Text: मैरीगोल्ड
#
# Input Text: kuntee
# Target Text: कुंती
# Predicted Text:
#
# Input Text: kush
# Target Text: कुश
# Predicted Text: मसाडा
#
# Input Text: kusumaadhiraaj
# Target Text: कुसुमाधिराज
# Predicted Text:
#
# Input Text: kyushu
# Target Text: क्यूशू
# Predicted Text: मतीनदास
#
# Input Text: laalamani
# Target Text: लालमणि
# Predicted Text: फै़क
#
# Input Text: lagu
# Target Text: लागू
# Predicted Text: फकीहाह
#
# Input Text: lahore fort
# Target Text: लाहौर फोर्ट
# Predicted Text:  फोर्ट
#
# Input Text: lakshmishree
# Target Text: लक्ष्मीश्री
# Predicted Text:
#
# Input Text: lal kunwar
# Target Text: लाल कुँवर
# Predicted Text: धरम मीरा
#
# Input Text: lal patthar
# Target Text: लाल पत्थर
# Predicted Text: धरम अमीरी
#
# Input Text: lalaatikaa
# Target Text: ललाटिका
# Predicted Text: मेहरुन्निसा
#
# Input Text: lalan
# Target Text: ललन
# Predicted Text:
#
# Input Text: lance klusener
# Target Text: लैन्स क्लूजनर
# Predicted Text: मैलोडियन मेंगक्वांग
#
# Input Text: landler
# Target Text: लैंडर
# Predicted Text: श्चेल्फी
#
# Input Text: larissa
# Target Text: लैरीसा
# Predicted Text: मुक़द्दर
#
# Input Text: latona
# Target Text: लैटोना
# Predicted Text: फर्डीनांड
#
# Input Text: lawaate
# Target Text: लवाटे
# Predicted Text: राजगोपालाचारी
#
# Input Text: lawrence school
# Target Text: लॉरेंस स्कूल
# Predicted Text: पाइरिस मिलन
#
# Input Text: layyah
# Target Text: लय्याह
# Predicted Text: माइकल
#
# Input Text: leatrix
# Target Text: लीट्रिक्स
# Predicted Text: माइक
#
# Input Text: lebanon
# Target Text: लेबनॉन
# Predicted Text: वास
#
# Input Text: leelaaraam
# Target Text: लीलाराम
# Predicted Text:
#
# Input Text: lemhi
# Target Text: लेम्ही
# Predicted Text: बरेथ
#
# Input Text: liberace
# Target Text: लिब्रेस
# Predicted Text: प्रवीण
#
# Input Text: light house
# Target Text: लाइट हाउस
# Predicted Text:
#
# Input Text: lilianna
# Target Text: लिलियाना
# Predicted Text: बायोटेक
#
# Input Text: linaeve
# Target Text: लिनाएव
# Predicted Text: फोर्ट
#
# Input Text: lincoln university
# Target Text: लिंकन यूनिवर्सिटी
# Predicted Text: मनुहार यूनिवर्सिटी
#
# Input Text: lion
# Target Text: लायन
# Predicted Text: सेंटाइम्स
#
# Input Text: liverpool community
# Target Text: लिवरपूल कम्युनिटी
# Predicted Text:  दो
#
# Input Text: lokmat
# Target Text: लोकमत
# Predicted Text:
#
# Input Text: los marmoles
# Target Text: लॉस मार्मोल्स
# Predicted Text: लीट्रिक्स अल्लेगहेन्ये
#
# Input Text: lothringen
# Target Text: लॉथरिंगन
# Predicted Text: सायप्रस
#
# Input Text: love in simla
# Target Text: लव इन शिमला
# Predicted Text:   बायोटेक
#
# Input Text: lucia
# Target Text: ल्यूसी
# Predicted Text: इवेलिया
#
# Input Text: luciano
# Target Text: ल्युसिआनो
# Predicted Text:
#
# Input Text: lucky number
# Target Text: लकी नंबर
# Predicted Text: और
#
# Input Text: luktuke
# Target Text: लुकतुके
# Predicted Text: मुकद्दर
#
# Input Text: maadhavee
# Target Text: माधवी
# Predicted Text:
#
# Input Text: macronix international
# Target Text: मैक्रॉनिक्स इंटरनेशनल
# Predicted Text: जेमिनी मूर्ति
#
# Input Text: madan manjari
# Target Text: मदन मंजरी
# Predicted Text:
#
# Input Text: madhu
# Target Text: मधु
# Predicted Text:
#
# Input Text: madivan
# Target Text: मादिवन
# Predicted Text:
#
# Input Text: mafizur rahman
# Target Text: मफिज़र रहमान
# Predicted Text:  अब्दुल
#
# Input Text: maghavaajit
# Target Text: मघवाजित
# Predicted Text: नैरित
#
# Input Text: mahaashvetaa
# Target Text: महाश्वेता
# Predicted Text: गैवोट
#
# Input Text: mahaavat
# Target Text: महावत
# Predicted Text: नंदा
#
# Input Text: mahabali hanuman
# Target Text: महाबली हनुमान
# Predicted Text: चरिथा
#
# Input Text: mahasweta
# Target Text: महाश्वेता
# Predicted Text: वैन
#
# Input Text: mahijuba
# Target Text: महिजुबा
# Predicted Text: बत्रा
#
# Input Text: mahira
# Target Text: महिरा
# Predicted Text: एक्सेप्शनल
#
# Input Text: mahish
# Target Text: महिश
# Predicted Text: साइंटीफिक
#
# Input Text: mahotsaah
# Target Text: महोत्साह
# Predicted Text: अशरफ
#
# Input Text: mainaa
# Target Text: मैना
# Predicted Text:
#
# Input Text: makayla
# Target Text: मकायला
# Predicted Text:
#
# Input Text: malayala manorama
# Target Text: मालायला मनोरमा
# Predicted Text:  अन्नपूर्णा
#
# Input Text: malpasset dam
# Target Text: मैल्पसेट डैम
# Predicted Text:  डेल्ही
#
# Input Text: mangatraam
# ...
#
# Input Text: romantic india
# Target Text: रोमांटिक इंडिया
# Predicted Text: तिलक इंडिया
#
# Input Text: romesh kaluwitharana
# Target Text: रोमेश कालुविथराणा
# Predicted Text: तिमिन
#
# Input Text: roseanne
# Target Text: रोज़ीन
# Predicted Text: तिरप
#
# Input Text: roshanee
# Target Text: रोशनी
# Predicted Text: तोईयाबे
#
# Input Text: rudy
# Target Text: रुडी
# Predicted Text:
#
# Input Text: rupaiya
# Target Text: रुपैया
# Predicted Text:
#
# Input Text: russell krovi
# Target Text: रसेल क्रोवी
# Predicted Text: टोरी गए
#
# Input Text: saadat
# Target Text: सादात
# Predicted Text: ट्रूडा
#
# Input Text: sach
# Target Text: सच
# Predicted Text:
#
# Input Text: sachche ka bolbala
# Target Text: सच्चे का बोलबाला
# Predicted Text:  वर्धक
#
# Input Text: sachin tendulkar
# Target Text: सचिन तेंडुलकर
# Predicted Text: इन्वेस्टमेंट साल
#
# Input Text: sadiqah
# Target Text: सदीकाह
# Predicted Text: प्लाज़ा
#
# Input Text: saheb
# Target Text: साहब
# Predicted Text: बाद
#
# Input Text: sailaab
# Target Text: सैलाब
# Predicted Text:
#
# Input Text: sailesh
# Target Text: सैलेश
# Predicted Text: उबेजा
#
# Input Text: saint helens fort
# Target Text: सेंट हेलेन्स फोर्ट
# Predicted Text: उमापति नावेद फोर्ट
#
# Input Text: sainte marie
# Target Text: सेंट मेरी
# Predicted Text: डंडी हल
#
# Input Text: saipratap
# Target Text: साईप्रताप
# Predicted Text:
#
# Input Text: sajan
# Target Text: सजन
# Predicted Text:
#
# Input Text: sajeewa de silva
# Target Text: सजीवा डे सिल्वा
# Predicted Text: उत्तर एक
#
# Input Text: sajni
# Target Text: सजनी
# Predicted Text: जाएगा
#
# Input Text: salil ankola
# Target Text: सलिल अंकोला
# Predicted Text: जाएगा चरिथा
#
# Input Text: samaj patan
# Target Text: समाज पतन
# Predicted Text: वर्धा
#
# Input Text: sambad
# Target Text: संबद
# Predicted Text: वेंकटेश
#
# Input Text: sambaran
# Target Text: समबरन
# Predicted Text: वेंकटेश्वर
#
# Input Text: samrendru
# Target Text: समरेंदु
# Predicted Text:
#
# Input Text: san martino
# Target Text: सैन मार्टिनो
# Predicted Text: ख्वाजा ईवंस
#
# Input Text: san paolo imi
# Target Text: सन पेओलो मी
# Predicted Text: ख्वाजा  विशालगढ़
#
# Input Text: sanghera
# Target Text: संघेरा
# Predicted Text: विश्राम
#
# Input Text: sant ravidas ki amar kahani
# Target Text: संत रविदास की अमर कहानी
# Predicted Text:   अवार्ड डंग इमानुएल
#
# Input Text: santos
# Target Text: सेंटोज़
# Predicted Text: वायटिस
#
# Input Text: sarayu
# Target Text: सरयू
# Predicted Text:
#
# Input Text: sareen
# Target Text: सरीन
# Predicted Text: और
#
# Input Text: sariska
# Target Text: सरिस्का
# Predicted Text: वॉक्ले
#
# Input Text: saskatchewan
# Target Text: सैस्कैचवान
# Predicted Text:
#
# Input Text: sati anjani
# Target Text: सती अंजनी
# Predicted Text: महाश्वेता रिज़रवायर
#
# Input Text: sati nagkanaya
# Target Text: सती नागकन्या
# Predicted Text: महाश्वेता भूतनाथ
#
# Input Text: satnam overseas
# Target Text: सतनाम ओवरसीस
# Predicted Text:
#
# Input Text: satyaki
# Target Text: सत्याकि
# Predicted Text: वज़ीरा
#
# Input Text: sau saal baad
# Target Text: सौ साल बाद
# Predicted Text:  खान बेटी
#
# Input Text: saunders
# Target Text: सॉन्डर्स
# Predicted Text: वेडेल
#
# Input Text: scotia sea
# Target Text: स्कॉटिया सी
# Predicted Text:
#
# Input Text: seemaant
# Target Text: सीमांत
# Predicted Text:
#
# Input Text: sekere
# Target Text: सेकरे
# Predicted Text:
#
# Input Text: seliya
# Target Text: सेलिया
# Predicted Text: जस्टिस
#
# Input Text: senegal
# Target Text: सेनेगल
# Predicted Text:
#
# Input Text: seringapatam
# Target Text: सेरिंगापटम
# Predicted Text: यूकॉन
#
# Input Text: sevaaraam
# Target Text: सेवाराम
# Predicted Text: युवराज
#
# Input Text: shaitan
# Target Text: शैतान
# Predicted Text:
#
# Input Text: shake hands
# Target Text: शेक हैंड्‍स
# Predicted Text:  रिज़रवायर
#
# Input Text: shampa
# Target Text: शम्पा
# Predicted Text: ज़लील
#
# Input Text: shamsheer e arab
# Target Text: शमशीर ए अरब
# Predicted Text: ज़ैब
#
# Input Text: shan
# Target Text: शान
# Predicted Text: कैलाश
#
# Input Text: shanghai museum
# Target Text: शंघाई म्युज़ियम
# Predicted Text:  वन
#
# Input Text: shanpaak
# Target Text: शंपाक
# Predicted Text:
#
# Input Text: sharadini
# Target Text: शारदिनी
# Predicted Text:
#
# Input Text: sharon stone
# Target Text: शेरॉन स्टोन
# Predicted Text: लुटेरा कमल
#
# Input Text: shatrughn
# Target Text: शत्रुघ्न
# Predicted Text:
#
# Input Text: shery
# Target Text: शेरी
# Predicted Text:
#
# Input Text: shimane maru
# Target Text: शिमेन मारू
# Predicted Text:  कॉरडोफोन
#
# Input Text: shoaib akhtar
# Target Text: शोएब खान
# Predicted Text:
#
# Input Text: shoeb
# Target Text: शोएब
# Predicted Text:
#
# Input Text: shotput
# Target Text: शॉटपुट
# Predicted Text:
#
# Input Text: shreshth
# Target Text: श्रेष्ठ
# Predicted Text:
#
# Input Text: shridevi
# Target Text: श्रीदेवी
# Predicted Text: कैटी
#
# Input Text: shridhar
# Target Text: श्रीधर
# Predicted Text:
#
# Input Text: shripad
# Target Text: श्रीपद
# Predicted Text:
#
# Input Text: shu'a
# Target Text: शुआ
# Predicted Text:
#
# Input Text: shubhang
# Target Text: शुभांग
# Predicted Text:
#
# Input Text: shungare
# Target Text: शुंगारे
# Predicted Text:
#
# Input Text: shurayh
# Target Text: शुरायह
# Predicted Text:
#
# Input Text: shyaamaa
# Target Text: श्यामा
# Predicted Text:
#
# Input Text: sihlsee
# Target Text: सिहल्सी
# Predicted Text:
#
# Input Text: silvain
# Target Text: सिल्वैन
# Predicted Text:
#
# Input Text: silver standard resources
# Target Text: सिल्वर स्टैंडर्ड रिसोर्सेज़
# Predicted Text:
#
# Input Text: simon katich
# Target Text: साइमन कैटिच
# Predicted Text:
#
# Input Text: sipahiya
# Target Text: सिपहिया
# Predicted Text:
#
# Input Text: siraalee
# Target Text: सिराली
# Predicted Text: वृंदावनेश्वरी
#
# Input Text: siran
# Target Text: सिरन
# Predicted Text:
#
# Input Text: siusan
# Target Text: सिउसन
# Predicted Text:
#
# Input Text: skipper
# Target Text: स्किपर
# Predicted Text:
#
# Input Text: slowman
# Target Text: स्लोमेन
# Predicted Text:
#
# Input Text: sneha
# Target Text: स्नेहा
# Predicted Text: डुअर्स
#
# Input Text: snigdhaa
# Target Text: स्निग्धा
# Predicted Text:
#
# Input Text: sohani
# Target Text: सोहनी
# Predicted Text:
#
# Input Text: sohni
# Target Text: सोहनी
# Predicted Text: दीपा
#
# Input Text: solferino
# Target Text: सोल्फेरिनो
# Predicted Text:
#
# Input Text: som
# Target Text: सोम
# Predicted Text:
#
# Input Text: somakaantaa
# Target Text: सोमकांता
# Predicted Text:
#
# Input Text: southern iron
# Target Text: साउदर्न आयरन
# Predicted Text: खट्टड़ा द
#
# Input Text: sowani
# Target Text: सोवानी
# Predicted Text:
#
# Input Text: sparsh
# Target Text: स्पर्श
# Predicted Text:
#
# Input Text: spathareion museum of the shadow theatre
# Target Text: स्पाथेर‍ियन म्युज़ियम ऑफ द शैडो थ‍िएटर
# Predicted Text:  वन ऑफ आज नावेद
#
# Input Text: stats chippac
# Target Text: स्टेट्सचिपपैक
# Predicted Text:  खुद्दार
#
# Input Text: steve martin
# Target Text: स्टीव मार्टिन
# Predicted Text:  हनुमान
#
# Input Text: stevens
# Target Text: स्टीवन्स
# Predicted Text:
#
# Input Text: stolt-nielsen
# Target Text: स्टॉल्ट निलसन
# Predicted Text:
#
# Input Text: stride arcolab
# Target Text: स्ट्राइड आर्कोलैब
# Predicted Text:  वर्धक
#
# Input Text: subhaashachandr
# Target Text: सुभाषचंद्र
# Predicted Text:
#
# Input Text: suchi
# Target Text: सुचि
# Predicted Text:
#
# Input Text: sudarshan
# Target Text: सुदर्शन
# Predicted Text:
#
# Input Text: suhrewardi
# Target Text: सुहरेवर्दी
# Predicted Text:
#
# Input Text: sujaya
# Target Text: सुजया
# Predicted Text:
#
# Input Text: sukhija
# Target Text: सुखीजा
# Predicted Text: सायप्रस
#
# Input Text: sulaiman
# Target Text: सुलेमान
# Predicted Text:
#
# Input Text: sultanah
# Target Text: सुल्तानाह
# Predicted Text: चिस्ती
#
# Input Text: summerside united methodist
# Target Text: समरसाइड यूनाइटेड मेथोडिस्ट
# Predicted Text:   कुमारी
#
# Input Text: sun microsystems
# Target Text: सन माइक्रोसिस्टम
# Predicted Text:
#
# Input Text: sunopta
# Target Text: सनऑप्टा
# Predicted Text:
#
# Input Text: surgery
# Target Text: सर्जरी
# Predicted Text:
#
# Input Text: susan sarandon
# Target Text: सुज़ेन सेरेन्डॉन
# Predicted Text:
#
# Input Text: suwo
# Target Text: सूवो
# Predicted Text:
#
# Input Text: swan
# Target Text: स्वान
# Predicted Text: क्लामथ
#
# Input Text: syed akhtar imam quadri
# Target Text: सय्यद अख्तर इमाम क़ादरी
# Predicted Text:  दो
#
# Input Text: syndicate bank
# Target Text: सिंडीकेट बैंक
# Predicted Text:
#
# Input Text: talakkad
# Target Text: तलक्कड
# Predicted Text:
#
# Input Text: talika
# Target Text: तालिका
# Predicted Text: खुरायमाह
#
# Input Text: tanuj
# Target Text: तनुज
# Predicted Text:
#
# Input Text: tanwir
# Target Text: तनवीर
# Predicted Text: आचार्यनंदन
#
# Input Text: target
# Target Text: टारगेट
# Predicted Text: विल्सन
#
# Input Text: tariqah
# Target Text: तारि़काह
# Predicted Text:
#
# Input Text: tarulata
# Target Text: तरुलता
# Predicted Text:
#
# Input Text: taryn
# Target Text: टैरिन
# Predicted Text:
#
# Input Text: tata tea
# Target Text: टाटा टी
# Predicted Text:  कैलाश
#
# Input Text: tazwell
# Target Text: टैज़वेल
# Predicted Text:
#
# Input Text: tejaa
# Target Text: तेजा
# Predicted Text:
#
# Input Text: tejaswini
# Target Text: तेजस्विनी
# Predicted Text:
#
# Input Text: tel aviv
# Target Text: तेल अविव
# Predicted Text:
#
# Input Text: tera karam mera dharam
# Target Text: तेरा करम मेरा धरम
# Predicted Text:  धूम्र म्युज़ियम प्राइज़
#
# Input Text: thames valley university
# Target Text: थेम्स वैली यूनिवर्सिटी
# Predicted Text:   यूनिवर्सिटी
#
# Input Text: thar
# Target Text: थार
# Predicted Text:
#
# Input Text: the times of india
# Target Text: द टाइम्स ऑफ इंडिया
# Predicted Text: आज मीर ऑफ इंडिया
#
# Input Text: thuringen
# Target Text: थरिंगन
# Predicted Text:
#
# Input Text: thyra
# Target Text: थायरा
# Predicted Text:
#
# Input Text: tilak
# Target Text: तिलक
# Predicted Text:
#
# Input Text: timin
# Target Text: तिमिन
# Predicted Text:
#
# Input Text: tirap
# Target Text: तिरप
# Predicted Text:
#
# Input Text: toiyabe
# Target Text: तोईयाबे
# Predicted Text:
#
# Input Text: tony
# Target Text: टोनी
# Predicted Text:
#
# Input Text: toofan
# Target Text: तूफान
# Predicted Text: जय
#
# Input Text: torie
# Target Text: टोरी
# Predicted Text:
#
# Input Text: tress
# Target Text: ट्रेसी
# Predicted Text:
#
# Input Text: trevelian
# Target Text: ट्रेवेलियन
# Predicted Text:
#
# Input Text: trinity biotech
# Target Text: ट्रिनिटी बायोटेक
# Predicted Text: कुमारी
#
# Input Text: truda
# Target Text: ट्रूडा
# Predicted Text:
#
# Input Text: truly
# Target Text: ट्रूली
# Predicted Text:
#
# Input Text: trump world tower
# Target Text: ट्रम्प वर्ल्ड टॉवर
# Predicted Text:  चक्र साल
#
# Input Text: tube investment
# Target Text: ट्यूब इन्वेस्टमेंट
# Predicted Text:
#
# Input Text: tungabhadra
# Target Text: तुंगभद्रा
# Predicted Text:
#
# Input Text: two prudential plaza
# Target Text: टू प्रुडेन्शियल प्लाज़ा
# Predicted Text: चितहरा फागुन टर्ब्रग
#
# Input Text: ubeja
# Target Text: उबेजा
# Predicted Text:
#
# Input Text: umapati
# Target Text: उमापति
# Predicted Text: वार
#
# Input Text: ummayyah
# Target Text: उम्मय्याह
# Predicted Text:
#
# Input Text: university of alaska
# Target Text: यूनिवर्सिटी ऑफ अलास्का
# Predicted Text: यूनिवर्सिटी ऑफ बात
#
# Input Text: university of dundee
# Target Text: यूनिवर्सिटी ऑफ डंडी
# Predicted Text: यूनिवर्सिटी ऑफ भानुप्रसाद
#
# Input Text: university of hull
# Target Text: यूनिवर्सिटी ऑफ हल
# Predicted Text: यूनिवर्सिटी ऑफ लागू
#
# Input Text: university of keele
# Target Text: यूनिवर्सिटी ऑफ कीले
# Predicted Text: यूनिवर्सिटी ऑफ स्कूल,
#
# Input Text: university of sunderland
# Target Text: यूनिवर्सिटी ऑफ सुंदरलैंड
# Predicted Text: यूनिवर्सिटी ऑफ
#
# Input Text: urania
# Target Text: यूरेनिया
# Predicted Text:
#
# Input Text: ursala
# Target Text: उर्सला
# Predicted Text:
#
# Input Text: uttar kannada
# Target Text: उत्तर कन्नड़
# Predicted Text: गुड़गाँव दिलबर
#
# Input Text: vajra
# Target Text: वज्र
# Predicted Text: कुँवर
#
# Input Text: valentino
# Target Text: वैलेंटिनो
# Predicted Text:
#
# Input Text: valli
# Target Text: वल्ली
# Predicted Text:
#
# Input Text: van
# Target Text: वन
# Predicted Text: जीनी
#
# Input Text: vanoise
# Target Text: वैनॉइस
# Predicted Text:
#
# Input Text: vardha
# Target Text: वर्धा
# Predicted Text:
#
# Input Text: velaa
# Target Text: वेला
# Predicted Text:
#
# Input Text: venkatesh
# Target Text: वेंकटेश
# Predicted Text:
#
# Input Text: venkateshvar
# Target Text: वेंकटेश्वर
# Predicted Text:
#
# Input Text: veolia environnement
# Target Text: वेओलिया एनवायरमेंट
# Predicted Text:
#
# Input Text: vidya vardhaka sangha high school, bangalore
# Target Text: विद्या वर्धक संघ हाई स्कूल, बैंगलोर
# Predicted Text:  केटल  प्यास
#
# Input Text: vidyut
# Target Text: विद्युत
# Predicted Text:
#
# Input Text: vijaynagar
# Target Text: विजयनगर
# Predicted Text:
#
# Input Text: vimohinee
# Target Text: विमोहिनी
# Predicted Text:
#
# Input Text: viplaav
# Target Text: विप्लाव
# Predicted Text:
#
# Input Text: viresh
# Target Text: विरेश
# Predicted Text:
#
# Input Text: vishalgad
# Target Text: विशालगढ़
# Predicted Text: अछनेरा
#
# Input Text: vishram
# Target Text: विश्राम
# Predicted Text:
#
# Input Text: visisht seva medal
# Target Text: विशिष्ट सेवा मेडल
# Predicted Text:   मेडल
#
# Input Text: vittorio emanuele
# Target Text: विक्टोरियो इमानुएल
# Predicted Text:  कुमारी
#
# Input Text: vrandaavaneshvaree
# Target Text: वृंदावनेश्वरी
# Predicted Text: लैंडर
#
# Input Text: vytis
# Target Text: वायटिस
# Predicted Text:
#
# Input Text: wachhar
# Target Text: वच्चर
# Predicted Text:
#
# Input Text: waite
# Target Text: वैट
# Predicted Text: कैतिर
#
# Input Text: walker museum
# Target Text: वॉकर म्युज़ियम
# Predicted Text:  वन
#
# Input Text: walkley award
# Target Text: वॉक्ले अवार्ड
# Predicted Text:  की
#
# Input Text: walt disney
# Target Text: वॉल्ट डिज़्नी
# Predicted Text:  चेस्टर
#
# Input Text: warner
# Target Text: वार्नर
# Predicted Text: लैरीसा
#
# Input Text: washington
# Target Text: वॉशिंगटन
# Predicted Text:
#
# Input Text: watan ke rakhwale
# Target Text: वतन के रखवाले
# Predicted Text:  फिल
#
# Input Text: wazeera
# Target Text: वज़ीरा
# Predicted Text:
#
# Input Text: weddell
# Target Text: वेडेल
# Predicted Text: लैटोना
#
# Input Text: willa
# Target Text: विलार्ड
# Predicted Text:
#
# Input Text: wockhardt
# Target Text: वॉकहार्ड
# Predicted Text: ताज़ा
#
# Input Text: woodward
# Target Text: वुडवर्ड
# Predicted Text:
#
# Input Text: yaqeen
# Target Text: य़कीन
# Predicted Text:
#
# Input Text: yaqub
# Target Text: य़ाकुब
# Predicted Text:
#
# Input Text: yar
# Target Text: यार
# Predicted Text:
#
# Input Text: yasir arafat
# Target Text: यासिर अराफत
# Predicted Text:
#
# Input Text: yehiam fort
# Target Text: येहैम फोर्ट
# Predicted Text:  फोर्ट
#
# Input Text: yograj
# Target Text: योगराज
# Predicted Text: लेबनॉन
#
# Input Text: yukon
# Target Text: यूकॉन
# Predicted Text:
#
# Input Text: yuvraj singh
# Target Text: युवराज सिंह
# Predicted Text:
#
# Input Text: zahoor elahi
# Target Text: ज़हूर इलाही
# Predicted Text:  मैकलियर
#
# Input Text: zaleel
# Target Text: ज़लील
# Predicted Text:
#
# Input Text: zayb
# Target Text: ज़ैब
# Predicted Text:
#
# Input Text: zorion
# Target Text: ज़ोरियन
# Predicted Text: लाइट
